# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Lecture 30 - CNN Architectures</center>
# ### <center> ResNet</center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/30_CnnArchitectures/MainResNet1.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# %%
import torch
import torchvision
import torchsummary

# %% [markdown]
# For Colab users:

# %%
# !wget https://raw.githubusercontent.com/FixelAlgorithmsTeam/FixelCourses/master/MachineLearningMethod/30_CnnArchitectures/ResNetAux.py

# %%
#-- Record figures during training:
from ResNetAux import TrainLoop, ValidationLoop, TrainModel, OneCycleScheduler

# %% [markdown]
# ### Download CIFAR-10 dataset:

# %%
import torchvision
import torchvision.transforms as transforms

oTrainSet = torchvision.datasets.CIFAR10(root='../../data', train=True,  download=True, transform=transforms.ToTensor())
oTestSet  = torchvision.datasets.CIFAR10(root='../../data', train=False, download=True, transform=transforms.ToTensor())
oTrainSet.data.shape, oTrainSet[0][0].shape
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# ((50000, 32, 32, 3), torch.Size([3, 32, 32]))

# %%
lClasses  = oTrainSet.classes
lClasses
# Out:
# ['airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck']

# %% [markdown]
# ### Plot some examples:

# %%
N, H, W, C = oTrainSet.data.shape
fig, _     = plt.subplots(2, 3, figsize=(10,6))
for ax in fig.axes:
    idx   = np.random.randint(0, N)
    mX, y = oTrainSet[idx]
    ax.imshow(np.transpose(mX.numpy(), (1,2,0)), cmap='gray')
    ax.set_title('True label: ' + str(lClasses[y]))
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Compute mean and variance:

# %%
vMean = oTrainSet.data.mean((0,1,2)) / 255
vStd  = oTrainSet.data.std ((0,1,2)) / 255
print('µ =', vMean)
print('σ =', vStd)
# Out:
# µ = [0.49139968 0.48215841 0.44653091]
# σ = [0.24703223 0.24348513 0.26158784]

# %% [markdown]
# ### Set datasets with normalization:

# %%
oTransform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(vMean, vStd)
])

oTrainSet.transform = oTransform
oTestSet .transform = oTransform

# %% [markdown]
# ### Create data loaders:

# %%
batchSize = 128
oTrainDL  = torch.utils.data.DataLoader(oTrainSet, shuffle=True,  batch_size=batchSize,   num_workers=2)
oTestDL   = torch.utils.data.DataLoader(oTestSet,  shuffle=False, batch_size=2*batchSize, num_workers=2)

# %% [markdown]
# ### Define the model (2D CNN):

# %%
import torch.nn as nn

def LeftBranch(C):
    oModel = nn.Sequential(
        nn.Conv2d(C, C, 3, padding=1, bias=False),
        nn.BatchNorm2d(C),
        nn.ReLU(),
        nn.Conv2d(C, C, 3, padding=1, bias=False),
        nn.BatchNorm2d(C),
    )
    
    return oModel
               
def RightBranch(C):
    oModel = nn.Sequential() #-- Identity

    return oModel

# %%
class ResBlock(nn.Module):
    def __init__(self, C):
        super(ResBlock, self).__init__()
        
        self.oLeftBranch  = LeftBranch(C)
        self.oRightBranch = RightBranch(C)

    def forward(self, mX):
        mZ = nn.functional.relu(self.oLeftBranch(mX) + self.oRightBranch(mX))
        return mZ
        
torchsummary.summary(ResBlock(64), (64, 56, 56)); print()
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 64, 56, 56]          --
# |    └─Conv2d: 2-1                       [-1, 64, 56, 56]          36,864
# |    └─BatchNorm2d: 2-2                  [-1, 64, 56, 56]          128
# |    └─ReLU: 2-3                         [-1, 64, 56, 56]          --
# |    └─Conv2d: 2-4                       [-1, 64, 56, 56]          36,864
# |    └─BatchNorm2d: 2-5                  [-1, 64, 56, 56]          128
# ├─Sequential: 1-2                        [-1, 64, 56, 56]          --
# ==========================================================================================
# Total params: 73,984
# Trainable params: 73,984
# Non-trainable params: 0
# Total mult-adds (M): 231.28
# ==========================================================================================
# Input size (MB): 0.77
# Forward/backward pass size (MB): 6.12
# Params size (MB): 0.28
# Estimated Total Size (MB): 7.17
# ==========================================================================================

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight.data)

#-- Tensor to vector (reshape):
class Flatten(nn.Module):
    def forward(self, mX):
        N  = mX.shape[0]
        mZ = mX.view(N, -1)
        return mZ
    
#--------------------------------------------------------------------------------#
#--------------------------------------------------------------------------------#
def GetModel():
    d      = 90
    oModel = nn.Sequential(
        nn.Sequential(),
        nn.Conv2d(3, d, 3, padding=1, bias=False), nn.BatchNorm2d(d),  nn.ReLU(),
        nn.Conv2d(d, d, 3, padding=1, bias=False), nn.BatchNorm2d(d),  nn.ReLU(),  nn.MaxPool2d(2),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        ResBlock(d),
        nn.AdaptiveAvgPool2d(1),
        Flatten(),
        nn.Linear(d, 10)
    )
    
    oModel.apply(weights_init)
    
    return oModel


torchsummary.summary(GetModel(), (3, 32, 32)); print()
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ├─Sequential: 1-1                        [-1, 3, 32, 32]           --
# ├─Conv2d: 1-2                            [-1, 90, 32, 32]          2,430
# ├─BatchNorm2d: 1-3                       [-1, 90, 32, 32]          180
# ├─ReLU: 1-4                              [-1, 90, 32, 32]          --
# ├─Conv2d: 1-5                            [-1, 90, 32, 32]          72,900
# ├─BatchNorm2d: 1-6                       [-1, 90, 32, 32]          180
# ├─ReLU: 1-7                              [-1, 90, 32, 32]          --
# ├─MaxPool2d: 1-8                         [-1, 90, 16, 16]          --
# ├─ResBlock: 1-9                          [-1, 90, 16, 16]          --
# |    └─Sequential: 2-1                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-1                  [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-2             [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-3                    [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-4                  [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-5             [-1, 90, 16, 16]          180
# |    └─Sequential: 2-2                   [-1, 90, 16, 16]          --
# ├─ResBlock: 1-10                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-3                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-6                  [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-7             [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-8                    [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-9                  [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-10            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-4                   [-1, 90, 16, 16]          --
# ├─ResBlock: 1-11                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-5                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-11                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-12            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-13                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-14                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-15            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-6                   [-1, 90, 16, 16]          --
# ├─ResBlock: 1-12                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-7                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-16                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-17            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-18                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-19                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-20            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-8                   [-1, 90, 16, 16]          --
# ├─ResBlock: 1-13                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-9                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-21                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-22            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-23                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-24                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-25            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-10                  [-1, 90, 16, 16]          --
# ├─ResBlock: 1-14                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-11                  [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-26                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-27            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-28                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-29                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-30            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-12                  [-1, 90, 16, 16]          --
# ├─ResBlock: 1-15                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-13                  [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-31                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-32            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-33                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-34                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-35            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-14                  [-1, 90, 16, 16]          --
# ├─ResBlock: 1-16                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-15                  [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-36                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-37            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-38                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-39                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-40            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-16                  [-1, 90, 16, 16]          --
# ├─ResBlock: 1-17                         [-1, 90, 16, 16]          --
# |    └─Sequential: 2-17                  [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-41                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-42            [-1, 90, 16, 16]          180
# |    |    └─ReLU: 3-43                   [-1, 90, 16, 16]          --
# |    |    └─Conv2d: 3-44                 [-1, 90, 16, 16]          72,900
# |    |    └─BatchNorm2d: 3-45            [-1, 90, 16, 16]          180
# |    └─Sequential: 2-18                  [-1, 90, 16, 16]          --
# ├─AdaptiveAvgPool2d: 1-18                [-1, 90, 1, 1]            --
# ├─Flatten: 1-19                          [-1, 90]                  --
# ├─Linear: 1-20                           [-1, 10]                  910
# ==========================================================================================
# Total params: 1,392,040
# Trainable params: 1,392,040
# Non-trainable params: 0
# Total mult-adds (M): 415.69
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 9.14
# Params size (MB): 5.31
# Estimated Total Size (MB): 14.46
# ==========================================================================================

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
device
# Out:
# device(type='cuda', index=0)

# %%
import torch.optim as optim
LossFunc = nn.CrossEntropyLoss()

# %%
# %matplotlib notebook

oModel = GetModel().to(device)
oOptim = optim.AdamW(oModel.parameters(), lr=0, betas=(0.9, 0.99), weight_decay=2e-2)

iterPerEpoch  = len(oTrainDL)
numEpochs     = 30
numIter       = numEpochs * iterPerEpoch
minLR         = 1e-4
maxLR         = 3e-2
vLearningRate = minLR + .5 * (maxLR - minLR) * (1 + np.cos(np.arange(numIter) / numIter * 2*np.pi + np.pi))

oScheduler = OneCycleScheduler(oOptim, vLearningRate)
TrainModel(oModel, oTrainDL, oTestDL, LossFunc, numEpochs, oOptim, oScheduler)
# Out:
# <img src="data:image/png;base64,..." width="1199.999973990701">
# Epoch   0: | Train loss: 1.39945 | Val loss: 1.34734 | Train Accuracy: 0.4955 | Val Accuracy: 0.5253 | epoch time: 50.870 | <-- Checkpoint!
# Epoch   1: | Train loss: 1.00053 | Val loss: 1.80758 | Train Accuracy: 0.6432 | Val Accuracy: 0.4807 | epoch time: 50.353 |
# Epoch   2: | Train loss: 0.82281 | Val loss: 1.54483 | Train Accuracy: 0.7100 | Val Accuracy: 0.5458 | epoch time: 49.100 | <-- Checkpoint!
# Epoch   3: | Train loss: 0.71034 | Val loss: 1.37376 | Train Accuracy: 0.7540 | Val Accuracy: 0.6171 | epoch time: 49.653 | <-- Checkpoint!
# Epoch   4: | Train loss: 0.64252 | Val loss: 0.76098 | Train Accuracy: 0.7782 | Val Accuracy: 0.7417 | epoch time: 49.446 | <-- Checkpoint!
# Epoch   5: | Train loss: 0.58284 | Val loss: 0.86867 | Train Accuracy: 0.7999 | Val Accuracy: 0.7035 | epoch time: 50.605 |
# Epoch   6: | Train loss: 0.54219 | Val loss: 0.81144 | Train Accuracy: 0.8165 | Val Accuracy: 0.7341 | epoch time: 49.928 |
# Epoch   7: | Train loss: 0.51370 | Val loss: 0.82341 | Train Accuracy: 0.8247 | Val Accuracy: 0.7296 | epoch time: 49.052 |
# Epoch   8: | Train loss: 0.49532 | Val loss: 0.92498 | Train Accuracy: 0.8310 | Val Accuracy: 0.7314 | epoch time: 48.553 |
# Epoch   9: | Train loss: 0.47744 | Val loss: 0.71981 | Train Accuracy: 0.8373 | Val Accuracy: 0.7667 | epoch time: 48.682 | <-- Checkpoint!
# Epoch  10: | Train loss: 0.47025 | Val loss: 0.78130 | Train Accuracy: 0.8397 | Val Accuracy: 0.7635 | epoch time: 48.707 |
# Epoch  11: | Train loss: 0.45902 | Val loss: 0.60702 | Train Accuracy: 0.8433 | Val Accuracy: 0.7982 | epoch time: 48.594 | <-- Checkpoint!
# Epoch  12: | Train loss: 0.44236 | Val loss: 0.90376 | Train Accuracy: 0.8502 | Val Accuracy: 0.7187 | epoch time: 48.905 |
# Epoch  13: | Train loss: 0.43124 | Val loss: 1.11376 | Train Accuracy: 0.8515 | Val Accuracy: 0.6928 | epoch time: 48.565 |
# Epoch  14: | Train loss: 0.42250 | Val loss: 0.67819 | Train Accuracy: 0.8556 | Val Accuracy: 0.7787 | epoch time: 48.875 |
# Epoch  15: | Train loss: 0.39620 | Val loss: 0.81352 | Train Accuracy: 0.8655 | Val Accuracy: 0.7359 | epoch time: 48.673 |
# Epoch  16: | Train loss: 0.38676 | Val loss: 0.64047 | Train Accuracy: 0.8665 | Val Accuracy: 0.7946 | epoch time: 48.636 |
# Epoch  17: | Train loss: 0.36421 | Val loss: 0.64807 | Train Accuracy: 0.8766 | Val Accuracy: 0.7878 | epoch time: 48.841 |
# Epoch  18: | Train loss: 0.33856 | Val loss: 0.56133 | Train Accuracy: 0.8836 | Val Accuracy: 0.8125 | epoch time: 48.452 | <-- Checkpoint!
# Epoch  19: | Train loss: 0.31152 | Val loss: 0.53639 | Train Accuracy: 0.8918 | Val Accuracy: 0.8282 | epoch time: 49.063 | <-- Checkpoint!
# Epoch  20: | Train loss: 0.27223 | Val loss: 0.51457 | Train Accuracy: 0.9061 | Val Accuracy: 0.8383 | epoch time: 48.117 | <-- Checkpoint!
# Epoch  21: | Train loss: 0.23457 | Val loss: 0.56573 | Train Accuracy: 0.9174 | Val Accuracy: 0.8255 | epoch time: 49.197 |
# Epoch  22: | Train loss: 0.19060 | Val loss: 0.49694 | Train Accuracy: 0.9339 | Val Accuracy: 0.8474 | epoch time: 49.488 | <-- Checkpoint!
# Epoch  23: | Train loss: 0.14286 | Val loss: 0.39111 | Train Accuracy: 0.9505 | Val Accuracy: 0.8819 | epoch time: 50.101 | <-- Checkpoint!
# Iteration:  82: loss = 0.087670
