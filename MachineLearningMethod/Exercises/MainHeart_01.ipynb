# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Exercise 1 - Hearth disease classification</center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/Exercises/MainHeart_01.ipynb)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})
# np.random.seed(1)

# %% [markdown]
# #### Load the dataset:
# https://www.kaggle.com/ronitf/heart-disease-uci

# %%
dData = pd.read_csv('heart.csv')
dData
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# #### Rename columns:

# %%
dData.columns = ['Age', 'Sex', 'Chest_pain_type', 'Resting_blood_pressure', 'Cholesterol', 'Fasting_blood_sugar', 'Rest_ECG', 'Max_heart_rate_achieved',
                 'Exercise_induced_angina', 'ST_depression', 'ST_slope', 'Num_major_vessels', 'Thalassemia', 'Target']
dData
# Out:
#      Age  Sex  Chest_pain_type  Resting_blood_pressure  Cholesterol  \
# 0     63    1                3                     145          233
# 1     37    1                2                     130          250
# 2     41    0                1                     130          204
# 3     56    1                1                     120          236
# 4     57    0                0                     120          354
# ..   ...  ...              ...                     ...          ...
# 298   57    0                0                     140          241
# 299   45    1                3                     110          264
# 300   68    1                0                     144          193
# 301   57    1                0                     130          131
# 302   57    0                1                     130          236
#
#      Fasting_blood_sugar  Rest_ECG  Max_heart_rate_achieved  \
# 0                      1         0                      150
# 1                      0         1                      187
# 2                      0         0                      172
# 3                      0         1                      178
# 4                      0         1                      163
# ..                   ...       ...                      ...
# 298                    0         1                      123
# 299                    0         1                      132
# 300                    1         1                      141
# 301                    0         1                      115
# 302                    0         0                      174
#
#      Exercise_induced_angina  ST_depression  ST_slope  Num_major_vessels  \
# 0                          0            2.3         0                  0
# 1                          0            3.5         0                  0
# 2                          0            1.4         2                  0
# 3                          0            0.8         2                  0
# 4                          1            0.6         2                  0
# ..                       ...            ...       ...                ...
# 298                        1            0.2         1                  0
# 299                        0            1.2         1                  0
# 300                        0            3.4         1                  2
# 301                        1            1.2         1                  1
# 302                        0            0.0         1                  1
#
#      Thalassemia  Target
# 0              1       1
# 1              2       1
# 2              2       1
# 3              2       1
# 4              2       1
# ..           ...     ...
# 298            3       0
# 299            3       0
# 300            3       0
# 301            3       0
# 302            2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# #### Meaningful categorical data:

# %%
dData.loc[dData['Sex']                     == 0, 'Sex']                     = 'female'
dData.loc[dData['Sex']                     == 1, 'Sex']                     = 'male'
        
dData.loc[dData['Chest_pain_type']         == 1, 'Chest_pain_type']         = 'typical angina'
dData.loc[dData['Chest_pain_type']         == 2, 'Chest_pain_type']         = 'atypical angina'
dData.loc[dData['Chest_pain_type']         == 3, 'Chest_pain_type']         = 'non-anginal pain'
dData.loc[dData['Chest_pain_type']         == 4, 'Chest_pain_type']         = 'asymptomatic'

dData.loc[dData['Fasting_blood_sugar']     == 0, 'Fasting_blood_sugar']     = 'lower than 120mg/ml'
dData.loc[dData['Fasting_blood_sugar']     == 1, 'Fasting_blood_sugar']     = 'greater than 120mg/ml'

dData.loc[dData['Rest_ECG']                == 0, 'Rest_ECG']                = 'normal'
dData.loc[dData['Rest_ECG']                == 1, 'Rest_ECG']                = 'ST-T wave abnormality'
dData.loc[dData['Rest_ECG']                == 2, 'Rest_ECG']                = 'left ventricular hypertrophy'

dData.loc[dData['Exercise_induced_angina'] == 0, 'Exercise_induced_angina'] = 'no'
dData.loc[dData['Exercise_induced_angina'] == 1, 'Exercise_induced_angina'] = 'yes'

dData.loc[dData['ST_slope']                == 1, 'ST_slope']                = 'upsloping'
dData.loc[dData['ST_slope']                == 2, 'ST_slope']                = 'flat'
dData.loc[dData['ST_slope']                == 3, 'ST_slope']                = 'downsloping'

dData.loc[dData['Thalassemia']             == 1, 'Thalassemia']             = 'normal'
dData.loc[dData['Thalassemia']             == 2, 'Thalassemia']             = 'fixed defect'
dData.loc[dData['Thalassemia']             == 3, 'Thalassemia']             = 'reversable defect'

dData.loc[dData['Target']                  == 0, 'Target']                  = 'hearth disease'
dData.loc[dData['Target']                  == 1, 'Target']                  = 'no hearth disease'
dData
# Out:
#      Age     Sex   Chest_pain_type  Resting_blood_pressure  Cholesterol  \
# 0     63    male  non-anginal pain                     145          233
# 1     37    male   atypical angina                     130          250
# 2     41  female    typical angina                     130          204
# 3     56    male    typical angina                     120          236
# 4     57  female                 0                     120          354
# ..   ...     ...               ...                     ...          ...
# 298   57  female                 0                     140          241
# 299   45    male  non-anginal pain                     110          264
# 300   68    male                 0                     144          193
# 301   57    male                 0                     130          131
# 302   57  female    typical angina                     130          236
#
#        Fasting_blood_sugar               Rest_ECG  Max_heart_rate_achieved  \
# 0    greater than 120mg/ml                 normal                      150
# 1      lower than 120mg/ml  ST-T wave abnormality                      187
# 2      lower than 120mg/ml                 normal                      172
# 3      lower than 120mg/ml  ST-T wave abnormality                      178
# 4      lower than 120mg/ml  ST-T wave abnormality                      163
# ..                     ...                    ...                      ...
# 298    lower than 120mg/ml  ST-T wave abnormality                      123
# 299    lower than 120mg/ml  ST-T wave abnormality                      132
# 300  greater than 120mg/ml  ST-T wave abnormality                      141
# 301    lower than 120mg/ml  ST-T wave abnormality                      115
# 302    lower than 120mg/ml                 normal                      174
#
#     Exercise_induced_angina  ST_depression   ST_slope  Num_major_vessels  \
# 0                        no            2.3          0                  0
# 1                        no            3.5          0                  0
# 2                        no            1.4       flat                  0
# 3                        no            0.8       flat                  0
# 4                       yes            0.6       flat                  0
# ..                      ...            ...        ...                ...
# 298                     yes            0.2  upsloping                  0
# 299                      no            1.2  upsloping                  0
# 300                      no            3.4  upsloping                  2
# 301                     yes            1.2  upsloping                  1
# 302                      no            0.0  upsloping                  1
#
#            Thalassemia             Target
# 0               normal  no hearth disease
# 1         fixed defect  no hearth disease
# 2         fixed defect  no hearth disease
# 3         fixed defect  no hearth disease
# 4         fixed defect  no hearth disease
# ..                 ...                ...
# 298  reversable defect     hearth disease
# 299  reversable defect     hearth disease
# 300  reversable defect     hearth disease
# 301  reversable defect     hearth disease
# 302       fixed defect     hearth disease
#
# [303 rows x 14 columns]

# %%
dData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      303 non-null    int64
#  1   Sex                      303 non-null    object
#  2   Chest_pain_type          303 non-null    object
#  3   Resting_blood_pressure   303 non-null    int64
#  4   Cholesterol              303 non-null    int64
#  5   Fasting_blood_sugar      303 non-null    object
#  6   Rest_ECG                 303 non-null    object
#  7   Max_heart_rate_achieved  303 non-null    int64
#  8   Exercise_induced_angina  303 non-null    object
#  9   ST_depression            303 non-null    float64
#  10  ST_slope                 303 non-null    object
#  11  Num_major_vessels        303 non-null    int64
#  12  Thalassemia              303 non-null    object
#  13  Target                   303 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 33.3+ KB

# %%
dData = pd.get_dummies(dData, drop_first=True)
dData
# Out:
#      Age  Resting_blood_pressure  Cholesterol  Max_heart_rate_achieved  \
# 0     63                     145          233                      150
# 1     37                     130          250                      187
# 2     41                     130          204                      172
# 3     56                     120          236                      178
# 4     57                     120          354                      163
# ..   ...                     ...          ...                      ...
# 298   57                     140          241                      123
# 299   45                     110          264                      132
# 300   68                     144          193                      141
# 301   57                     130          131                      115
# 302   57                     130          236                      174
#
#      ST_depression  Num_major_vessels  Sex_male  \
# 0              2.3                  0         1
# 1              3.5                  0         1
# 2              1.4                  0         0
# 3              0.8                  0         1
# 4              0.6                  0         0
# ..             ...                ...       ...
# 298            0.2                  0         0
# 299            1.2                  0         1
# 300            3.4                  2         1
# 301            1.2                  1         1
# 302            0.0                  1         0
#
#      Chest_pain_type_atypical angina  Chest_pain_type_non-anginal pain  \
# 0                                  0                                 1
# 1                                  1                                 0
# 2                                  0                                 0
# 3                                  0                                 0
# 4                                  0                                 0
# ..                               ...                               ...
# 298                                0                                 0
# 299                                0                                 1
# 300                                0                                 0
# 301                                0                                 0
# 302                                0                                 0
#
#      Chest_pain_type_typical angina  Fasting_blood_sugar_lower than 120mg/ml  \
# 0                                 0                                        0
# 1                                 0                                        1
# 2                                 1                                        1
# 3                                 1                                        1
# 4                                 0                                        1
# ..                              ...                                      ...
# 298                               0                                        1
# 299                               0                                        1
# 300                               0                                        0
# 301                               0                                        1
# 302                               1                                        1
#
#      Rest_ECG_left ventricular hypertrophy  Rest_ECG_normal  \
# 0                                        0                1
# 1                                        0                0
# 2                                        0                1
# 3                                        0                0
# 4                                        0                0
# ..                                     ...              ...
# 298                                      0                0
# 299                                      0                0
# 300                                      0                0
# 301                                      0                0
# 302                                      0                1
#
#      Exercise_induced_angina_yes  ST_slope_flat  ST_slope_upsloping  \
# 0                              0              0                   0
# 1                              0              0                   0
# 2                              0              1                   0
# 3                              0              1                   0
# 4                              1              1                   0
# ..                           ...            ...                 ...
# 298                            1              0                   1
# 299                            0              0                   1
# 300                            0              0                   1
# 301                            1              0                   1
# 302                            0              0                   1
#
#      Thalassemia_fixed defect  Thalassemia_normal  \
# 0                           0                   1
# 1                           1                   0
# 2                           1                   0
# 3                           1                   0
# 4                           1                   0
# ..                        ...                 ...
# 298                         0                   0
# 299                         0                   0
# 300                         0                   0
# 301                         0                   0
# 302                         1                   0
#
#      Thalassemia_reversable defect  Target_no hearth disease
# 0                                0                         1
# 1                                0                         1
# 2                                0                         1
# 3                                0                         1
# 4                                0                         1
# ..                             ...                       ...
# 298                              1                         0
# 299                              1                         0
# 300                              1                         0
# 301                              1                         0
# 302                              0                         0
#
# [303 rows x 20 columns]

# %% [markdown]
# #### Pair plot:

# %%
lColumn = ['Age', 'Resting_blood_pressure', 'Cholesterol', 'Max_heart_rate_achieved', 'ST_depression', 'Num_major_vessels', 'Target_no hearth disease']
sns.pairplot(dData[lColumn], hue='Target_no hearth disease', diag_kind='hist')

# %% [markdown]
# #### Display data balance:

# %%
 dData['Target_no hearth disease'].value_counts()
# Out:
# 1    165
# 0    138
# Name: Target_no hearth disease, dtype: int64

# %% [markdown]
# #### Split to features and labels:

# %%
dTrain = dData.drop('Target_no hearth disease', 1)
dY     = dData['Target_no hearth disease']

# %% [markdown]
# #### Train linear SVM:

# %%
from sklearn.svm             import SVC
from sklearn.model_selection import cross_val_score

for C in [0.1, 0.5, 1, 2, 5]:
    oSVM      = SVC(kernel='linear', C=C)
    vAccuracy = cross_val_score(oSVM, dTrain, dY, cv=10)
    print(f'Linear SVM with C = {C:6.1f} | cross validation accuracy: {vAccuracy.mean():.4f}')
# Out:
# Linear SVM with C =    0.1 | cross validation accuracy: 0.8249
# Linear SVM with C =    0.5 | cross validation accuracy: 0.8282
# Linear SVM with C =    1.0 | cross validation accuracy: 0.8282
# Linear SVM with C =    2.0 | cross validation accuracy: 0.8249
# Linear SVM with C =    5.0 | cross validation accuracy: 0.8184

# %% [markdown]
# #### Normalize the data

# %%
dTrain.describe()
# Out:
#               Age  Resting_blood_pressure  Cholesterol  \
# count  303.000000              303.000000   303.000000
# mean    54.366337              131.623762   246.264026
# std      9.082101               17.538143    51.830751
# min     29.000000               94.000000   126.000000
# 25%     47.500000              120.000000   211.000000
# 50%     55.000000              130.000000   240.000000
# 75%     61.000000              140.000000   274.500000
# max     77.000000              200.000000   564.000000
#
#        Max_heart_rate_achieved  ST_depression  Num_major_vessels    Sex_male  \
# count               303.000000     303.000000         303.000000  303.000000
# mean                149.646865       1.039604           0.729373    0.683168
# std                  22.905161       1.161075           1.022606    0.466011
# min                  71.000000       0.000000           0.000000    0.000000
# 25%                 133.500000       0.000000           0.000000    0.000000
# 50%                 153.000000       0.800000           0.000000    1.000000
# 75%                 166.000000       1.600000           1.000000    1.000000
# max                 202.000000       6.200000           4.000000    1.000000
#
#        Chest_pain_type_atypical angina  Chest_pain_type_non-anginal pain  \
# count                       303.000000                        303.000000
# mean                          0.287129                          0.075908
# std                           0.453171                          0.265288
# min                           0.000000                          0.000000
# 25%                           0.000000                          0.000000
# 50%                           0.000000                          0.000000
# 75%                           1.000000                          0.000000
# max                           1.000000                          1.000000
#
#        Chest_pain_type_typical angina  \
# count                      303.000000
# mean                         0.165017
# std                          0.371809
# min                          0.000000
# 25%                          0.000000
# 50%                          0.000000
# 75%                          0.000000
# max                          1.000000
#
#        Fasting_blood_sugar_lower than 120mg/ml  \
# count                               303.000000
# mean                                  0.851485
# std                                   0.356198
# min                                   0.000000
# 25%                                   1.000000
# 50%                                   1.000000
# 75%                                   1.000000
# max                                   1.000000
#
#        Rest_ECG_left ventricular hypertrophy  Rest_ECG_normal  \
# count                             303.000000       303.000000
# mean                                0.013201         0.485149
# std                                 0.114325         0.500606
# min                                 0.000000         0.000000
# 25%                                 0.000000         0.000000
# 50%                                 0.000000         0.000000
# 75%                                 0.000000         1.000000
# max                                 1.000000         1.000000
#
#        Exercise_induced_angina_yes  ST_slope_flat  ST_slope_upsloping  \
# count                   303.000000     303.000000          303.000000
# mean                      0.326733       0.468647            0.462046
# std                       0.469794       0.499842            0.499382
# min                       0.000000       0.000000            0.000000
# 25%                       0.000000       0.000000            0.000000
# 50%                       0.000000       0.000000            0.000000
# 75%                       1.000000       1.000000            1.000000
# max                       1.000000       1.000000            1.000000
#
#        Thalassemia_fixed defect  Thalassemia_normal  \
# count                303.000000          303.000000
# mean                   0.547855            0.059406
# std                    0.498528            0.236774
# min                    0.000000            0.000000
# 25%                    0.000000            0.000000
# 50%                    1.000000            0.000000
# 75%                    1.000000            0.000000
# max                    1.000000            1.000000
#
#        Thalassemia_reversable defect
# count                     303.000000
# mean                        0.386139
# std                         0.487668
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         1.000000
# max                         1.000000

# %%
from sklearn import preprocessing

dTrain = pd.DataFrame(preprocessing.StandardScaler().fit_transform(dTrain), columns=dTrain.columns)
dTrain.describe()
# Out:
#                 Age  Resting_blood_pressure   Cholesterol  \
# count  3.030000e+02            3.030000e+02  3.030000e+02
# mean   5.825923e-17           -7.146832e-16 -9.828955e-17
# std    1.001654e+00            1.001654e+00  1.001654e+00
# min   -2.797624e+00           -2.148802e+00 -2.324160e+00
# 25%   -7.572802e-01           -6.638668e-01 -6.814943e-01
# 50%    6.988599e-02           -9.273778e-02 -1.210553e-01
# 75%    7.316189e-01            4.783913e-01  5.456738e-01
# max    2.496240e+00            3.905165e+00  6.140401e+00
#
#        Max_heart_rate_achieved  ST_depression  Num_major_vessels  \
# count             3.030000e+02   3.030000e+02       3.030000e+02
# mean             -5.203025e-16  -3.140136e-16       4.752341e-16
# std               1.001654e+00   1.001654e+00       1.001654e+00
# min              -3.439267e+00  -8.968617e-01      -7.144289e-01
# 25%              -7.061105e-01  -8.968617e-01      -7.144289e-01
# 50%               1.466343e-01  -2.067053e-01      -7.144289e-01
# 75%               7.151309e-01   4.834512e-01       2.650822e-01
# max               2.289429e+00   4.451851e+00       3.203615e+00
#
#            Sex_male  Chest_pain_type_atypical angina  \
# count  3.030000e+02                     3.030000e+02
# mean  -1.319077e-17                     3.341661e-16
# std    1.001654e+00                     1.001654e+00
# min   -1.468418e+00                    -6.346478e-01
# 25%   -1.468418e+00                    -6.346478e-01
# 50%    6.810052e-01                    -6.346478e-01
# 75%    6.810052e-01                     1.575677e+00
# max    6.810052e-01                     1.575677e+00
#
#        Chest_pain_type_non-anginal pain  Chest_pain_type_typical angina  \
# count                      3.030000e+02                    3.030000e+02
# mean                       1.183505e-16                   -3.297692e-16
# std                        1.001654e+00                    1.001654e+00
# min                       -2.866058e-01                   -4.445542e-01
# 25%                       -2.866058e-01                   -4.445542e-01
# 50%                       -2.866058e-01                   -4.445542e-01
# 75%                       -2.866058e-01                   -4.445542e-01
# max                        3.489114e+00                    2.249444e+00
#
#        Fasting_blood_sugar_lower than 120mg/ml  \
# count                             3.030000e+02
# mean                              3.444256e-17
# std                               1.001654e+00
# min                              -2.394438e+00
# 25%                               4.176345e-01
# 50%                               4.176345e-01
# 75%                               4.176345e-01
# max                               4.176345e-01
#
#        Rest_ECG_left ventricular hypertrophy  Rest_ECG_normal  \
# count                           3.030000e+02     3.030000e+02
# mean                            8.143468e-17     1.634190e-16
# std                             1.001654e+00     1.001654e+00
# min                            -1.156630e-01    -9.707253e-01
# 25%                            -1.156630e-01    -9.707253e-01
# 50%                            -1.156630e-01    -9.707253e-01
# 75%                            -1.156630e-01     1.030158e+00
# max                             8.645808e+00     1.030158e+00
#
#        Exercise_induced_angina_yes  ST_slope_flat  ST_slope_upsloping  \
# count                 3.030000e+02   3.030000e+02        3.030000e+02
# mean                 -5.203025e-16   2.147164e-16       -8.896441e-16
# std                   1.001654e+00   1.001654e+00        1.001654e+00
# min                  -6.966305e-01  -9.391419e-01       -9.267663e-01
# 25%                  -6.966305e-01  -9.391419e-01       -9.267663e-01
# 50%                  -6.966305e-01  -9.391419e-01       -9.267663e-01
# 75%                   1.435481e+00   1.064802e+00        1.079021e+00
# max                   1.435481e+00   1.064802e+00        1.079021e+00
#
#        Thalassemia_fixed defect  Thalassemia_normal  \
# count              3.030000e+02        3.030000e+02
# mean               6.020120e-16       -1.282436e-17
# std                1.001654e+00        1.001654e+00
# min               -1.100763e+00       -2.513123e-01
# 25%               -1.100763e+00       -2.513123e-01
# 50%                9.084609e-01       -2.513123e-01
# 75%                9.084609e-01       -2.513123e-01
# max                9.084609e-01        3.979112e+00
#
#        Thalassemia_reversable defect
# count                   3.030000e+02
# mean                    4.125779e-16
# std                     1.001654e+00
# min                    -7.931155e-01
# 25%                    -7.931155e-01
# 50%                    -7.931155e-01
# 75%                     1.260850e+00
# max                     1.260850e+00

# %% [markdown]
# #### Train kernel SVM (Gaussian kernel):

# %%
lC   = [1, 10, 100, 1000, 5000]
lσ   = [0.01, 0.1, 1, 10, 100]
dRes = pd.DataFrame(columns=['C', 'σ', 'Accuracy'])

for C in lC:
    for σ in lσ:
        oSVM                = SVC(kernel='rbf', C=C, gamma=1/(2*σ**2))
        vAccuracy           = cross_val_score(oSVM, dTrain, dY, cv=10)
        dRes.loc[len(dRes)] = [C, σ, vAccuracy.mean()]
        
dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#          C       σ  Accuracy
# 19  1000.0  100.00  0.841505
# 13   100.0   10.00  0.838065
# 3      1.0   10.00  0.834839
# 8     10.0   10.00  0.834839
# 14   100.0  100.00  0.834839
# 24  5000.0  100.00  0.825054
# 9     10.0  100.00  0.815054
# 18  1000.0   10.00  0.781935
# 23  5000.0   10.00  0.762043
# 22  5000.0    1.00  0.672688
# 17  1000.0    1.00  0.672688
# 12   100.0    1.00  0.672688
# 7     10.0    1.00  0.672688
# 2      1.0    1.00  0.665699
# 1      1.0    0.10  0.544516
# 11   100.0    0.10  0.544516
# 10   100.0    0.01  0.544516
# 15  1000.0    0.01  0.544516
# 16  1000.0    0.10  0.544516
# 6     10.0    0.10  0.544516
# 5     10.0    0.01  0.544516
# 20  5000.0    0.01  0.544516
# 21  5000.0    0.10  0.544516
# 4      1.0  100.00  0.544516
# 0      1.0    0.01  0.544516

# %% [markdown]
# #### Train kernel SVM (polynomial kernel):

# %%
lC   = [1, 10, 100, 1000]
lP   = range(1, 9)
dRes = pd.DataFrame(columns=['C', 'P', 'Accuracy'])

for C in lC:
    for P in lP:
        oSVM                = SVC(kernel='poly', C=C, degree=P)
        vAccuracy           = cross_val_score(oSVM, dTrain, dY, cv=10)
        dRes.loc[len(dRes)] = [C, P, vAccuracy.mean()]
        
dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#          C    P  Accuracy
# 0      1.0  1.0  0.838065
# 2      1.0  3.0  0.825269
# 8     10.0  1.0  0.825054
# 24  1000.0  1.0  0.821613
# 16   100.0  1.0  0.821613
# 12    10.0  5.0  0.795699
# 10    10.0  3.0  0.795591
# 18   100.0  3.0  0.778710
# 26  1000.0  3.0  0.778710
# 20   100.0  5.0  0.772258
# 28  1000.0  5.0  0.772258
# 22   100.0  7.0  0.762151
# 1      1.0  2.0  0.755591
# 30  1000.0  7.0  0.752151
# 14    10.0  7.0  0.745699
# 4      1.0  5.0  0.742473
# 9     10.0  2.0  0.732043
# 11    10.0  4.0  0.725806
# 27  1000.0  4.0  0.722581
# 19   100.0  4.0  0.722581
# 3      1.0  4.0  0.702688
# 17   100.0  2.0  0.702473
# 13    10.0  6.0  0.699462
# 21   100.0  6.0  0.699247
# 29  1000.0  6.0  0.695914
# 31  1000.0  8.0  0.672688
# 25  1000.0  2.0  0.669140
# 23   100.0  8.0  0.666452
# 6      1.0  7.0  0.653441
# 15    10.0  8.0  0.643011
# 5      1.0  6.0  0.626882
# 7      1.0  8.0  0.584194

# %% [markdown]
# #### Train K-NN:

# %%
from sklearn.neighbors import KNeighborsClassifier

for K in range(1, 9):
    oKnn   = KNeighborsClassifier(n_neighbors=K)
    scores = cross_val_score(oKnn, dTrain, dY, cv=10)
    print(f'K-nn with K = {K:2d} | cross validation accuracy: {scores.mean():.4f}')
# Out:
# K-nn with K =  1 | cross validation accuracy: 0.7657
# K-nn with K =  2 | cross validation accuracy: 0.7691
# K-nn with K =  3 | cross validation accuracy: 0.7892
# K-nn with K =  4 | cross validation accuracy: 0.7889
# K-nn with K =  5 | cross validation accuracy: 0.8122
# K-nn with K =  6 | cross validation accuracy: 0.8056
# K-nn with K =  7 | cross validation accuracy: 0.8219
# K-nn with K =  8 | cross validation accuracy: 0.8186

# %% [markdown]
# #### Take best model and plot confusion matrix (using cross validation):

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics         import confusion_matrix

oSVM            = SVC(kernel='rbf', C=1000, gamma=1/(2*100**2))
vCrossValHatY   = cross_val_predict(oSVM, dTrain, dY, cv=10)
mTrainConfusion = confusion_matrix(dY, vCrossValHatY)
mTrainConfusion
# Out:
# array([[107,  31],
#        [ 17, 148]], dtype=int64)

# %% [markdown]
# #### ELI5 (Explain Like I'm Five):
# https://eli5.readthedocs.io/en/latest/index.html

# %%
import eli5

oSVM = SVC(kernel='linear', C=0.1).fit(dTrain, dY)
eli5.show_weights(oSVM, feature_names=dTrain.columns.tolist(), target_names=['hearth disease', 'no hearth disease'], )
# Out:
# C:\Users\Or\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Or\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=no hearth disease
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.498
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_atypical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.355
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_non-anginal pain
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.347
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_fixed defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.06%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.210
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_slope_flat
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.175
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_typical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Max_heart_rate_achieved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.25%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.128
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Rest_ECG_left ventricular hypertrophy
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 97.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.021
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Age
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 95.44%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.060
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cholesterol
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 95.36%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.062
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Fasting_blood_sugar_lower than 120mg/ml
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 94.61%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.077
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_slope_upsloping
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.118
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Rest_ECG_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.53%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.122
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Resting_blood_pressure
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.03%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.211
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_reversable defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 87.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.261
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Exercise_induced_angina_yes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.02%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.329
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Sex_male
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 83.39%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.382
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_depression
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.82%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.469
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Num_major_vessels
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# #### Single prediction inspection:

# %%
eli5.show_prediction(oSVM, dTrain.iloc[2], target_names=['hearth disease', 'no hearth disease'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=no hearth disease
#
# </b>
#
#
#     (score <b>1.891</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.484
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Sex_male
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.393
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_typical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.54%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.335
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Num_major_vessels
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 85.20%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.315
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_fixed defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.33%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.224
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_slope_flat
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.181
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Exercise_induced_angina_yes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.21%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.174
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.37%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.170
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Max_heart_rate_achieved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.48%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.168
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_reversable defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.78%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.071
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_slope_upsloping
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 95.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.049
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cholesterol
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.12%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.030
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Age
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.011
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Resting_blood_pressure
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Rest_ECG_left ventricular hypertrophy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.026
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Fasting_blood_sugar_lower than 120mg/ml
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.99%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.032
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 93.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.102
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_non-anginal pain
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.52%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.119
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ST_depression
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.121
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Rest_ECG_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.316
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Chest_pain_type_atypical angina
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ### SHAP (SHapley Additive exPlanations):
# https://shap.readthedocs.io/en/latest/#

# %%
import shap

oExplainer  = shap.LinearExplainer(oSVM, dTrain)
mShapValues = oExplainer.shap_values(dTrain)
shap.summary_plot(mShapValues, dTrain)
