# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Exercise 02 - Regression (Solution)</center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/Exercises/MainRegressionExercise02.ipynb)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# np.random.seed(1)
# %matplotlib notebook

# %% [markdown]
# ### Get data:
# From Kaggle: https://www.kaggle.com/mirichoi0218/insurance

# %%
dData = pd.read_csv('insurance.csv')
dData
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Change columns names:

# %%
dData.columns = ['Age', 'Sex', 'BMI', 'NumberOfChildren', 'Smoker', 'Region', 'Charges']
dData
# Out:
#       Age     Sex     BMI  NumberOfChildren Smoker     Region      Charges
# 0      19  female  27.900                 0    yes  southwest  16884.92400
# 1      18    male  33.770                 1     no  southeast   1725.55230
# 2      28    male  33.000                 3     no  southeast   4449.46200
# 3      33    male  22.705                 0     no  northwest  21984.47061
# 4      32    male  28.880                 0     no  northwest   3866.85520
# ...   ...     ...     ...               ...    ...        ...          ...
# 1333   50    male  30.970                 3     no  northwest  10600.54830
# 1334   18  female  31.920                 0     no  northeast   2205.98080
# 1335   18  female  36.850                 0     no  southeast   1629.83350
# 1336   21  female  25.800                 0     no  southwest   2007.94500
# 1337   61  female  29.070                 0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# ### Create dummies variables:

# %%
dData = pd.get_dummies(dData, drop_first=True)

#-- Move charges to last columns:
lCols = [c for c in dData.columns.tolist() if c != 'Charges'] + ['Charges']
dData = dData[lCols]
dData
# Out:
#       Age     BMI  NumberOfChildren  Sex_male  Smoker_yes  Region_northwest  \
# 0      19  27.900                 0         0           1                 0
# 1      18  33.770                 1         1           0                 0
# 2      28  33.000                 3         1           0                 0
# 3      33  22.705                 0         1           0                 1
# 4      32  28.880                 0         1           0                 1
# ...   ...     ...               ...       ...         ...               ...
# 1333   50  30.970                 3         1           0                 1
# 1334   18  31.920                 0         0           0                 0
# 1335   18  36.850                 0         0           0                 0
# 1336   21  25.800                 0         0           0                 0
# 1337   61  29.070                 0         0           1                 1
#
#       Region_southeast  Region_southwest      Charges
# 0                    0                 1  16884.92400
# 1                    1                 0   1725.55230
# 2                    1                 0   4449.46200
# 3                    0                 0  21984.47061
# 4                    0                 0   3866.85520
# ...                ...               ...          ...
# 1333                 0                 0  10600.54830
# 1334                 0                 0   2205.98080
# 1335                 1                 0   1629.83350
# 1336                 0                 1   2007.94500
# 1337                 0                 0  29141.36030
#
# [1338 rows x 9 columns]

# %%
# dTrainX = dData.drop(columns='Charges')
dTrainX = dData.drop(columns=['Charges', 'Region_northwest', 'Region_southeast', 'Region_southwest'])
dTrainY = dData['Charges']

mX = dTrainX.values
vY = dTrainY.values

mX -= np.mean(mX, axis=0)
mX /= np.std(mX,  axis=0)
vY -= np.mean(vY)
vY /= np.std(vY)

mX.shape, vY.shape
# Out:
# ((1338, 5), (1338,))

# %% [markdown]
# ### Exercise 1:
# * Train a linear regressor (with or without polynomial features).
# * Try to get the best $R^2$ score with $K=50$ fold cross-validation.
# * Hint: Consider using $L^1$ regularization (lasso).

# %%
from sklearn.preprocessing   import PolynomialFeatures
from sklearn.model_selection import cross_val_predict, KFold
from sklearn.metrics         import r2_score
from sklearn.linear_model    import LinearRegression

#-- Cross validation regression:
dRes   = pd.DataFrame(columns=['P', 'R2'])
for P in [1, 2, 3]:
    mPhi                = PolynomialFeatures(P, include_bias=False).fit_transform(mX)
    vHatY               = cross_val_predict(LinearRegression(), mPhi, vY, cv=KFold(50, shuffle=True))
    dRes.loc[len(dRes)] = [P, r2_score(vY, vHatY)]

dRes.sort_values(by='R2', ascending=False)
# Out:
#      P        R2
# 2  3.0  0.839459
# 1  2.0  0.839451
# 0  1.0  0.746455

# %%
from sklearn.linear_model import Lasso

#-- Cross validation regression with Lasso:
vLam = np.logspace(-2.5, 0, 15)
dRes = pd.DataFrame(columns=['P', 'lam', 'R2'])
for P in [1, 2, 3]:
    for lam in vLam:
        mPhi                = PolynomialFeatures(P, include_bias=False).fit_transform(mX)
        vHatY               = cross_val_predict(Lasso(alpha=lam, max_iter=10000), mPhi, vY, cv=KFold(50, shuffle=True))
        dRes.loc[len(dRes)] = [P, lam, r2_score(vY, vHatY)]

dRes.sort_values(by='R2', ascending=False)
# Out:
#       P       lam        R2
# 31  3.0  0.004771  0.841612
# 30  3.0  0.003162  0.841559
# 32  3.0  0.007197  0.841391
# 33  3.0  0.010857  0.841105
# 34  3.0  0.016379  0.840564
# 16  2.0  0.004771  0.840404
# 15  2.0  0.003162  0.840063
# 17  2.0  0.007197  0.839730
# 18  2.0  0.010857  0.839591
# 35  3.0  0.024709  0.839017
# 19  2.0  0.016379  0.838877
# 20  2.0  0.024709  0.836304
# 36  3.0  0.037276  0.835897
# 21  2.0  0.037276  0.831360
# 37  3.0  0.056234  0.829790
# 22  2.0  0.056234  0.824756
# 38  3.0  0.084834  0.818016
# 23  2.0  0.084834  0.811795
# 39  3.0  0.127980  0.809955
# 40  3.0  0.193070  0.795955
# 24  2.0  0.127980  0.781836
# 41  3.0  0.291263  0.764816
# 1   1.0  0.004771  0.747327
# 3   1.0  0.010857  0.747285
# 0   1.0  0.003162  0.747135
# 2   1.0  0.007197  0.747049
# 4   1.0  0.016379  0.746556
# 5   1.0  0.024709  0.745069
# 6   1.0  0.037276  0.741687
# 7   1.0  0.056234  0.736268
# 8   1.0  0.084834  0.725072
# 25  2.0  0.193070  0.718633
# 9   1.0  0.127980  0.698450
# 42  3.0  0.439397  0.693180
# 10  1.0  0.193070  0.642812
# 26  2.0  0.291263  0.598303
# 43  3.0  0.662870  0.573490
# 11  1.0  0.291263  0.545133
# 27  2.0  0.439397  0.527310
# 44  3.0  1.000000  0.516078
# 12  1.0  0.439397  0.423979
# 28  2.0  0.662870  0.412517
# 13  1.0  0.662870  0.175870
# 29  2.0  1.000000  0.148029
# 14  1.0  1.000000 -0.001476

# %% [markdown]
# ### Exercise 2:
# * Try non-parametric models.
# * Hint: Consider splitting your data into two subsets and train two regressors (one for each set).
# * Improve your $R^2$ score from exercise 1.

# %% [markdown]
# #### Regressor tree:

# %%
from sklearn.tree import DecisionTreeRegressor

vHatY = cross_val_predict(DecisionTreeRegressor(max_leaf_nodes=11), mX, vY, cv=KFold(len(vY), shuffle=True))
print(f'Tree = {r2_score(vY, vHatY)}')
# Out:
# Tree = 0.8438097797190999

# %% [markdown]
# ### Split on smokers:
# `DualRegressor` trains a tree on the smokers and Lasso on the non-smokers:

# %%
from sklearn.base import BaseEstimator

class DualRegressor(BaseEstimator):
    def __init__(self, dTreeArg, dLassoArg):
        self.oTree      = DecisionTreeRegressor(**dTreeArg)
        self.oLasso     = Lasso(**dLassoArg)
        
        self.smokerIdx  = 4
        self.dTreeArg   = dTreeArg
        self.dLassoArg  = dLassoArg
        
    def fit(self, mX, vY):
        vIdx = mX[:,self.smokerIdx] > 0
        mX1  = mX[vIdx, :]
        mX2  = mX[~vIdx,:]
        vY1  = vY[vIdx]
        vY2  = vY[~vIdx]

        self.oTree .fit(mX1, vY1)
        self.oLasso.fit(mX2, vY2)
        
    def predict(self, mX):
        vIdx = mX[:,self.smokerIdx] > 0
        mX1  = mX[vIdx, :]
        mX2  = mX[~vIdx,:]
        
        vHatY1 = None
        vHatY2 = None
        if mX1.shape[0] > 0:
            vHatY1       = self.oTree .predict(mX1)
        if mX2.shape[0] > 0:
            vHatY2       = self.oLasso.predict(mX2)
        vHatY        = np.zeros(mX.shape[0])
        vHatY[vIdx]  = vHatY1
        vHatY[~vIdx] = vHatY2
        return vHatY
    
    def get_params(self, deep=True):
        return {'dTreeArg': self.dTreeArg, 'dLassoArg': self.dLassoArg}

# %%
dTreeArg  = {'max_leaf_nodes':11, 'random_state':0}
dLassoArg = {'alpha':0.010,       'max_iter':1000}
oReg      = DualRegressor(dTreeArg, dLassoArg)
vHatY     = cross_val_predict(oReg, mX, vY, cv=KFold(len(vY), shuffle=True))
print(f'Dual = {r2_score(vY, vHatY)}')
# Out:
# Dual = 0.8531773120840362

# %% [markdown]
# ### Gradient boosting:
# We did not learn this (yet)

# %%
from sklearn.ensemble import GradientBoostingRegressor

vHatY = cross_val_predict(GradientBoostingRegressor(n_estimators=100, learning_rate=0.05), dTrainX, dTrainY, cv=KFold(50, shuffle=True))
print(f'GBR = {r2_score(vY, vHatY)}')
# Out:
# GBR = 0.8625390631642986
