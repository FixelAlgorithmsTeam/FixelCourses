# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Exercise 0 - Iris classification</center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/Exercises/MainClassificationExercise00_Iris.ipynb)

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import seaborn           as sns
import matplotlib
matplotlib.rc('font', **{'size':16})

# %% [markdown]
# #### Load Iris data:

# %%
from sklearn import datasets

dIrisData         = datasets.load_iris(as_frame=True)
vY                = dIrisData['target']
dIris             = dIrisData['data']
dIris['Species']  = dIrisData['target_names'][vY]
dIris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        Species
# 0       setosa
# ...

# %%
dIris['Species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ![Iris](https://www.pngkey.com/png/full/82-826789_iris-iris-sepal-and-petal.png)
# Image from: https://www.pngkey.com/

# %% [markdown]
# #### Display basic information (useful to count NaNs in the data):

# %%
dIris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Species            150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# #### Basic statistics:

# %%
dIris.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# #### Count by target (species):

# %%
display(dIris.groupby('Species').size())

dIris['Species'].value_counts().plot(kind='bar', figsize=(5, 5), title='Count species', rot=-10)
plt.show()
# Out:
# Species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# #### Pair plot:

# %%
sns.pairplot(dIris, hue="Species", diag_kind='hist', plot_kws={'s':50, 'edgecolor':'k'})
plt.show()

# %% [markdown]
# ### Prepare data for training:

# %%
dTrain = dIris.drop(columns='Species')
display(dTrain), vY
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# (None,
# ...

# %% [markdown]
# ### Exercise:
# * Get the best leave one out cross validation accuracy on the Iris data (KFolds = 150).
# * You can use everything we learned by now.
