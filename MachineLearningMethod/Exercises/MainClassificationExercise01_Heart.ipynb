# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Exercise 1 - Hearth disease classification</center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/Exercises/MainHeart_01.ipynb)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import numpy             as np
import pandas            as pd
import seaborn           as sns
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})
# np.random.seed(1)

# %% [markdown]
# ### Load the dataset:
# https://www.kaggle.com/ronitf/heart-disease-uci

# %%
dData = pd.read_csv('heart.csv')
dData
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ### Rename columns:

# %%
dData.columns = ['Age', 'Sex', 'ChestPainType', 'RestingBloodPressure', 'Cholesterol', 'FastingBloodSugar', 'RestECG', 'MaxHeartRateAchieved',
                 'ExerciseInducedAngina', 'StDepression', 'StSlope', 'NumMajorVessels', 'Thalassemia', 'Target']
dData
# Out:
#      Age  Sex  ChestPainType  RestingBloodPressure  Cholesterol  \
# 0     63    1              3                   145          233
# 1     37    1              2                   130          250
# 2     41    0              1                   130          204
# 3     56    1              1                   120          236
# 4     57    0              0                   120          354
# ..   ...  ...            ...                   ...          ...
# 298   57    0              0                   140          241
# 299   45    1              3                   110          264
# 300   68    1              0                   144          193
# 301   57    1              0                   130          131
# 302   57    0              1                   130          236
#
#      FastingBloodSugar  RestECG  MaxHeartRateAchieved  ExerciseInducedAngina  \
# 0                    1        0                   150                      0
# 1                    0        1                   187                      0
# 2                    0        0                   172                      0
# 3                    0        1                   178                      0
# 4                    0        1                   163                      1
# ..                 ...      ...                   ...                    ...
# 298                  0        1                   123                      1
# 299                  0        1                   132                      0
# 300                  1        1                   141                      0
# 301                  0        1                   115                      1
# 302                  0        0                   174                      0
#
#      StDepression  StSlope  NumMajorVessels  Thalassemia  Target
# 0             2.3        0                0            1       1
# 1             3.5        0                0            2       1
# 2             1.4        2                0            2       1
# 3             0.8        2                0            2       1
# 4             0.6        2                0            2       1
# ..            ...      ...              ...          ...     ...
# 298           0.2        1                0            3       0
# 299           1.2        1                0            3       0
# 300           3.4        1                2            3       0
# 301           1.2        1                1            3       0
# 302           0.0        1                1            2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# ### Meaningful categorical data:
# (Based on the data description)

# %%
dData.loc[dData['Sex']                   == 0, 'Sex']                   = 'female'
dData.loc[dData['Sex']                   == 1, 'Sex']                   = 'male'
        
dData.loc[dData['ChestPainType']         == 1, 'ChestPainType']         = 'typical angina'
dData.loc[dData['ChestPainType']         == 2, 'ChestPainType']         = 'atypical angina'
dData.loc[dData['ChestPainType']         == 3, 'ChestPainType']         = 'non-anginal pain'
dData.loc[dData['ChestPainType']         == 4, 'ChestPainType']         = 'asymptomatic'

dData.loc[dData['FastingBloodSugar']     == 0, 'FastingBloodSugar']     = 'lower than 120mg/ml'
dData.loc[dData['FastingBloodSugar']     == 1, 'FastingBloodSugar']     = 'greater than 120mg/ml'

dData.loc[dData['RestECG']               == 0, 'RestECG']               = 'normal'
dData.loc[dData['RestECG']               == 1, 'RestECG']               = 'ST-T wave abnormality'
dData.loc[dData['RestECG']               == 2, 'RestECG']               = 'left ventricular hypertrophy'

dData.loc[dData['ExerciseInducedAngina'] == 0, 'ExerciseInducedAngina'] = 'no'
dData.loc[dData['ExerciseInducedAngina'] == 1, 'ExerciseInducedAngina'] = 'yes'

dData.loc[dData['StSlope']               == 1, 'StSlope']               = 'upsloping'
dData.loc[dData['StSlope']               == 2, 'StSlope']               = 'flat'
dData.loc[dData['StSlope']               == 3, 'StSlope']               = 'downsloping'

dData.loc[dData['Thalassemia']           == 1, 'Thalassemia']            = 'normal'
dData.loc[dData['Thalassemia']           == 2, 'Thalassemia']            = 'fixed defect'
dData.loc[dData['Thalassemia']           == 3, 'Thalassemia']            = 'reversable defect'

dData.loc[dData['Target']                == 0, 'Target']                 = 'hearth disease'
dData.loc[dData['Target']                == 1, 'Target']                 = 'no hearth disease'
dData
# Out:
#      Age     Sex     ChestPainType  RestingBloodPressure  Cholesterol  \
# 0     63    male  non-anginal pain                   145          233
# 1     37    male   atypical angina                   130          250
# 2     41  female    typical angina                   130          204
# 3     56    male    typical angina                   120          236
# 4     57  female                 0                   120          354
# ..   ...     ...               ...                   ...          ...
# 298   57  female                 0                   140          241
# 299   45    male  non-anginal pain                   110          264
# 300   68    male                 0                   144          193
# 301   57    male                 0                   130          131
# 302   57  female    typical angina                   130          236
#
#          FastingBloodSugar                RestECG  MaxHeartRateAchieved  \
# 0    greater than 120mg/ml                 normal                   150
# 1      lower than 120mg/ml  ST-T wave abnormality                   187
# 2      lower than 120mg/ml                 normal                   172
# 3      lower than 120mg/ml  ST-T wave abnormality                   178
# 4      lower than 120mg/ml  ST-T wave abnormality                   163
# ..                     ...                    ...                   ...
# 298    lower than 120mg/ml  ST-T wave abnormality                   123
# 299    lower than 120mg/ml  ST-T wave abnormality                   132
# 300  greater than 120mg/ml  ST-T wave abnormality                   141
# 301    lower than 120mg/ml  ST-T wave abnormality                   115
# 302    lower than 120mg/ml                 normal                   174
#
#     ExerciseInducedAngina  StDepression    StSlope  NumMajorVessels  \
# 0                      no           2.3          0                0
# 1                      no           3.5          0                0
# 2                      no           1.4       flat                0
# 3                      no           0.8       flat                0
# 4                     yes           0.6       flat                0
# ..                    ...           ...        ...              ...
# 298                   yes           0.2  upsloping                0
# 299                    no           1.2  upsloping                0
# 300                    no           3.4  upsloping                2
# 301                   yes           1.2  upsloping                1
# 302                    no           0.0  upsloping                1
#
#            Thalassemia             Target
# 0               normal  no hearth disease
# 1         fixed defect  no hearth disease
# 2         fixed defect  no hearth disease
# 3         fixed defect  no hearth disease
# 4         fixed defect  no hearth disease
# ..                 ...                ...
# 298  reversable defect     hearth disease
# 299  reversable defect     hearth disease
# 300  reversable defect     hearth disease
# 301  reversable defect     hearth disease
# 302       fixed defect     hearth disease
#
# [303 rows x 14 columns]

# %%
dData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    303 non-null    int64
#  1   Sex                    303 non-null    object
#  2   ChestPainType          303 non-null    object
#  3   RestingBloodPressure   303 non-null    int64
#  4   Cholesterol            303 non-null    int64
#  5   FastingBloodSugar      303 non-null    object
#  6   RestECG                303 non-null    object
#  7   MaxHeartRateAchieved   303 non-null    int64
#  8   ExerciseInducedAngina  303 non-null    object
#  9   StDepression           303 non-null    float64
#  10  StSlope                303 non-null    object
#  11  NumMajorVessels        303 non-null    int64
#  12  Thalassemia            303 non-null    object
#  13  Target                 303 non-null    object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 33.3+ KB

# %% [markdown]
# ### Pair plot:

# %%
dDataToPlot           = dData.select_dtypes(include=['number'])
dDataToPlot['Target'] = dData['Target'];
sns.pairplot(dDataToPlot, hue='Target', diag_kind='hist', plot_kws={'s':50, 'edgecolor':'k'})
plt.show()
# Out:
# C:\Users\Or\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dCorr = dDataToPlot.corr()
dCorr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col0,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col1,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col2,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col3,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col4,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col1{
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col2{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col3,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col0,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col1,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col2,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col4,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col4{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col5{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col2,#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col3{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col3{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col4{
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col5{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col0{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col1{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col3{
#             background-color:  #97b8ff;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col4{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col0{
#             background-color:  #cbd8ee;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col1{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col2{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col3{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col5{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col0{
#             background-color:  #d8dce2;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col1{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col2{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b634397a_f7f1_11ea_906a_e8de277b53c7row5_col4{
#             background-color:  #c6d6f1;
#             color:  #000000;
#         }</style><table id="T_b634397a_f7f1_11ea_906a_e8de277b53c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Age</th>        <th class="col_heading level0 col1" >RestingBloodPressure</th>        <th class="col_heading level0 col2" >Cholesterol</th>        <th class="col_heading level0 col3" >MaxHeartRateAchieved</th>        <th class="col_heading level0 col4" >StDepression</th>        <th class="col_heading level0 col5" >NumMajorVessels</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b634397a_f7f1_11ea_906a_e8de277b53c7level0_row0" class="row_heading level0 row0" >Age</th>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col1" class="data row0 col1" >0.28</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col2" class="data row0 col2" >0.21</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col3" class="data row0 col3" >-0.40</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col4" class="data row0 col4" >0.21</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row0_col5" class="data row0 col5" >0.28</td>
#             </tr>
#             <tr>
#                         <th id="T_b634397a_f7f1_11ea_906a_e8de277b53c7level0_row1" class="row_heading level0 row1" >RestingBloodPressure</th>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col0" class="data row1 col0" >0.28</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col2" class="data row1 col2" >0.12</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col3" class="data row1 col3" >-0.05</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col4" class="data row1 col4" >0.19</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row1_col5" class="data row1 col5" >0.10</td>
#             </tr>
#             <tr>
#                         <th id="T_b634397a_f7f1_11ea_906a_e8de277b53c7level0_row2" class="row_heading level0 row2" >Cholesterol</th>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col0" class="data row2 col0" >0.21</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col1" class="data row2 col1" >0.12</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col3" class="data row2 col3" >-0.01</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col4" class="data row2 col4" >0.05</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row2_col5" class="data row2 col5" >0.07</td>
#             </tr>
#             <tr>
#                         <th id="T_b634397a_f7f1_11ea_906a_e8de277b53c7level0_row3" class="row_heading level0 row3" >MaxHeartRateAchieved</th>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col0" class="data row3 col0" >-0.40</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col1" class="data row3 col1" >-0.05</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col2" class="data row3 col2" >-0.01</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col4" class="data row3 col4" >-0.34</td>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row3_col5" class="data row3 col5" >-0.21</td>
#             </tr>
#             <tr>
#                         <th id="T_b634397a_f7f1_11ea_906a_e8de277b53c7level0_row4" class="row_heading level0 row4" >StDepression</th>
#                         <td id="T_b634397a_f7f1_11ea_906a_e8de277b53c7row4_col0" class="data row4 col0" >0.21<

# %% [markdown]
# ### Categorical to dummy

# %%
dData = pd.get_dummies(dData, drop_first=True)
dData
# Out:
#      Age  RestingBloodPressure  Cholesterol  MaxHeartRateAchieved  \
# 0     63                   145          233                   150
# 1     37                   130          250                   187
# 2     41                   130          204                   172
# 3     56                   120          236                   178
# 4     57                   120          354                   163
# ..   ...                   ...          ...                   ...
# 298   57                   140          241                   123
# 299   45                   110          264                   132
# 300   68                   144          193                   141
# 301   57                   130          131                   115
# 302   57                   130          236                   174
#
#      StDepression  NumMajorVessels  Sex_male  ChestPainType_atypical angina  \
# 0             2.3                0         1                              0
# 1             3.5                0         1                              1
# 2             1.4                0         0                              0
# 3             0.8                0         1                              0
# 4             0.6                0         0                              0
# ..            ...              ...       ...                            ...
# 298           0.2                0         0                              0
# 299           1.2                0         1                              0
# 300           3.4                2         1                              0
# 301           1.2                1         1                              0
# 302           0.0                1         0                              0
#
#      ChestPainType_non-anginal pain  ChestPainType_typical angina  \
# 0                                 1                             0
# 1                                 0                             0
# 2                                 0                             1
# 3                                 0                             1
# 4                                 0                             0
# ..                              ...                           ...
# 298                               0                             0
# 299                               1                             0
# 300                               0                             0
# 301                               0                             0
# 302                               0                             1
#
#      FastingBloodSugar_lower than 120mg/ml  \
# 0                                        0
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        1
# ..                                     ...
# 298                                      1
# 299                                      1
# 300                                      0
# 301                                      1
# 302                                      1
#
#      RestECG_left ventricular hypertrophy  RestECG_normal  \
# 0                                       0               1
# 1                                       0               0
# 2                                       0               1
# 3                                       0               0
# 4                                       0               0
# ..                                    ...             ...
# 298                                     0               0
# 299                                     0               0
# 300                                     0               0
# 301                                     0               0
# 302                                     0               1
#
#      ExerciseInducedAngina_yes  StSlope_flat  StSlope_upsloping  \
# 0                            0             0                  0
# 1                            0             0                  0
# 2                            0             1                  0
# 3                            0             1                  0
# 4                            1             1                  0
# ..                         ...           ...                ...
# 298                          1             0                  1
# 299                          0             0                  1
# 300                          0             0                  1
# 301                          1             0                  1
# 302                          0             0                  1
#
#      Thalassemia_fixed defect  Thalassemia_normal  \
# 0                           0                   1
# 1                           1                   0
# 2                           1                   0
# 3                           1                   0
# 4                           1                   0
# ..                        ...                 ...
# 298                         0                   0
# 299                         0                   0
# 300                         0                   0
# 301                         0                   0
# 302                         1                   0
#
#      Thalassemia_reversable defect  Target_no hearth disease
# 0                                0                         1
# 1                                0                         1
# 2                                0                         1
# 3                                0                         1
# 4                                0                         1
# ..                             ...                       ...
# 298                              1                         0
# 299                              1                         0
# 300                              1                         0
# 301                              1                         0
# 302                              0                         0
#
# [303 rows x 20 columns]

# %%
dCorr = dData.corr()
dCorr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col0,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col1,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row2_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row3_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row5_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row7_col7,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row8_col8,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col10,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col11,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row12_col12,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row13_col13,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col14,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row15_col15,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row16_col16,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row17_col17,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row18_col18,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col19{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col1{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row12_col5{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col11{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col15{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col10,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col1{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col7,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col19,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row15_col1,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col10{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col8,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col14,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col10,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row17_col9{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col1,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row8_col10,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col13{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col10{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col11,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row11_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row17_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row17_col8{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col12,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col11{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col13,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row2_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row7_col18{
#             background-color:  #b7cff9;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col14,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col15,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row12_col13,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row17_col18{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col15{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col16,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col16{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col17,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row5_col17,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row13_col17,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row15_col6{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row0_col18,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col18{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col0,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row5_col4{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col16,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row12_col1,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col6{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col7{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row13_col0{
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row8_col5{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col7,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col5{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col8,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row2_col12,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col16{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col7{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_b6452802_f7f1_11ea_a519_e8de277b53c7row1_col10,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row3_col0,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row3_col11,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row4_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row6_col2,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row7_col8,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row7_col9,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row9_col7,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row10_col1,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col4,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row14_col15,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row15_col3,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row15_col14,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row16_col6,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row16_col17,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row16_col18,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row18_col16,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row18_col19,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col5,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col12,#T_b6452802_f7f1_11ea_a519_e8de277b53c7row19_col13{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b645280

# %% [markdown]
# ### Same correlation plot but with SNS:

# %%
fig, ax = plt.subplots(figsize=(16,16))
sns.heatmap(dData.corr(method='pearson'), annot=True, fmt='.2f', cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax)
ax.set_yticklabels(ax.get_yticklabels(), rotation="horizontal")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Display data balance:

# %%
display(dData['Target_no hearth disease'].value_counts())
dData['Target_no hearth disease'].value_counts().plot(kind='bar', figsize=(5, 5), title='Count hearth disease', rot=0)
plt.show()
# Out:
# 1    165
# 0    138
# Name: Target_no hearth disease, dtype: int64

# %% [markdown]
# ### Split to features and labels:

# %%
dTrain = dData.drop(columns='Target_no hearth disease')
dY     = dData['Target_no hearth disease']

dTrain.describe()
# Out:
#               Age  RestingBloodPressure  Cholesterol  MaxHeartRateAchieved  \
# count  303.000000            303.000000   303.000000            303.000000
# mean    54.366337            131.623762   246.264026            149.646865
# std      9.082101             17.538143    51.830751             22.905161
# min     29.000000             94.000000   126.000000             71.000000
# 25%     47.500000            120.000000   211.000000            133.500000
# 50%     55.000000            130.000000   240.000000            153.000000
# 75%     61.000000            140.000000   274.500000            166.000000
# max     77.000000            200.000000   564.000000            202.000000
#
#        StDepression  NumMajorVessels    Sex_male  \
# count    303.000000       303.000000  303.000000
# mean       1.039604         0.729373    0.683168
# std        1.161075         1.022606    0.466011
# min        0.000000         0.000000    0.000000
# 25%        0.000000         0.000000    0.000000
# 50%        0.800000         0.000000    1.000000
# 75%        1.600000         1.000000    1.000000
# max        6.200000         4.000000    1.000000
#
#        ChestPainType_atypical angina  ChestPainType_non-anginal pain  \
# count                     303.000000                      303.000000
# mean                        0.287129                        0.075908
# std                         0.453171                        0.265288
# min                         0.000000                        0.000000
# 25%                         0.000000                        0.000000
# 50%                         0.000000                        0.000000
# 75%                         1.000000                        0.000000
# max                         1.000000                        1.000000
#
#        ChestPainType_typical angina  FastingBloodSugar_lower than 120mg/ml  \
# count                    303.000000                             303.000000
# mean                       0.165017                               0.851485
# std                        0.371809                               0.356198
# min                        0.000000                               0.000000
# 25%                        0.000000                               1.000000
# 50%                        0.000000                               1.000000
# 75%                        0.000000                               1.000000
# max                        1.000000                               1.000000
#
#        RestECG_left ventricular hypertrophy  RestECG_normal  \
# count                            303.000000      303.000000
# mean                               0.013201        0.485149
# std                                0.114325        0.500606
# min                                0.000000        0.000000
# 25%                                0.000000        0.000000
# 50%                                0.000000        0.000000
# 75%                                0.000000        1.000000
# max                                1.000000        1.000000
#
#        ExerciseInducedAngina_yes  StSlope_flat  StSlope_upsloping  \
# count                 303.000000    303.000000         303.000000
# mean                    0.326733      0.468647           0.462046
# std                     0.469794      0.499842           0.499382
# min                     0.000000      0.000000           0.000000
# 25%                     0.000000      0.000000           0.000000
# 50%                     0.000000      0.000000           0.000000
# 75%                     1.000000      1.000000           1.000000
# max                     1.000000      1.000000           1.000000
#
#        Thalassemia_fixed defect  Thalassemia_normal  \
# count                303.000000          303.000000
# mean                   0.547855            0.059406
# std                    0.498528            0.236774
# min                    0.000000            0.000000
# 25%                    0.000000            0.000000
# 50%                    1.000000            0.000000
# 75%                    1.000000            0.000000
# max                    1.000000            1.000000
#
#        Thalassemia_reversable defect
# count                     303.000000
# mean                        0.386139
# std                         0.487668
# min                         0.000000
# 25%                         0.000000
# 50%                         0.000000
# 75%                         1.000000
# max                         1.000000

# %% [markdown]
# ### Normalize the data

# %%
from sklearn import preprocessing

mX     = preprocessing.StandardScaler().fit_transform(dTrain)
dTrain = pd.DataFrame(mX, columns=dTrain.columns)
dTrain.describe()
# Out:
#                 Age  RestingBloodPressure   Cholesterol  MaxHeartRateAchieved  \
# count  3.030000e+02          3.030000e+02  3.030000e+02          3.030000e+02
# mean   5.825923e-17         -7.146832e-16 -9.828955e-17         -5.203025e-16
# std    1.001654e+00          1.001654e+00  1.001654e+00          1.001654e+00
# min   -2.797624e+00         -2.148802e+00 -2.324160e+00         -3.439267e+00
# 25%   -7.572802e-01         -6.638668e-01 -6.814943e-01         -7.061105e-01
# 50%    6.988599e-02         -9.273778e-02 -1.210553e-01          1.466343e-01
# 75%    7.316189e-01          4.783913e-01  5.456738e-01          7.151309e-01
# max    2.496240e+00          3.905165e+00  6.140401e+00          2.289429e+00
#
#        StDepression  NumMajorVessels      Sex_male  \
# count  3.030000e+02     3.030000e+02  3.030000e+02
# mean  -3.140136e-16     4.752341e-16 -1.319077e-17
# std    1.001654e+00     1.001654e+00  1.001654e+00
# min   -8.968617e-01    -7.144289e-01 -1.468418e+00
# 25%   -8.968617e-01    -7.144289e-01 -1.468418e+00
# 50%   -2.067053e-01    -7.144289e-01  6.810052e-01
# 75%    4.834512e-01     2.650822e-01  6.810052e-01
# max    4.451851e+00     3.203615e+00  6.810052e-01
#
#        ChestPainType_atypical angina  ChestPainType_non-anginal pain  \
# count                   3.030000e+02                    3.030000e+02
# mean                    3.341661e-16                    1.183505e-16
# std                     1.001654e+00                    1.001654e+00
# min                    -6.346478e-01                   -2.866058e-01
# 25%                    -6.346478e-01                   -2.866058e-01
# 50%                    -6.346478e-01                   -2.866058e-01
# 75%                     1.575677e+00                   -2.866058e-01
# max                     1.575677e+00                    3.489114e+00
#
#        ChestPainType_typical angina  FastingBloodSugar_lower than 120mg/ml  \
# count                  3.030000e+02                           3.030000e+02
# mean                  -3.297692e-16                           3.444256e-17
# std                    1.001654e+00                           1.001654e+00
# min                   -4.445542e-01                          -2.394438e+00
# 25%                   -4.445542e-01                           4.176345e-01
# 50%                   -4.445542e-01                           4.176345e-01
# 75%                   -4.445542e-01                           4.176345e-01
# max                    2.249444e+00                           4.176345e-01
#
#        RestECG_left ventricular hypertrophy  RestECG_normal  \
# count                          3.030000e+02    3.030000e+02
# mean                           8.143468e-17    1.634190e-16
# std                            1.001654e+00    1.001654e+00
# min                           -1.156630e-01   -9.707253e-01
# 25%                           -1.156630e-01   -9.707253e-01
# 50%                           -1.156630e-01   -9.707253e-01
# 75%                           -1.156630e-01    1.030158e+00
# max                            8.645808e+00    1.030158e+00
#
#        ExerciseInducedAngina_yes  StSlope_flat  StSlope_upsloping  \
# count               3.030000e+02  3.030000e+02       3.030000e+02
# mean               -5.203025e-16  2.147164e-16      -8.896441e-16
# std                 1.001654e+00  1.001654e+00       1.001654e+00
# min                -6.966305e-01 -9.391419e-01      -9.267663e-01
# 25%                -6.966305e-01 -9.391419e-01      -9.267663e-01
# 50%                -6.966305e-01 -9.391419e-01      -9.267663e-01
# 75%                 1.435481e+00  1.064802e+00       1.079021e+00
# max                 1.435481e+00  1.064802e+00       1.079021e+00
#
#        Thalassemia_fixed defect  Thalassemia_normal  \
# count              3.030000e+02        3.030000e+02
# mean               6.020120e-16       -1.282436e-17
# std                1.001654e+00        1.001654e+00
# min               -1.100763e+00       -2.513123e-01
# 25%               -1.100763e+00       -2.513123e-01
# 50%                9.084609e-01       -2.513123e-01
# 75%                9.084609e-01       -2.513123e-01
# max                9.084609e-01        3.979112e+00
#
#        Thalassemia_reversable defect
# count                   3.030000e+02
# mean                    4.125779e-16
# std                     1.001654e+00
# min                    -7.931155e-01
# 25%                    -7.931155e-01
# 50%                    -7.931155e-01
# 75%                     1.260850e+00
# max                     1.260850e+00

# %% [markdown]
# ### Train a linear SVM:

# %%
from sklearn.svm             import SVC
from sklearn.model_selection import cross_val_score, KFold

dRes = pd.DataFrame(columns=['C', 'Accuracy'])

for C in np.linspace(1e-3, 5, 20):
    oSVM                = SVC(kernel='linear', C=C)
    vAccuracy           = cross_val_score(oSVM, dTrain, dY, cv=KFold(20, shuffle=True))
    dRes.loc[len(dRes)] = [C, vAccuracy.mean()]

dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#            C  Accuracy
# 2   0.527211  0.842083
# 12  3.158263  0.838542
# 6   1.579632  0.835208
# 16  4.210684  0.828958
# 15  3.947579  0.827917
# 1   0.264105  0.827708
# 13  3.421368  0.825625
# 3   0.790316  0.825417
# 5   1.316526  0.825000
# 11  2.895158  0.824375
# 10  2.632053  0.822917
# 19  5.000000  0.822292
# 9   2.368947  0.821667
# 18  4.736895  0.821458
# 8   2.105842  0.821250
# 4   1.053421  0.821042
# 14  3.684474  0.819583
# 17  4.473789  0.818542
# 7   1.842737  0.818542
# 0   0.001000  0.816875

# %% [markdown]
# ### Train a kernel SVM (Gaussian kernel):

# %%
dRes = pd.DataFrame(columns=['C', 'σ', 'Accuracy'])

for C in np.linspace(25, 75, 10):
    for σ in np.linspace(8, 12, 10):
        oSVM                = SVC(kernel='rbf', C=C, gamma=1/(2*σ**2))
        vAccuracy           = cross_val_score(oSVM, dTrain, dY, cv=KFold(20, shuffle=True))
        dRes.loc[len(dRes)] = [C, σ, vAccuracy.mean()]
        
dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#             C          σ  Accuracy
# 55  52.777778  10.222222  0.862083
# 74  63.888889   9.777778  0.861042
# 97  75.000000  11.111111  0.855208
# 96  75.000000  10.666667  0.855208
# 10  30.555556   8.000000  0.855000
# ..        ...        ...       ...
# 84  69.444444   9.777778  0.818125
# 18  30.555556  11.555556  0.818125
# 34  41.666667   9.777778  0.817708
# 70  63.888889   8.000000  0.815208
# 90  75.000000   8.000000  0.808542
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Train a kernel SVM (polynomial kernel):

# %%
dRes = pd.DataFrame(columns=['C', 'P', 'Accuracy'])

for C in np.linspace(1e-6, 3, 20):
    for P in range(1, 5):
        oSVM                = SVC(kernel='poly', C=C, degree=P)
        vAccuracy           = cross_val_score(oSVM, dTrain, dY, cv=KFold(20, shuffle=True))
        dRes.loc[len(dRes)] = [C, P, vAccuracy.mean()]
        
dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#            C    P  Accuracy
# 78  3.000000  3.0  0.842917
# 60  2.368421  1.0  0.841042
# 4   0.157896  1.0  0.839167
# 58  2.210527  3.0  0.838542
# 32  1.263158  1.0  0.835625
# ..       ...  ...       ...
# 7   0.157896  4.0  0.580000
# 3   0.000001  4.0  0.545208
# 0   0.000001  1.0  0.545208
# 2   0.000001  3.0  0.545000
# 1   0.000001  2.0  0.544375
#
# [80 rows x 3 columns]

# %% [markdown]
# ### Train a K-NN classifier:

# %%
from sklearn.neighbors import KNeighborsClassifier

dRes = pd.DataFrame(columns=['K', 'Accuracy'])

for K in range(1, 15):
    oKnn                = KNeighborsClassifier(n_neighbors=K)
    vAccuracy           = cross_val_score(oKnn, dTrain, dY, cv=KFold(20, shuffle=True))
    dRes.loc[len(dRes)] = [K, vAccuracy.mean()]
    
dRes.sort_values(by='Accuracy', ascending=False)
# Out:
#        K  Accuracy
# 9   10.0  0.829167
# 10  11.0  0.827917
# 8    9.0  0.824792
# 11  12.0  0.821875
# 13  14.0  0.818958
# 6    7.0  0.818125
# 12  13.0  0.815417
# 5    6.0  0.812500
# 7    8.0  0.812083
# 4    5.0  0.808333
# 2    3.0  0.795833
# 1    2.0  0.772500
# 3    4.0  0.768750
# 0    1.0  0.745625

# %% [markdown]
# ### Take the best model and plot a confusion matrix (using cross validation):

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics         import confusion_matrix, ConfusionMatrixDisplay

oSVM            = SVC(kernel='rbf', C=75, gamma=1/(2*10.22**2))
vCrossValHatY   = cross_val_predict(oSVM, dTrain, dY, cv=KFold(100, shuffle=True))
mTrainConfusion = confusion_matrix(dY, vCrossValHatY)

_, ax = plt.subplots(figsize=(8, 7))
ConfusionMatrixDisplay(mTrainConfusion, display_labels=range(10)).plot(values_format='d', ax=ax)
plt.title('Train (cross validation) accuracy: ' + str(np.mean(dY == vCrossValHatY)))
plt.show()

# %% [markdown]
# ### Colab users should install ELI5 and SHAP with:
# `!pip install eli5`
# `!pip install shap`

# %% [markdown]
# ### ELI5 (Explain Like I'm Five):
# https://eli5.readthedocs.io/en/latest/index.html

# %%
import eli5

oSVM = SVC(kernel='linear', C=5).fit(dTrain, dY)
eli5.show_weights(oSVM, feature_names=dTrain.columns.tolist(), target_names=['hearth disease', 'no hearth disease'], )
# Out:
# C:\Users\Or\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# C:\Users\Or\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=no hearth disease
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.648
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_atypical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.35%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.499
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_fixed defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.473
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_non-anginal pain
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.300
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StSlope_flat
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.235
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         MaxHeartRateAchieved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.222
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 90.88%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.211
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_typical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.73%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.184
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 98.26%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.020
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Age
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cholesterol
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 100.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestECG_left ventricular hypertrophy
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 99.29%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.006
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StSlope_upsloping
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.27%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.059
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         FastingBloodSugar_lower than 120mg/ml
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 94.47%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.103
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_reversable defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 90.45%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.225
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestECG_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 90.01%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.241
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ExerciseInducedAngina_yes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.242
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestingBloodPressure
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.72%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.401
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Sex_male
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.11%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.467
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StDepression
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 81.95%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.560
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         NumMajorVessels
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ### Single prediction inspection:

# %%
dData.iloc[2]
# Out:
# Age                                       41.0
# RestingBloodPressure                     130.0
# Cholesterol                              204.0
# MaxHeartRateAchieved                     172.0
# StDepression                               1.4
# NumMajorVessels                            0.0
# Sex_male                                   0.0
# ChestPainType_atypical angina              0.0
# ChestPainType_non-anginal pain             0.0
# ChestPainType_typical angina               1.0
# FastingBloodSugar_lower than 120mg/ml      1.0
# RestECG_left ventricular hypertrophy       0.0
# RestECG_normal                             1.0
# ExerciseInducedAngina_yes                  0.0
# StSlope_flat                               1.0
# StSlope_upsloping                          0.0
# Thalassemia_fixed defect                   1.0
# Thalassemia_normal                         0.0
# Thalassemia_reversable defect              0.0
# Target_no hearth disease                   1.0
# Name: 2, dtype: float64

# %%
eli5.show_prediction(oSVM, dTrain.iloc[2], target_names=['hearth disease', 'no hearth disease'])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=no hearth disease
#
# </b>
#
#
#     (score <b>1.892</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.588
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Sex_male
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 82.79%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.475
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_typical angina
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 83.34%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.453
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_fixed defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 84.74%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.400
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         NumMajorVessels
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.96%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.319
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StSlope_flat
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.64%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.230
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         MaxHeartRateAchieved
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.184
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.168
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ExerciseInducedAngina_yes
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 94.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.082
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_reversable defect
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 97.97%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.022
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestingBloodPressure
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 99.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.005
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StSlope_upsloping
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 100.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestECG_left ventricular hypertrophy
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 99.93%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.000
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Cholesterol
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.83%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.025
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         FastingBloodSugar_lower than 120mg/ml
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 97.55%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.029
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Age
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 96.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.056
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Thalassemia_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.135
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_non-anginal pain
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 92.49%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.145
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         StDepression
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.57%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.232
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         RestECG_normal
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.43%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.411
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         ChestPainType_atypical angina
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# ### SHAP (SHapley Additive exPlanations):
# https://shap.readthedocs.io/en/latest/#

# %%
import shap

oExplainer  = shap.LinearExplainer(oSVM, dTrain)
mShapValues = oExplainer.shap_values(dTrain)
shap.summary_plot(mShapValues, dTrain)
