# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Lecture 17 - Non-parametric Clustering </center>
# ### <center> HDBSCAN </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/17_NonparametricClustering/MainHDBSCAN1.ipynb)

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib.cm
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# %%
mX = np.load('clusterable_data.npy')

plt.figure (figsize=(8, 8))
plt.scatter(mX[:,0], mX[:,1], s=50, color=[0,1,0], edgecolor='k')
plt.xlabel ('$x_1$')
plt.ylabel ('$x_2$')
plt.axis   ('equal')
plt.grid   ()
plt.show   ()

# %%
from hdbscan import HDBSCAN

oHDBSCAN = HDBSCAN(min_cluster_size=20, min_samples=5)
vC       = oHDBSCAN.fit_predict(mX)
np.unique(vC)
# Out:
# array([-1,  0,  1,  2,  3,  4,  5], dtype=int64)

# %%
Nc = len(np.unique(vC))

plt.figure(figsize=(9, 9))
plt.scatter(mX[:,0], mX[:,1], s=50, c=vC, edgecolor='k', cmap=matplotlib.cm.get_cmap('gist_rainbow', Nc))
plt.xlabel ('$x_1$')
plt.ylabel ('$x_2$')
plt.axis   ('equal')
plt.show   ()

# %% [markdown]
# ### Exercise
# * Use `sklearn.datasets.load_digits` to load the digits data.
# * Apply `HDBSCAN` to obtain 10 clusters.
# * Plot a few examples from each cluster,
# can you identify each cluster?

# %%
from sklearn.datasets import load_digits

mX, vY = load_digits(return_X_y=True)

mX.shape, vY.shape
# Out:
# ((1797, 64), (1797,))

# %%
N, d = mX.shape

fig, _ = plt.subplots(2, 10, figsize=(10, 2))
for ax in fig.axes:
    idx  = np.random.randint(N)
    mI   = np.reshape(mX[idx,:], (8, 8))
    
    ax.imshow    (mI, cmap='gray')
    ax.set_xticks([])
    ax.set_yticks([])

plt.tight_layout()

# %%
oHDBSCAN = HDBSCAN(???)
vC       = oHDBSCAN.fit_predict(mX)
np.unique(vC)
# Out:
#   File "<ipython-input-7-01600b7340d5>", line 1
#     oHDBSCAN = HDBSCAN(???)
#                        ^
# SyntaxError: invalid syntax

# %%
fig, mAxes = plt.subplots(10, 10, figsize=(10, 10))
for ii in range(10):
    mXi = mX[vC==ii,:]
    for jj in range(10):
        idx  = np.random.randint(mXi.shape[0])
        mI   = np.reshape(mXi[idx,:], (8, 8))
        
        ax   = mAxes[ii,jj]
        ax.imshow    (mI, cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])

plt.tight_layout()

# %%
# oHDBSCAN = HDBSCAN(min_cluster_siz=40, min_sample=5)
