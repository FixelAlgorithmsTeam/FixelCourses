# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Lecture 18 - Principal Component Analysis</center>
# ### <center> PCA - Solution </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/18_PCA/MainPCA_Solution.ipynb)

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# np.random.seed(2)

# %% [markdown]
# ### Exercise
# * Use the iris data: `load_iris`
# * Apply PCA to reduce the dimensionality from $4$ to $2$.
# * Plot a scatter plot of the low dimensional features (after the PCA) and color them according to the labels.

# %%
from sklearn.decomposition import PCA
from sklearn               import datasets

mX, vY = datasets.load_iris(return_X_y=True)
mX.shape, vY.shape
# Out:
# ((150, 4), (150,))

# %%
data = datasets.load_iris(as_frame=True)
dData = data.data
dData['target'] = data.target

# %%
dData
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
import seaborn as sns

sns.pairplot(dData, hue='target')

# %%
d     = 2
oPCA  = PCA(n_components=d).fit(mX)
mZ    = oPCA.transform(mX)
mZ.shape
# Out:
# (150, 2)

# %%
plt.figure(figsize=(8, 4))
plt.scatter(mZ[:,0], mZ[:,1], c=vY, s=100, edgecolor='k')
plt.xlabel('$z_1$')
plt.ylabel('$z_2$')
plt.axis  ('equal')
plt.show  ()

# %%
oPCA.explained_variance_ratio_, sum(oPCA.explained_variance_ratio_)
# Out:
# (array([0.92461872, 0.05306648]), 0.9776852063187949)

# %%
oPCA.noise_variance_
# Out:
# 0.05102229650818437
