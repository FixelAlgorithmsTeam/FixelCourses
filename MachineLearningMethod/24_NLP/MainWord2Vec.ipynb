# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Machine Learning Methods </center>
# ## <center> Lecture 24 - Introduction to NLP </center>
# ### <center> Wrod2Vec </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/MachineLearningMethod/24_NLP/MainWord2Vec.ipynb)

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc('font', **{'size' : 16})

# %% [markdown]
# ### Load IMDB Sentiment Analysis:
# https://www.kaggle.com/kaushik3497/imdb-sentiment-analysis

# %%
N     = 25000
dData = pd.read_csv('labeledTrainData.tsv', delimiter='\t')
dData = dData[:N]
dData
# Out:
#             id  sentiment                                             review
# 0       5814_8          1  With all this stuff going down at the moment w...
# 1       2381_9          1  \The Classic War of the Worlds\" by Timothy Hi...
# 2       7759_3          0  The film starts with a manager (Nicholas Bell)...
# 3       3630_4          0  It must be assumed that those who praised this...
# 4       9495_8          1  Superbly trashy and wondrously unpretentious 8...
# ...        ...        ...                                                ...
# 24995   3453_3          0  It seems like more consideration has gone into...
# 24996   5064_1          0  I don't believe they made this film. Completel...
# 24997  10905_3          0  Guy is a loser. Can't get girls, needs to buil...
# 24998  10194_3          0  This 30 minute documentary Buñuel made in the ...
# 24999   8478_8          1  I saw this movie as a child and it broke my he...
#
# [25000 rows x 3 columns]

# %% [markdown]
# ### Pre-processing:
# * Remove HTML stuff.
# * Remove punctuation and switch to lower case.

# %%
import re
from   bs4 import BeautifulSoup  

def PreprocessLine(text):
    
    text   = BeautifulSoup(text).get_text()                 #-- remove <br> and HTML
    lWords = re.sub("[^a-zA-Z]", " ", text).lower().split() #-- keep lower case letters
    
    return  lWords

# %% [markdown]
# ### Split text into lines:
# Using `tokenizer`

# %%
import nltk

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
sText     = dData['review'].values[9]
lLines    = tokenizer.tokenize(sText.strip())

print(sText)
print('=' * 120)
print('=' * 120)
lLines
# Out:
# <br /><br />This movie is full of references. Like \Mad Max II\", \"The wild one\" and many others. The ladybug´s face it´s a clear reference (or tribute) to Peter Lorre. This movie is a masterpiece. We´ll talk much more about in the future."
# ========================================================================================================================
# ========================================================================================================================
# ['<br /><br />This movie is full of references.',
#  'Like \\Mad Max II\\", \\"The wild one\\" and many others.',
#  'The ladybug´s face it´s a clear reference (or tribute) to Peter Lorre.',
#  'This movie is a masterpiece.',
#  'We´ll talk much more about in the future."']

# %% [markdown]
# ### Convert raw text to processed lines:

# %%
def Text2lines(sText):
    lRawLines = tokenizer.tokenize(sText.strip())
    lLines    = []
    
    for rawLine in lRawLines:
        if len(rawLine) > 0:
            lLines.append(PreprocessLine(rawLine))

    return lLines

# %%
lLines = []
for sText in dData['review'].values:
    lLines += Text2lines(sText)
# Out:
# C:\Users\Or\anaconda3\lib\site-packages\bs4\__init__.py:332: MarkupResemblesLocatorWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Or\anaconda3\lib\site-packages\bs4\__init__.py:332: MarkupResemblesLocatorWarning: "..." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(
# C:\Users\Or\anaconda3\lib\site-packages\bs4\__init__.py:417: MarkupResemblesLocatorWarning: "http://www.happierabroad.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   warnings.warn(

# %%
len(lLines)
# Out:
# 266885

# %% [markdown]
# ### Train Word2Vec model:
# Using `gensim`
# https://radimrehurek.com/gensim/index.html

# %%
from gensim.models import word2vec

d            = 300
minWordCount = 40
contextWin   = 5

oWord2Vec    = word2vec.Word2Vec(lLines, workers=4, vector_size=d, min_count=minWordCount, window=contextWin)
# Out:
# C:\Users\Or\anaconda3\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %% [markdown]
# #### Check vocabulary size:

# %%
len(oWord2Vec.wv.key_to_index)
# Out:
# 8306

# %%
oWord2Vec.wv.key_to_index
# Out:
# {'the': 0,
#  'and': 1,
#  'a': 2,
#  'of': 3,
#  'to': 4,
#  'is': 5,
#  'it': 6,
#  'in': 7,
#  'i': 8,
#  'this': 9,
#  'that': 10,
#  's': 11,
#  'was': 12,
#  'as': 13,
#  'for': 14,
#  'with': 15,
#  'movie': 16,
#  'but': 17,
#  'film': 18,
#  't': 19,
#  'you': 20,
#  'on': 21,
#  'not': 22,
#  'he': 23,
#  'are': 24,
#  'his': 25,
#  'have': 26,
#  'be': 27,
#  'one': 28,
#  'all': 29,
#  'at': 30,
#  'they': 31,
#  'by': 32,
#  'an': 33,
#  'who': 34,
#  'so': 35,
#  'from': 36,
#  'like': 37,
#  'there': 38,
#  'her': 39,
#  'or': 40,
#  'just': 41,
#  'about': 42,
#  'out': 43,
#  'if': 44,
#  'has': 45,
#  'what': 46,
#  'some': 47,
#  'good': 48,
#  'can': 49,
#  'more': 50,
#  'she': 51,
#  'when': 52,
#  'very': 53,
#  'up': 54,
#  'time': 55,
#  'no': 56,
#  'even': 57,
#  'my': 58,
#  'would': 59,
#  'which': 60,
#  'story': 61,
#  'only': 62,
#  'really': 63,
#  'see': 64,
#  'their': 65,
#  'had': 66,
#  'we': 67,
#  'were': 68,
#  'me': 69,
#  'well': 70,
#  'than': 71,
#  'much': 72,
#  'get': 73,
#  'bad': 74,
#  'been': 75,
#  'people': 76,
#  'will': 77,
#  'do': 78,
#  'other': 79,
#  'also': 80,
#  'into': 81,
#  'first': 82,
#  'great': 83,
#  'because': 84,
#  'how': 85,
#  'him': 86,
#  'don': 87,
#  'most': 88,
#  'made': 89,
#  'its': 90,
#  'then': 91,
#  'way': 92,
#  'make': 93,
#  'them': 94,
#  'could': 95,
#  'too': 96,
#  'movies': 97,
#  'any': 98,
#  'after': 99,
#  'think': 100,
#  'characters': 101,
#  'character': 102,
#  'watch': 103,
#  'two': 104,
#  'films': 105,
#  'seen': 106,
#  'many': 107,
#  'life': 108,
#  'being': 109,
#  'plot': 110,
#  'acting': 111,
#  'never': 112,
#  'love': 113,
#  'little': 114,
#  'best': 115,
#  'where': 116,
#  'over': 117,
#  'did': 118,
#  'show': 119,
#  'know': 120,
#  'off': 121,
#  'ever': 122,
#  'man': 123,
#  'does': 124,
#  'here': 125,
#  'better': 126,
#  'your': 127,
#  'end': 128,
#  'still': 129,
#  'these': 130,
#  'say': 131,
#  'scene': 132,
#  'why': 133,
#  'while': 134,
#  'scenes': 135,
#  've': 136,
#  'go': 137,
#  'such': 138,
#  'm': 139,
#  'something': 140,
#  'should': 141,
#  'back': 142,
#  'through': 143,
#  'real': 144,
#  'those': 145,
#  'watching': 146,
#  'now': 147,
#  're': 148,
#  'though': 149,
#  'doesn': 150,
#  'thing': 151,
#  'old': 152,
#  'years': 153,
#  'actors': 154,
#  'director': 155,
#  'work': 156,
#  'didn': 157,
#  'another': 158,
#  'before': 159,
#  'new': 160,
#  'nothing': 161,
#  'funny': 162,
#  'actually': 163,
#  'makes': 164,
#  'look': 165,
#  'find': 166,
#  'going': 167,
#  'few': 168,
#  'same': 169,
#  'part': 170,
#  'again': 171,
#  'lot': 172,
#  'every': 173,
#  'world': 174,
#  'cast': 175,
#  'us': 176,
#  'quite': 177,
#  'down': 178,
#  'want': 179,
#  'things': 180,
#  'pretty': 181,
#  'young': 182,
#  'seems': 183,
#  'around': 184,
#  'horror': 185,
#  'got': 186,
#  'however': 187,
#  'fact': 188,
#  'take': 189,
#  'big': 190,
#  'enough': 191,
#  'long': 192,
#  'thought': 193,
#  'series': 194,
#  'both': 195,
#  'between': 196,
#  'may': 197,
#  'original': 198,
#  'give': 199,
#  'd': 200,
#  'action': 201,
#  'own': 202,
#  'right': 203,
#  'without': 204,
#  'must': 205,
#  'comedy': 206,
#  'always': 207,
#  'times': 208,
#  'point': 209,
#  'gets': 210,
#  'family': 211,
#  'come': 212,
#  'role': 213,
#  'isn': 214,
#  'saw': 215,
#  'almost': 216,
#  'interesting': 217,
#  'least': 218,
#  'done': 219,
#  'whole': 220,
#  'music': 221,
#  'bit': 222,
#  'guy': 223,
#  'script': 224,
#  'far': 225,
#  'making': 226,
#  'minutes': 227,
#  'feel': 228,
#  'anything': 229,
#  'last': 230,
#  'might': 231,
#  'since': 232,
#  'll': 233,
#  'performance': 234,
#  'girl': 235,
#  'probably': 236,
#  'am': 237,
#  'woman': 238,
#  'kind': 239,
#  'tv': 240,
#  'away': 241,
#  'yet': 242,
#  'day': 243,
#  'rather': 244,
#  'worst': 245,
#  'fun': 246,
#  'sure': 247,
#  'hard': 248,
#  'anyone': 249,
#  'played': 250,
#  'each': 251,
#  'found': 252,
#  'having': 253,
#  'although': 254,
#  'especially': 255,
#  'our': 256,
#  'course': 257,
#  'believe': 258,
#  'screen': 259,
#  'comes': 260,
#  'looking': 261,
#  'trying': 262,
#  'set': 263,
#  'goes': 264,
#  'book': 265,
#  'looks': 266,
#  'place': 267,
#  'actor': 268,
#  'different': 269,
#  'put': 270,
#  'year': 271,
#  'money': 272,
#  'ending': 273,
#  'dvd': 274,
#  'let': 275,
#  'maybe': 276,
#  'someone': 277,
#  'true': 278,
#  'once': 279,
#  'sense': 280,
#  'reason': 281,
#  'everything': 282,
#  'wasn': 283,
#  'shows': 284,
#  'three': 285,
#  'worth': 286,
#  'job': 287,
#  'main': 288,
#  'together': 289,
#  'play': 290,
#  'watched': 291,
#  'american': 292,
#  'everyone': 293,
#  'plays': 294,
#  'john': 295,
#  'effects': 296,
#  'later': 297,
#  'audience': 298,
#  'said': 299,
#  'takes': 300,
#  'instead': 301,
#  'house': 302,
#  'beautiful': 303,
#  'seem': 304,
#  'night': 305,
#  'high': 306,
#  'himself': 307,
#  'version': 308,
#  'wife': 309,
#  'during': 310,
#  'left': 311,
#  'father': 312,
#  'special': 313,
#  'seeing': 314,
#  'half': 315,
#  'star': 316,
#  'excellent': 317,
#  'shot': 318,
#  'war': 319,
#  'idea': 320,
#  'black': 321,
#  'nice': 322,
#  'less': 323,
#  'else': 324,
#  'mind': 325,
#  'simply': 326,
#  'read': 327,
#  'second': 328,
#  'fan': 329,
#  'men': 330,
#  'death': 331,
#  'hollywood': 332,
#  'poor': 333,
#  'help': 334,
#  'completely': 335,
#  'dead': 336,
#  'used': 337,
#  'home': 338,
#  'line': 339,
#  'either': 340,
#  'short': 341,
#  'top': 342,
#  'given': 343,
#  'kids': 344,
#  'budget': 345,
#  'try': 346,
#  'classic': 347,
#  'performances': 348,
#  'wrong': 349,
#  'women': 350,
#  'enjoy': 351,
#  'boring': 352,
#  'need': 353,
#  'use': 354,
#  'rest': 355,
#  'low': 356,
#  'production': 357,
#  'friends': 358,
#  'full': 359,
#  'until': 360,
#  'camera': 361,
#  'along': 362,
#  'truly': 363,
#  'video': 364,
#  'awful': 365,
#  'couple': 366,
#  'tell': 367,
#  'next': 368,
#  'remember': 369,
#  'stupid': 370,
#  'start': 371,
#  'stars': 372,
#  'sex': 373,
#  'mean': 374,
#  'won': 375,
#  'perhaps': 376,
#  'came': 377,
#  'recommend': 378,
#  'moments': 379,
#  'school': 380,
#  'episode': 381,
#  'wonderful': 382,
#  'small': 383,
#  'face': 384,
#  'understand': 385,
#  'terrible': 386,
#  'playing': 387,
#  'getting': 388,
#  'written': 389,
#  'early': 390,
#  'name': 391,
#  'doing': 392,
#  'often': 393,
#  'style': 394,
#  'keep': 395,
#  'perfect': 396,
#  'human': 397,
#  'person': 398,
#  'others': 399,
#  'definitely': 400,
#  'gives': 401,
#  'itself': 402,
#  'boy': 403,
#  'lost': 404,
#  'live': 405,
#  'lines': 406,
#  'become': 407,
#  'dialogue': 408,
#  'head': 409,
#  'finally': 410,
#  'piece': 411,
#  'yes': 412,
#  'case': 413,
#  'felt': 414,
#  'mother': 415,
#  'supposed': 416,
#  'liked': 417,
#  'children': 418,
#  'couldn': 419,
#  'title': 420,
#  'white': 421,
#  'cinema': 422,
#  'absolutely': 423,
#  'picture': 424,
#  'against': 425,
#  'sort': 426,
#  'worse': 427,
#  'went': 428,
#  'certainly': 429,
#  'entire': 430,
#  'waste': 431,
#  'killer': 432,
#  'problem': 433,
#  'oh': 434,
#  'mr': 435,
#  'evil': 436,
#  'hope': 437,
#  'friend': 438,
#  'entertaining': 439,
#  'overall': 440,
#  'called': 441,
#  'based': 442,
#  'loved': 443,
#  'fans': 444,
#  'several': 445,
#  'drama': 446,
#  'beginning': 447,
#  'lives': 448,
#  'care': 449,
#  'already': 450,
#  'becomes': 451,
#  'dark': 452,
#  'laugh': 453,
#  'direction': 454,
#  'example': 455,
#  'under': 456,
#  'despite': 457,
#  'seemed': 458,
#  'throughout': 459,
#  'turn': 460,
#  'son': 461,
#  'unfortunately': 462,
#  'wanted': 463,
#  'michael': 464,
#  'history': 465,
#  'final': 466,
#  'heart': 467,
#  'fine': 468,
#  'sound': 469,
#  'b': 470,
#  'amazing': 471,
#  'child': 472,
#  'guess': 473,
#  'humor': 474,
#  'lead': 475,
#  'totally': 476,
#  'writing': 477,
#  'guys': 478,
#  'quality': 479,
#  'close': 480,
#  'art': 481,
#  'wants': 482,
#  'game': 483,
#  'behind': 484,
#  'town': 485,
#  'works': 486,
#  'side': 487,
#  'tries': 488,
#  'days': 489,
#  'past': 490,
#  'viewer': 491,
#  'able': 492,
#  'flick': 493,
#  'hand': 494,
#  'genre': 495,
#  'act': 496,
#  'turns': 497,
#  'enjoyed': 498,
#  'today': 499,
#  'kill': 500,
#  'favorite': 501,
#  'car': 502,
#  'soon': 503,
#  'starts': 504,
#  'actress': 505,
#  'sometimes': 506,
#  'run': 507,
#  'eyes': 508,
#  'gave': 509,
#  'etc': 510,
#  'girls': 511,
#  'late': 512,
#  'god': 513,
#  'directed': 514,
#  'horrible': 515,
#  'kid': 516,
#  'city': 517,
#  'brilliant': 518,
#  'parts': 519,
#  'hour': 520,
#  'self': 521,
#  'blood': 522,
#  'themselves': 523,
#  'stories': 524,
#  'thinking': 525,
#  'expect': 526,
#  'stuff': 527,
#  'obviously': 528,
#  'decent': 529,
#  'voice': 530,
#  'writer': 531,
#  'fight': 532,
#  'highly': 533,
#  'myself': 534,
#  'feeling': 535,
#  'daughter': 536,
#  'slow': 537,
#  'except': 538,
#  'matter': 539,
#  'type': 540,
#  'age': 541,
#  'anyway': 542,
#  'roles': 543,
#  'moment': 544,
#  'killed': 545,
#  'heard': 546,
#  'says': 547,
#  'leave': 548,
#  'brother': 549,
#  'took': 550,
#  'police': 551,
#  'strong': 552,
#  'cannot': 553,
#  'violence': 554,
#  'hit': 555,
#  'stop': 556,
#  'known': 557,
#  'happens': 558,
#  'particularly': 559,
#  'involved': 560,
#  'happened': 561,
#  'extremely': 562,
#  'james': 563,
#  'chance': 564,
#  'obvious': 565,
#  'murder': 566,
#  'told': 567,
#  'living': 568,
#  'coming': 569,
#  'alone': 570,
#  'experience': 571,
#  'wouldn': 572,
#  'lack': 573,
#  'hero': 574,
#  'including': 575,
#  'attempt': 576,
#  'please': 577,
#  'happen': 578,
#  'crap': 579,
#  'gore': 580,
#  'wonder': 581,
#  'complete': 582,
#  'cut': 583,
#  'group': 584,
#  'ago': 585,
#  'interest': 586,
#  'none': 587,
#  'score': 588,
#  'husband': 589,
#  'hell': 590,
#  'david': 591,
#  'simple': 592,
#  'save': 593,
#  'ok': 594,
#  'looked': 595,
#  'song': 596,
#  'career': 597,
#  'number': 598,
#  'seriously': 599,
#  'king': 600,
#  'possible': 601,
#  'annoying': 602,
#  'sad': 603,
#  'exactly': 604,
#  'shown': 605,
#  'musical': 606,
#  'running': 607,
#  'serious': 608,
#  'yourself': 609,
#  'scary': 610,
#  'reality': 611,
#  'english': 612,
#  'released': 613,
#  'taken': 614,
#  'whose': 615,
#  'ends': 616,
#  'hours': 617,
#  'cinematography': 618,
#  'usually': 619,
#  'opening': 620,
#  'jokes': 621,
#  'light': 622,
#  'hilarious': 623,
#  'body': 624,
#  'cool': 625,
#  'across': 626,
#  'relationship': 627,
#  'somewhat': 628,
#  'happy': 629,
#  'usual': 630,
#  'ridiculous': 631,
#  'started': 632,
#  'level': 633,
#  'view': 634,
#  'opinion': 635,
#  'change': 636,
#  'novel': 637,
#  'wish': 638,
#  'middle': 639,
#  'taking': 640,
#  'talking': 641,
#  'ones': 642,
#  'documentary': 643,
#  'order': 644,
#  'robert': 645,
#  'finds': 646,
#  'power': 647,
#  'shots': 648,
#  'saying': 649,
#  'room': 650,
#  'huge': 651,
#  'female': 652,
#  'mostly': 653,
#  'episodes': 654,
#  'country': 655,
#  'five': 656,
#  'talent': 657,
#  'important': 658,
#  'modern': 659,
#  'rating': 660,
#  'earth': 661,
#  'major': 662,
#  'strange': 663,
#  'word': 664,
#  'jack': 665,
#  'turned': 666,
#  'call': 667,
#  'single': 668,
#  'apparently': 669,
#  'disappointed': 670,
#  'four': 671,
#  'events': 672,
#  'due': 673,
#  'songs': 674,
#  'attention': 675,
#  'basically': 676,
#  'television': 677,
#  'o': 678,
#  'comic': 679,
#  'knows': 680,
#  'future': 681,
#  'supporting': 682,
#  'clearly': 683,
#  'non': 684,
#  'british': 685,
#  'fast': 686,
#  'paul': 687,
#  'knew': 688,
#  'thriller': 689,
#  'class': 690,
#  'easily': 691,
#  'cheap': 692,
#  'silly': 693,
#  'aren': 694,
#  'problems': 695,
#  'words': 696,
#  'miss': 697,
#  'tells': 698,
#  'entertainment': 699,
#  'local': 700,
#  'rock': 701,
#  'sequence': 702,
#  'bring': 703,
#  'beyond': 704,
#  'straight': 705,
#  'george': 706,
#  'oscar': 707,
#  'upon': 708,
#  'whether': 709,
#  'moving': 710,
#  'romantic': 711,
#  'predictable': 712,
#  'sets': 713,
#  'similar': 714,
#  'falls': 715,
#  'mystery': 716,
#  'eye': 717,
#  'review': 718,
#  'lady': 719,
#  'richard': 720,
#  'enjoyable': 721,
#  'talk': 722,
#  'needs': 723,
#  'appears': 724,
#  'clich': 725,
#  'giving': 726,
#  'within': 727,
#  'message': 728,
#  'ten': 729,
#  'theater': 730,
#  'animation': 731,
#  'near': 732,
#  'team': 733,
#  'red': 734,
#  'sister': 735,
#  'sequel': 736,
#  'above': 737,
#  'theme': 738,
#  'dull': 739,
#  'nearly': 740,
#  'stand': 741,
#  'points': 742,
#  'lee': 743,
#  'haven': 744,
#  'bunch': 745,
#  'mention': 746,
#  'herself': 747,
#  'add': 748,
#  'feels': 749,
#  'york': 750,
#  'release': 751,
#  'ways': 752,
#  'storyline': 753,
#  'easy': 754,
#  'using': 755,
#  'surprised': 756,
#  'e': 757,
#  'named': 758,
#  'lots': 759,
#  'fantastic': 760,
#  'begins': 761,
#  'die': 762,
#  'working': 763,
#  'actual': 764,
#  'effort': 765,
#  'feature': 766,
#  'tale': 767,
#  'hate': 768,
#  'french': 769,
#  'minute': 770,
#  'stay': 771,
#  'clear': 772,
#  'tom': 773,
#  'follow': 774,
#  'viewers': 775,
#  'among': 776,
#  'elements': 777,
#  'comments': 778,
#  'typical': 779,
#  'avoid': 780,
#  'showing': 781,
#  'editing': 782,
#  'tried': 783,
#  'season': 784,
#  'sorry': 785,
#  'famous': 786,
#  'peter': 787,
#  'fall': 788,
#  'dialog': 789,
#  'period': 790,
#  'form': 791,
#  'general': 792,
#  'certain': 793,
#  'soundtrack': 794,
#  'buy': 795,
#  'filmed': 796,
#  'parents': 797,
#  'check': 798,
#  'means': 799,
#  'weak': 800,
#  'material': 801,
#  'figure': 802,
#  'crime': 803,
#  'doubt': 804,
#  'realistic': 805,
#  'somehow': 806,
#  'space': 807,
#  'gone': 808,
#  'disney': 809,
#  'kept': 810,
#  'leads': 811,
#  'viewing': 812,
#  'th': 813,
#  'greatest': 814,
#  'dance': 815,
#  'lame': 816,
#  'zombie': 817,
#  'third': 818,
#  'suspense': 819,
#  'brought': 820,
#  'imagine': 821,
#  'atmosphere': 822,
#  'hear': 823,
#  'whatever': 824,
#  'de': 825,
#  'particular': 826,
#  'sequences': 827,
#  'america': 828,
#  'move': 829,
#  'indeed': 830,
#  'learn': 831,
#  'average': 832,
#  'eventually': 833,
#  'rent': 834,
#  'wait': 835,
#  'note': 836,
#  'reviews': 837,
#  'deal': 838,
#  'forget': 839,
#  'surprise': 840,
#  'stage': 841,
#  'japanese': 842,
#  'poorly': 843,
#  'premise': 844,
#  'nature': 845,
#  'believable': 846,
#  'sexual': 847,
#  'sit': 848,
#  'subject': 849,
#  'possibly': 850,
#  'okay': 851,
#  'decided': 852,
#  'expected': 853,
#  'imdb': 854,
#  'dr': 855,
#  'truth': 856,
#  'street': 857,
#  'became': 858,
#  'free': 859,
#  'screenplay': 860,
#  'difficult': 861,
#  'killing': 862,
#  'romance': 863,
#  'baby': 864,
#  'joe': 865,
#  'hot': 866,
#  'dog': 867,
#  'nor': 868,
#  'question': 869,
#  'reading': 870,
#  'leaves': 871,
#  'needed': 872,
#  'begin': 873,
#  'meets': 874,
#  'directors': 875,
#  'unless': 876,
#  'society': 877,
#  'credits': 878,
#  'shame': 879,
#  'superb': 880,
#  'write': 881,
#  'otherwise': 882,
#  'situation': 883,
#  'meet': 884,
#  'dramatic': 885,
#  'memorable': 886,
#  'male': 887,
#  'open': 888,
#  'dream': 889,
#  'weird': 890,
#  'badly': 891,
#  'earlier': 892,
#  'writers': 893,
#  'fi': 894,
#  'forced': 895,
#  'acted': 896,
#  'laughs': 897,
#  'sci': 898,
#  'jane': 899,
#  'crazy': 900,
#  'emotional': 901,
#  'older': 902,
#  'monster': 903,
#  'beauty': 904,
#  'realize': 905,
#  'deep': 906,
#  'comment': 907,
#  'footage': 908,
#  'forward': 909,
#  'interested': 910,
#  'fantasy': 911,
#  'ask': 912,
#  'plus': 913,
#  'whom': 914,
#  'mark': 915,
#  'sounds': 916,
#  'directing': 917,
#  'features': 918,
#  'keeps': 919,
#  'development': 920,
#  'mess': 921,
#  'quickly': 922,
#  'air': 923,
#  'creepy': 924,
#  'c': 925,
#  'perfectly': 926,
#  'box': 927,
#  'towards': 928,
#  'girlfriend': 929,
#  'worked': 930,
#  'cheesy': 931,
#  'unique': 932,
#  'setting': 933,
#  'effect': 934,
#  'bill': 935,
#  'fire': 936,
#  'plenty': 937,
#  'hands': 938,
#  'result': 939,
#  'total': 940,
#  'previous': 941,
#  'brings': 942,
#  'personal': 943,
#  'incredibly': 944,
#  'rate': 945,
#  'doctor': 946,
#  'business': 947,
#  'return': 948,
#  'apart': 949,
#  'christmas': 950,
#  'joke': 951,
#  'leading': 952,
#  'casting': 953,
#  'admit': 954,
#  'cop': 955,
#  'powerful': 956,
#  'appear': 957,
#  'background': 958,
#  'boys': 959,
#  'ben': 960,
#  'present': 961,
#  'battle': 962,
#  'meant': 963,
#  'era': 964,
#  'hardly': 965,
#  'telling': 966,
#  'potential': 967,
#  'masterpiece': 968,
#  'create': 969,
#  'break': 970,
#  'secret': 971,
#  'pay': 972,
#  'gay': 973,
#  'dumb': 974,
#  'political': 975,
#  'fighting': 976,
#  'fails': 977,
#  'twist': 978,
#  'co': 979,
#  'various': 980,
#  'portrayed': 981,
#  'inside': 982,
#  'western': 983,
#  'villain': 984,
#  'reasons': 985,
#  'outside': 986,
#  'william': 987,
#  'nudity': 988,
#  'ideas': 989,
#  'front': 990,
#  'missing': 991,
#  'deserves': 992,
#  'married': 993,
#  'expecting': 994,
#  'match': 995,
#  'fairly': 996,
#  'rich': 997,
#  'talented': 998,
#  'unlike': 999,
#  ...}

# %% [markdown]
# #### Which word from the given list doesn't go with the others?

# %%
oWord2Vec.wv.doesnt_match(['man', 'child', 'woman', 'film'])
# Out:
# 'film'

# %% [markdown]
# #### Most similar:

# %%
oWord2Vec.wv.most_similar('film')
# Out:
# [('movie', 0.8893373012542725),
#  ('documentary', 0.6703558564186096),
#  ('picture', 0.6410948634147644),
#  ('flick', 0.6283562779426575),
#  ('sequel', 0.5940581560134888),
#  ('cinema', 0.535230815410614),
#  ('films', 0.5173639059066772),
#  ('turkey', 0.5110447406768799),
#  ('masterpiece', 0.5033935308456421),
#  ('product', 0.49864691495895386)]

# %% [markdown]
# ### A single word embedding:

# %%
word = 'this'
vZ   = oWord2Vec.wv[word]
vZ.shape
# Out:
# (300,)

# %% [markdown]
# ### Algebra with words:

# %%
vWord = oWord2Vec.wv['actor'] - oWord2Vec.wv['man'] +  oWord2Vec.wv['woman']
oWord2Vec.wv.most_similar(positive=[vWord], topn=1)

# oWord2Vec.wv.most_similar(positive=['actor', 'woman'], negative=['man'])
# Out:
# [('actress', 0.8335807919502258)]

# %% [markdown]
# ### Model words embedding:

# %%
#-- Embedding vectors (Vw)
mZ = oWord2Vec.wv.vectors
#-- Context vectors (Vc)
mC = oWord2Vec.syn1neg

mZ.shape, mC.shape
# Out:
# ((8306, 300), (8306, 300))

# %% [markdown]
# ### Compute $K$ clusters and print most similar words:

# %%
from sklearn.cluster import KMeans

K       = 10
# oKmeans = KMeans(n_clusters=K, n_init=1, init='random').fit(mZ)
oKmeans = KMeans(n_clusters=K).fit(mZ)
mMu     = oKmeans.cluster_centers_

# %%
bold = '\x1b[1m'
end  = '\x1b[0m'

for ii in range(K):
    print(bold + '--------------------------' + end)
    print(bold + f'Cluster {ii}:'             + end)
    display(oWord2Vec.wv.similar_by_vector(mMu[ii,:]))
    print(bold + '--------------------------' + end + '\n')
# Out:
# --------------------------
# Cluster 0:
# [('it', 0.6963847279548645),
#  ('i', 0.6258538365364075),
#  ('just', 0.6148213744163513),
#  ('you', 0.5909928679466248),
#  ('actually', 0.5906994342803955),
#  ('really', 0.5888749957084656),
#  ('what', 0.5867460370063782),
#  ('anyway', 0.5638018846511841),
#  ('that', 0.5589742660522461),
#  ('movie', 0.5473378896713257)]
# --------------------------
#
# --------------------------
# Cluster 1:
# [('truck', 0.8547428250312805),
#  ('crashes', 0.8420207500457764),
#  ('pool', 0.8314245343208313),
#  ('riding', 0.8298056721687317),
#  ('racing', 0.826576828956604),
#  ('neck', 0.821727991104126),
#  ('helicopter', 0.8204514384269714),
#  ('tree', 0.8197736740112305),
#  ('deserted', 0.8176237344741821),
#  ('climbing', 0.8149627447128296)]
# --------------------------
#
# --------------------------
# Cluster 2:
# [('accept', 0.7897562384605408),
#  ('relate', 0.7778269648551941),
#  ('tell', 0.7591675519943237),
#  ('ask', 0.7565035820007324),
#  ('leave', 0.7556847333908081),
#  ('find', 0.7475718855857849),
#  ('explain', 0.7384020686149597),
#  ('call', 0.7323665618896484),
#  ('appreciate', 0.7301350831985474),
#  ('understand', 0.7289038896560669)]
# --------------------------
#
# --------------------------
# Cluster 3:
# [('relations', 0.8446028232574463),
#  ('beliefs', 0.8340627551078796),
#  ('plight', 0.82899010181427),
#  ('conflicts', 0.8280780911445618),
#  ('awareness', 0.816286563873291),
#  ('desperation', 0.8118703961372375),
#  ('ideals', 0.8074533939361572),
#  ('interests', 0.7975994348526001),
#  ('views', 0.7928076982498169),
#  ('existence', 0.790086030960083)]
# --------------------------
#
# --------------------------
# Cluster 4:
# [('thomas', 0.9392228126525879),
#  ('julie', 0.9353925585746765),
#  ('miller', 0.9344971776008606),
#  ('lloyd', 0.924724280834198),
#  ('patrick', 0.9228273034095764),
#  ('burke', 0.922105073928833),
#  ('raymond', 0.9198663830757141),
#  ('keith', 0.9186036586761475),
#  ('hugh', 0.9183512926101685),
#  ('drake', 0.9160119891166687)]
# --------------------------
#
# --------------------------
# Cluster 5:
# [('uk', 0.7897157669067383),
#  ('code', 0.7204399704933167),
#  ('disc', 0.7199437618255615),
#  ('columbia', 0.7165877223014832),
#  ('bbc', 0.7083879113197327),
#  ('blockbusters', 0.7080051898956299),
#  ('broadcast', 0.7034980654716492),
#  ('august', 0.6959718465805054),
#  ('channel', 0.6902786493301392),
#  ('th', 0.6857770681381226)]
# --------------------------
#
# --------------------------
# Cluster 6:
# [('wonderland', 0.8054859042167664),
#  ('district', 0.8039807081222534),
#  ('mobster', 0.7998520731925964),
#  ('investigator', 0.7947738170623779),
#  ('hugo', 0.7935276627540588),
#  ('tourist', 0.7897177934646606),
#  ('gangs', 0.7884373664855957),
#  ('poet', 0.7870345115661621),
#  ('gypsy', 0.7847400903701782),
#  ('abu', 0.7842482328414917)]
# --------------------------
#
# --------------------------
# Cluster 7:
# [('uneven', 0.8552534580230713),
#  ('bland', 0.8447214961051941),
#  ('unrealistic', 0.8260059952735901),
#  ('riveting', 0.824479341506958),
#  ('melodramatic', 0.8235369920730591),
#  ('formulaic', 0.8180772662162781),
#  ('gripping', 0.8161770701408386),
#  ('stylish', 0.8158475756645203),
#  ('compelling', 0.8153582811355591),
#  ('unreal', 0.8121597170829773)]
# --------------------------
#
# --------------------------
# Cluster 8:
# [('wanted', 0.6428464651107788),
#  ('understood', 0.6208462119102478),
#  ('appears', 0.6137144565582275),
#  ('forgot', 0.6033156514167786),
#  ('got', 0.6017614603042603),
#  ('took', 0.5991787314414978),
#  ('hated', 0.5886221528053284),
#  ('did', 0.587199330329895),
#  ('showed', 0.5856050252914429),
#  ('missed', 0.5772632956504822)]
# --------------------------
#
# --------------------------
# Cluster 9:
# [('visuals', 0.8131970763206482),
#  ('dialog', 0.7800335884094238),
#  ('dialogue', 0.7739783525466919),
#  ('pacing', 0.7617191672325134),
#  ('atmosphere', 0.7530574202537537),
#  ('cinematography', 0.7408364415168762),
#  ('storyline', 0.7345183491706848),
#  ('imagery', 0.730393648147583),
#  ('storytelling', 0.7242763042449951),
#  ('editing', 0.7229069471359253)]
# --------------------------
