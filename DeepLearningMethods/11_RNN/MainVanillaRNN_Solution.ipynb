# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Lecture 11 - RNN </center>
# ### <center> Vanilla RNN </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/11_RNN/MainVanillaRNN_Solution.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

import torch
import torch.nn          as nn
import torch.optim       as optim
import torchsummary

matplotlib.rc('font', **{'size' : 16})

# %% [markdown]
# For Colab users:

# %%
if 'google.colab' in str(get_ipython()):
    # !npx degit FixelAlgorithmsTeam/FixelCourses/DeepLearningMethods/10_RNN/DeepLearningFramework ./DeepLearningFramework

# %% [markdown]
# #### Dataset:

# %%
#-- A simple sequence dataset:
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self, lX, vY):
        self.lX = lX
        self.vY = vY
        
    def __len__(self):
        return len(self.lX)
    
    def __getitem__(self, idx):
        vXi = self.lX[idx]
        yi  = self.vY[idx]
        return vXi, yi

# %%
from torch.nn.utils.rnn import pack_sequence

def SequenceCollateFunction(lBatch):
    
    lX, lY = zip          (*lBatch)
    vY     = torch.stack  (lY)
    mPackX = pack_sequence(lX, enforce_sorted=False)
    
    return mPackX, vY

# %% [markdown]
# ### Exercise
# * The goal is to estimate the following function:
# ![f_x](https://github.com/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/10_RNN//f_x.png?raw=true)
# * Train an RNN model and get $R^2$ above `0.99`.

# %% [markdown]
# #### Generate data:

# %%
minL   = 5
maxL   = 30
nTrain = 50000
nTest  = 10000
N      = nTrain + nTest

vY = torch.zeros(N)
lX = [None] * N
for ii in range(N):
    L       = np.random.randint(minL, maxL)
    vX      = torch.rand(L, 1)
    idx     = np.random.randint(L)
    vX[idx] = -1
    lX[ii]  = vX
    vY[ii]  = torch.sum(vX[:idx]**2) - torch.sum(vX[idx+1:]**2)

# %%
from torch.utils.data import random_split

oDataset            = SequenceDataset(lX, vY.float())
oTrainSet, oTestSet = random_split(oDataset, [nTrain, nTest])

len(oTrainSet), len(oTestSet)
# Out:
# (50000, 10000)

# %%
batchSize = 128
oTrainDL  = torch.utils.data.DataLoader(oTrainSet, shuffle=True,  batch_size=batchSize,   collate_fn=SequenceCollateFunction)
oTestDL   = torch.utils.data.DataLoader(oTestSet,  shuffle=False, batch_size=2*batchSize, collate_fn=SequenceCollateFunction)

# %% [markdown]
# ### Model:

# %%
class RnnModel(nn.Module):
    def __init__(self):
        super(RnnModel, self).__init__() #-- always do this
        
        H         = 100
        self.oRnn = nn.RNN   (input_size=1, hidden_size=H, batch_first=True)
        self.oFC  = nn.Linear(H, 1)

    def forward(self, mPackX):
                                   #-- mPackX.shape = (N*T,)
        _, mH  = self.oRnn(mPackX) #-- mH    .shape = (1, N, H)
        vY     = self.oFC (mH[0])  #-- vY    .shape = (N, 1)
        
        return vY[:,0]
#-------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------#
mPack, vY = next(iter(oTrainDL))

RnnModel()(mPack).shape
# Out:
# torch.Size([128])

# %%
from DeepLearningFramework.Metric import R2Score

DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
Loss   = nn.MSELoss()
Metric = R2Score

# %%
from torch.optim.lr_scheduler       import OneCycleLR
from DeepLearningFramework.Training import TrainModel

nEpochs    = 30
nIter      = nEpochs * len(oTrainDL)

oModel     = RnnModel  ().to(DEVICE)
oOptim     = optim.Adam(oModel.parameters(), lr=5e-5, betas=(0.8, 0.9))
oScheduler = OneCycleLR(oOptim, max_lr=5e-3, total_steps=nIter)
lHistory   = TrainModel(oModel, oTrainDL, oTestDL, Loss, Metric, nEpochs, oOptim, oScheduler);
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 000: | Train loss: 10.648 | Val loss:  6.728 | Train Metric:  0.239 | Val Metric:  0.514 | epoch time:  1.945 | <-- Checkpoint!
# Epoch 001: | Train loss:  5.958 | Val loss:  5.411 | Train Metric:  0.573 | Val Metric:  0.607 | epoch time:  1.385 | <-- Checkpoint!
# Epoch 002: | Train loss:  5.036 | Val loss:  5.256 | Train Metric:  0.639 | Val Metric:  0.620 | epoch time:  1.381 | <-- Checkpoint!
# Epoch 003: | Train loss:  4.804 | Val loss:  4.626 | Train Metric:  0.655 | Val Metric:  0.666 | epoch time:  1.388 | <-- Checkpoint!
# Epoch 004: | Train loss:  2.257 | Val loss:  1.183 | Train Metric:  0.837 | Val Metric:  0.914 | epoch time:  1.407 | <-- Checkpoint!
# Epoch 005: | Train loss:  0.874 | Val loss:  1.108 | Train Metric:  0.937 | Val Metric:  0.919 | epoch time:  1.413 | <-- Checkpoint!
# Epoch 006: | Train loss:  0.637 | Val loss:  0.974 | Train Metric:  0.954 | Val Metric:  0.929 | epoch time:  1.416 | <-- Checkpoint!
# Epoch 007: | Train loss:  0.452 | Val loss:  0.605 | Train Metric:  0.967 | Val Metric:  0.956 | epoch time:  1.422 | <-- Checkpoint!
# Epoch 008: | Train loss:  0.649 | Val loss:  4.172 | Train Metric:  0.953 | Val Metric:  0.699 | epoch time:  1.419 |
# Epoch 009: | Train loss:  0.634 | Val loss:  0.183 | Train Metric:  0.955 | Val Metric:  0.987 | epoch time:  1.434 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 010: | Train loss:  0.373 | Val loss:  0.218 | Train Metric:  0.973 | Val Metric:  0.984 | epoch time:  1.413 |
# Epoch 011: | Train loss:  0.183 | Val loss:  0.179 | Train Metric:  0.987 | Val Metric:  0.987 | epoch time:  1.407 | <-- Checkpoint!
# Epoch 012: | Train loss:  0.196 | Val loss:  0.203 | Train Metric:  0.986 | Val Metric:  0.985 | epoch time:  1.422 |
# Epoch 013: | Train loss:  0.126 | Val loss:  0.082 | Train Metric:  0.991 | Val Metric:  0.994 | epoch time:  1.383 | <-- Checkpoint!
# Epoch 014: | Train loss:  0.096 | Val loss:  0.086 | Train Metric:  0.993 | Val Metric:  0.994 | epoch time:  1.406 |
# Epoch 015: | Train loss:  0.080 | Val loss:  0.103 | Train Metric:  0.994 | Val Metric:  0.992 | epoch time:  1.384 |
# Epoch 016: | Train loss:  0.079 | Val loss:  0.080 | Train Metric:  0.994 | Val Metric:  0.994 | epoch time:  1.404 | <-- Checkpoint!
# Epoch 017: | Train loss:  0.055 | Val loss:  0.104 | Train Metric:  0.996 | Val Metric:  0.992 | epoch time:  1.430 |
# Epoch 018: | Train loss:  0.047 | Val loss:  0.026 | Train Metric:  0.997 | Val Metric:  0.998 | epoch time:  1.420 | <-- Checkpoint!
# Epoch 019: | Train loss:  0.040 | Val loss:  0.035 | Train Metric:  0.997 | Val Metric:  0.997 | epoch time:  1.379 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 020: | Train loss:  0.033 | Val loss:  0.026 | Train Metric:  0.998 | Val Metric:  0.998 | epoch time:  1.396 |
# Epoch 021: | Train loss:  0.027 | Val loss:  0.027 | Train Metric:  0.998 | Val Metric:  0.998 | epoch time:  1.395 |
# Epoch 022: | Train loss:  0.021 | Val loss:  0.018 | Train Metric:  0.998 | Val Metric:  0.999 | epoch time:  1.371 | <-- Checkpoint!
# Epoch 023: | Train loss:  0.016 | Val loss:  0.015 | Train Metric:  0.999 | Val Metric:  0.999 | epoch time:  1.401 | <-- Checkpoint!
# Epoch 024: | Train loss:  0.012 | Val loss:  0.010 | Train Metric:  0.999 | Val Metric:  0.999 | epoch time:  1.386 | <-- Checkpoint!
# Epoch 025: | Train loss:  0.010 | Val loss:  0.008 | Train Metric:  0.999 | Val Metric:  0.999 | epoch time:  1.391 | <-- Checkpoint!
# Epoch 026: | Train loss:  0.008 | Val loss:  0.007 | Train Metric:  0.999 | Val Metric:  1.000 | epoch time:  1.412 | <-- Checkpoint!
# Epoch 027: | Train loss:  0.006 | Val loss:  0.006 | Train Metric:  1.000 | Val Metric:  1.000 | epoch time:  1.369 | <-- Checkpoint!
# Epoch 028: | Train loss:  0.006 | Val loss:  0.006 | Train Metric:  1.000 | Val Metric:  1.000 | epoch time:  1.420 | <-- Checkpoint!
# Epoch 029: | Train loss:  0.005 | Val loss:  0.005 | Train Metric:  1.000 | Val Metric:  1.000 | epoch time:  1.391 | <-- Checkpoint!

# %%
from DeepLearningFramework.Auxiliary import PlotHistory

PlotHistory(lHistory)
plt.show   ()
