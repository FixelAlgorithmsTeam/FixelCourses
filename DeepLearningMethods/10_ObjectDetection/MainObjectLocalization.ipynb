# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Lecture 10 -  Object Detection </center>
# ### <center> Object Localization </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/10_ObjectDetection/MainObjectLocalization.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %%
if 'google.colab' in str(get_ipython()):
    # !npx degit FixelAlgorithmsTeam/FixelCourses/DeepLearningMethods/10_ObjectDetection/DeepLearningFramework ./DeepLearningFramework
    # !pip install torchinfo

# %%
#-----------------------------------------------------------#
#-----------------------------------------------------------#
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

import torch
import torch.nn    as nn
import torch.optim as optim
import torchinfo

from torch.optim.lr_scheduler import OneCycleLR
#-----------------------------------------------------------#
#-----------------------------------------------------------#
from DeepLearningFramework.Utils import PlotImage
#-----------------------------------------------------------#
#-----------------------------------------------------------#
torch.set_printoptions(3, linewidth=120, sci_mode=False)
torch.backends.cudnn.benchmark = True

# %% [markdown]
# #### Constants:

# %%
IMAGE_SIZE = 100
LABELS     = ['R', 'G', 'B']

# %% [markdown]
# #### `CreateImage` creates a synthetic image for object detection:

# %%
def CreateImage(imageSize, nObjects):
    mColor  = torch.eye(3)
    nColors = len(mColor)

    v       = torch.linspace(0, 1, IMAGE_SIZE)
    XX, YY  = torch.meshgrid(v, v, indexing='xy')
    
    vSize = [3, *XX.shape]
    mI    = torch.zeros(vSize)
    mBBox = torch.empty(nObjects, 5)
    for ii in range(nObjects):
        #-- Ellipse:
        cIdx = np.random.randint(nColors)
        vC   = mColor[cIdx]
        x    = np.random.rand()
        y    = np.random.rand()
        W    = np.random.rand() / 2
        H    = np.random.rand() / 2
        mE   = ((XX - x) / W) ** 2 + ((YY - y) / H)**2 <= 1
        mI  += mE[None,:,:] * vC[:,None,None] / 2
        
        #-- BBox:
        xLeft   = np.maximum(0, x - W)
        xRight  = np.minimum(1, x + W)
        yUp     = np.maximum(0, y - H)
        yDown   = np.minimum(1, y + H)
        xCenter = (xLeft + xRight) / 2
        yCenter = (yDown + yUp   ) / 2
        W       = xRight - xLeft
        H       = yDown  - yUp
        lBBox   = [xCenter, yCenter, W, H]
        
        mBBox[ii,:] = torch.tensor([cIdx, *lBBox])
    
    mI                      = torch.clamp(mI, 0, 1)
    mI[:,mI.max(0)[0] == 0] = 1
    return mI, mBBox
#----------------------------------------------------------#
#----------------------------------------------------------#
mI, mBBox = CreateImage(IMAGE_SIZE, 1)
mBBox
# Out:
# tensor([[1.000, 0.090, 0.767, 0.180, 0.419]])

# %% [markdown]
# #### BBox:
# ```python
# mBBox.shape = (1, 5)
# mBBox[ii]   = (label, xCetnter, yCenter, width, height)
# ```

# %% [markdown]
# #### A useful function to plot an image with its bounding boxes
# ```python
# from DeepLearningFramework.Utils import PlotImage
# ```

# %%
mI, mBBox = CreateImage(IMAGE_SIZE, 1)
PlotImage(mI, mBBox, LABELS, lColors=np.eye(3))
plt.show ()

# %% [markdown]
# #### Create synthetic datasets:

# %%
def MakeData(N):
    mX    = torch.empty(N, 3, IMAGE_SIZE, IMAGE_SIZE)
    mBBox = torch.empty(N, 5)
    for ii in range(N):
        mXi, mBi  = CreateImage(IMAGE_SIZE, 1)
        mX   [ii] = mXi
        mBBox[ii] = mBi[0]

    return mX, mBBox
        
nTrain = 10000
nTest  = 1000

mTrainX, mTrainBBox = MakeData(nTrain)
mTestX,  mTestBBox  = MakeData(nTest)

# %% [markdown]
# ### Define a `Dataset` class.
# In this example one can also use `torch.utils.data.TensorDataset`.
# However, it is important to know how to define a custom dataset.

# %%
class ObjectDataset(torch.utils.data.Dataset):
    def __init__(self, mX, mBBox):
        self.mX    = mX
        self.mBBox = mBBox
        
    def __len__(self):
        return self.mX.shape[0]
    
    def __getitem__(self, idx):
        mXi = self.mX   [idx]
        mBi = self.mBBox[idx]
        return mXi, mBi

# %% [markdown]
# #### Create train and test sets:

# %%
from DeepLearningFramework.Dataset import ObjectDataset

oTrainSet = ObjectDataset(mTrainX, mTrainBBox)
oTestSet  = ObjectDataset(mTestX,  mTestBBox)

# %% [markdown]
# #### Test our dataset code:

# %%
idx      = np.random.randint(nTrain)
mXi, mBi = oTrainSet[idx]

PlotImage(mXi, mBi[None], vLabels=LABELS, lColors=np.eye(3))
plt.show ()

# %% [markdown]
# #### Create a `DataLoader` with its `Collate` function:

# %%
batchSize = 256
oTrainDL  = torch.utils.data.DataLoader(oTrainSet, shuffle=True,  batch_size=1*batchSize, num_workers=2, persistent_workers=True)
oTestDL   = torch.utils.data.DataLoader(oTestSet,  shuffle=False, batch_size=2*batchSize, num_workers=2, persistent_workers=True)

mX,       mBBox       = next(iter(oTrainDL))
mX.shape, mBBox.shape
# Out:
# (torch.Size([256, 3, 100, 100]), torch.Size([256, 5]))

# %%
mX, mBBox = next(iter(oTrainDL))

PlotImage(mX[0], mBBox[[0]], vLabels=LABELS, lColors=np.eye(3))
plt.show ()

# %% [markdown]
# ### Define the model:

# %%
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        
        self.NN = nn.Sequential(
            nn.Identity(),
            nn.Conv2d(3,   32,  3, stride=2, padding=0, bias=False), nn.BatchNorm2d(32 ), nn.ReLU(),
            nn.Conv2d(32,  32,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(32 ), nn.ReLU(),
            nn.Conv2d(32,  32,  3, stride=2, padding=0, bias=False), nn.BatchNorm2d(32 ), nn.ReLU(),
            nn.Conv2d(32,  32,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(32 ), nn.ReLU(),
            nn.Conv2d(32,  32,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(32 ), nn.ReLU(),
            nn.Conv2d(32,  64,  3, stride=2, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  64,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  64,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  64,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  64,  3, stride=1, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  64,  3, stride=2, padding=1, bias=False), nn.BatchNorm2d(64 ), nn.ReLU(),
            nn.Conv2d(64,  128, 3, stride=1, padding=0, bias=False), nn.BatchNorm2d(128), nn.ReLU(),
            nn.Conv2d(128, 256, 3, stride=1, padding=0, bias=False), nn.BatchNorm2d(256), nn.ReLU(),
            nn.Conv2d(256, 512, 2, stride=1, padding=0, bias=False), nn.BatchNorm2d(512), nn.ReLU(),
            nn.Conv2d(512, 7,   1, stride=1, padding=0, bias=True ),
            nn.Flatten()
    )
        
    def forward(self, mX):
        mOutput = self.NN(mX)
                
        return mOutput
#-------------------------------------------------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------------------------------------------------#
#-- Model summary:
mOutput = Model()(mX)

mOutput.shape, \
torchinfo.summary(Model(), mX.shape)
# Out:
# (torch.Size([256, 7]),
#  ==========================================================================================
#  Layer (type:depth-idx)                   Output Shape              Param #
#  ==========================================================================================
#  Model                                    --                        --
#  ├─Sequential: 1-1                        [256, 7]                  --
#  │    └─Identity: 2-1                     [256, 3, 100, 100]        --
#  │    └─Conv2d: 2-2                       [256, 32, 49, 49]         864
#  │    └─BatchNorm2d: 2-3                  [256, 32, 49, 49]         64
#  │    └─ReLU: 2-4                         [256, 32, 49, 49]         --
#  │    └─Conv2d: 2-5                       [256, 32, 49, 49]         9,216
#  │    └─BatchNorm2d: 2-6                  [256, 32, 49, 49]         64
#  │    └─ReLU: 2-7                         [256, 32, 49, 49]         --
#  │    └─Conv2d: 2-8                       [256, 32, 24, 24]         9,216
#  │    └─BatchNorm2d: 2-9                  [256, 32, 24, 24]         64
#  │    └─ReLU: 2-10                        [256, 32, 24, 24]         --
#  │    └─Conv2d: 2-11                      [256, 32, 24, 24]         9,216
#  │    └─BatchNorm2d: 2-12                 [256, 32, 24, 24]         64
#  │    └─ReLU: 2-13                        [256, 32, 24, 24]         --
#  │    └─Conv2d: 2-14                      [256, 32, 24, 24]         9,216
#  │    └─BatchNorm2d: 2-15                 [256, 32, 24, 24]         64
#  │    └─ReLU: 2-16                        [256, 32, 24, 24]         --
#  │    └─Conv2d: 2-17                      [256, 64, 12, 12]         18,432
#  │    └─BatchNorm2d: 2-18                 [256, 64, 12, 12]         128
#  │    └─ReLU: 2-19                        [256, 64, 12, 12]         --
#  │    └─Conv2d: 2-20                      [256, 64, 12, 12]         36,864
#  │    └─BatchNorm2d: 2-21                 [256, 64, 12, 12]         128
#  │    └─ReLU: 2-22                        [256, 64, 12, 12]         --
#  │    └─Conv2d: 2-23                      [256, 64, 12, 12]         36,864
#  │    └─BatchNorm2d: 2-24                 [256, 64, 12, 12]         128
#  │    └─ReLU: 2-25                        [256, 64, 12, 12]         --
#  │    └─Conv2d: 2-26                      [256, 64, 12, 12]         36,864
#  │    └─BatchNorm2d: 2-27                 [256, 64, 12, 12]         128
#  │    └─ReLU: 2-28                        [256, 64, 12, 12]         --
#  │    └─Conv2d: 2-29                      [256, 64, 12, 12]         36,864
#  │    └─BatchNorm2d: 2-30                 [256, 64, 12, 12]         128
#  │    └─ReLU: 2-31                        [256, 64, 12, 12]         --
#  │    └─Conv2d: 2-32                      [256, 64, 6, 6]           36,864
#  │    └─BatchNorm2d: 2-33                 [256, 64, 6, 6]           128
#  │    └─ReLU: 2-34                        [256, 64, 6, 6]           --
#  │    └─Conv2d: 2-35                      [256, 128, 4, 4]          73,728
#  │    └─BatchNorm2d: 2-36                 [256, 128, 4, 4]          256
#  │    └─ReLU: 2-37                        [256, 128, 4, 4]          --
#  │    └─Conv2d: 2-38                      [256, 256, 2, 2]          294,912
#  │    └─BatchNorm2d: 2-39                 [256, 256, 2, 2]          512
#  │    └─ReLU: 2-40                        [256, 256, 2, 2]          --
#  │    └─Conv2d: 2-41                      [256, 512, 1, 1]          524,288
#  │    └─BatchNorm2d: 2-42                 [256, 512, 1, 1]          1,024
#  │    └─ReLU: 2-43                        [256, 512, 1, 1]          --
#  │    └─Conv2d: 2-44                      [256, 7, 1, 1]            3,591
#  │    └─Flatten: 2-45                     [256, 7]                  --
#  ==========================================================================================
#  Total params: 1,139,879
#  Trainable params: 1,139,879
#  Non-trainable params: 0
#  Total mult-adds (G): 17.47
#  ==========================================================================================
#  Input size (MB): 30.72
#  Forward/backward pass size (MB): 1068.78
#  Params size (MB): 4.56
#  Estimated Total Size (MB): 1104.05
#  ==========================================================================================)

# %% [markdown]
# ### Loss function (regression + classification):
# $$\ell\left(\hat{\boldsymbol{y}},\boldsymbol{y}\right)=\lambda_{\text{MSE}}\cdot\ell_{\text{MSE}}\left(\hat{\boldsymbol{y}}_{\text{bbox}},\boldsymbol{y}_{\text{bbox}}\right)+\lambda_{\text{CE}}\cdot\ell_{\text{CE}}\left(\hat{\boldsymbol{y}}_{\text{label}},\boldsymbol{y}_{\text{label}}\right)$$
# where $\lambda_{\text{MSE}}$ and $\lambda_{\text{CE}}$ are the weights
# of each loss.

# %%
def Loss(mOutput, mBBox):
    #-- mOutput.shape = (N, 7)
    #-- mBBox  .shape = (N, 5)
    #-- mOutput[ii,:] = [R, G, B, x, y, W, H]
    #-- mBBox  [ii,:] = [cIdx,    x, y, W, H]
    vLabel     = mBBox  [:,0 ].type(torch.long)
    mBBox      = mBBox  [:,1:]
    mLabelPred = mOutput[:,:3]
    mBBoxPred  = mOutput[:,3:]
    
    MSE = nn.MSELoss         ()(mBBoxPred,  mBBox)
    CE  = nn.CrossEntropyLoss()(mLabelPred, vLabel)
    
    loss = 20 * MSE + CE
    
    return loss, MSE.item(), CE.item()

# %% [markdown]
# ### Exercise 1: IoU
# Implement the `ComputeIoU` funciton.
# $$\text{IoU}\left(B_{i},B_{j}\right)=\frac{\text{Area}\left(B_{i}\cap B_{j}\right)}{\text{Area}\left(B_{i}\cup B_{j}\right)}$$
#
# * You may use the `Area` and `CenterToCorner` functions.

# %%
def Area(mBBox):
    #-- mBBox.shape = (N, 4)
    #-- mBBox[ii,:] = [xLeft, yUp, xRight, yDown]
    
    vXLeft, vYUp, vXRight, vYDown = mBBox.T
    return (vXRight - vXLeft).clamp(0) * (vYDown - vYUp).clamp(0)
#--------------------------------------------------------------------------#
#--------------------------------------------------------------------------#
def CenterToCorner(mBBox):
    #-- mBBox.shape = (N, 4)
    #-- mBBox[ii,:] = [xCenter, yCenter, width, height]
    vX, vY, vW, vH = mBBox.T
    vXLeft         = vX - vW / 2
    vXRight        = vX + vW / 2
    vYUp           = vY - vH / 2
    vYDown         = vY + vH / 2
    mBBox          = torch.stack([vXLeft, vYUp, vXRight, vYDown], dim=-1)

    return mBBox
#--------------------------------------------------------------------------#
#--------------------------------------------------------------------------#
# def ComputeIoU(mBBox1, mBBox2):
#     #-- mBBox1.shape = (N, 4)
#     #-- mBBox2.shape = (N, 4)
#     #-- mBBox1[ii,:] = [xCenter, yCenter, width, height]
#     #-- mBBox2[ii,:] = [xCenter, yCenter, width, height]
    
#     vIoU = ??? #-- vIoU.shape = (N,)
    
#     return vIoU

# %% [markdown]
# ### Exercise 2: Metric
# Implement the following metric.
# $$\text{Metric}=\frac{1}{N}\sum_{i=1}^{N}\mathbb{I}\left\{ \hat{y}_{i}=y_{i}\right\} \cdot\text{IoU}\left(\hat{B}_{i},B_{i}\right)$$
# where:
# - $\hat{y}_{i}$ is the predicted label
# - $y_{i}$ is the correct label
# - $\hat{B}_{i}$ is the predicted bounding box
# - $B_{i}$ is the correct bounding box
# In other words, the average IoU, considering only correct (label) prediction.

# %%
def Output2Target(mOutput):
    #-- mOutput.shape = (N, 7)
    #-- mOutput[ii,:] = [R, G, B, x, y, W, H]
    mClass = torch.argmax(mOutput[:,:3], dim=1, keepdims=True) #-- mClass.shape = (N, 1)
    mBBox  =              mOutput[:,3:]                        #-- mBBox .shape = (N, 4)
    mBBox  = torch.cat   ([mClass, mBBox], dim=1)              #-- mBBox .shape = (N, 5)
    return mBBox

# %%
def Metric(mOutput, mBBox):
    #-- mOutput.shape = (N, 7)
    #-- mBBox  .shape = (N, 5)
    #-- mOutput[ii,:] = [R, G, B, x, y, W, H]
    #-- mBBox  [ii,:] = [cIdx,    x, y, W, H]
    
    mBBoxPred  = Output2Target(mOutput) #-- mBBoxPred[ii,:] = [cIdx, x, y, W, H]
    vLabelPred = mBBoxPred[:,0]
    vLabel     = mBBox    [:,0]
    mBBoxPred  = mBBoxPred[:,1:]
    mBBox      = mBBox    [:,1:]

    vIoU       = ???
    vCorrect   = ???

    acc        = vCorrect.mean().item()
    IoU        = vIoU    .mean().item()
    metric     = ???
    
    return metric, acc, IoU

# %%
def Epoch(oModel, oDataDL, Loss, Metric, oOptim=None, oScheduler=None, bTrain=True):

    vEpochStats = np.zeros(6) #-- (Loss, CE, MSE, Metric, Accuracy, IoU)
    count       = 0
    nIter       = len(oDataDL)
    vLR         = np.full(nIter, np.nan)
    DEVICE      = next(oModel.parameters()).device #-- CPU\GPU

    oModel.train(bTrain) #-- train or test

    #-- Iterate over the mini-batches:
    for ii, (mX, mBBox) in enumerate(oDataDL):
        #-- Move to device (CPU\GPU):
        mX    = mX   .to(DEVICE)
        mBBox = mBBox.to(DEVICE)

        #-- Forward:
        if bTrain == True:
            #-- Store computational graph:
            mOut          = oModel(mX)
            loss, MSE, CE = Loss  (mOut, mBBox)

            #-- Backward:
            oOptim    .zero_grad() #-- set gradients to zeros
            loss      .backward () #-- backward
            oOptim    .step     () #-- update parameters
            oScheduler.step     () #-- update learning rate
        
        else:
            with torch.no_grad():
                #-- Do not store computational graph:
                mOut          = oModel(mX)
                loss, MSE, CE = Loss  (mOut, mBBox)

        with torch.no_grad():
            Nb                = mBBox.shape[0]
            metric, acc, IoU  = Metric(mOut, mBBox)
            vIterStats        = np.array([loss.item(), CE, MSE, metric, acc, IoU])
            vEpochStats      += Nb * vIterStats
            count            += Nb
            
        print(f'\r{"Train" if bTrain else "Val"} - Iteration: {ii:3d} ({nIter}): loss = {loss.item():6.3f}', end='')

    print('', end='\r')
    vEpochStats /= count
    
    return vEpochStats, vLR

# %%
import time

def TrainModel(oModel, oTrainData, oValData, Loss, Metric, nEpochs, oOptim, oScheduler=None, sModelName='ObjectLocalization'):

    TRAIN        = 0
    VAL          = 1
    vLR          = np.full(0,       np.nan)
    mHistory     = np.full((2, 6, nEpochs), np.nan)
    lNames       = ['Loss', 'CE', 'MSE', 'Metric', 'Accuracy', 'IoU']
    bestMetric   = -float('inf')

    fig, _ = plt.subplots(2, 3, figsize=(12, 6))
    for epoch in range(nEpochs):
        startTime                     = time.time()
        mHistory[TRAIN,:,epoch], vLRi = Epoch(oModel, oTrainData, Loss, Metric, oOptim, oScheduler, bTrain=True ) #-- train
        mHistory[VAL,  :,epoch], _    = Epoch(oModel, oValData,   Loss, Metric,                     bTrain=False) #-- validate
        epochTime                     = time.time() - startTime

        #-- Display:
        if epoch % 10 == 0:
            print('-' * 120)
        print('Epoch '            f'{epoch                   :03d}:',   end='')
        print(' | Train loss: '   f'{mHistory[TRAIN,0,epoch] :6.3f}',   end='')
        print(' | Val loss: '     f'{mHistory[VAL,  0,epoch] :6.3f}',   end='')
        print(' | Train Metric: ' f'{mHistory[TRAIN,3,epoch] :6.3f}',   end='')
        print(' | Val Metric: '   f'{mHistory[VAL,  3,epoch] :6.3f}',   end='')
        print(' | epoch time: '   f'{epochTime               :6.3f} |', end='')

        valMetric = mHistory[VAL,3,epoch]
        #-- Save best model (early stopping):
        if valMetric > bestMetric:
            bestMetric = valMetric
            try   : torch.save(oModel.state_dict(), sModelName + '.pt')
            except: pass
            print(' <-- Checkpoint!')
        else:
            print('')
            
        for ii, ax in enumerate(fig.axes):
            ax.cla      ()
            ax.plot     (mHistory[TRAIN, ii], 'b', label='Train')
            ax.plot     (mHistory[VAL,   ii], 'r', label='Validation')
            ax.set_title(lNames[ii])
            ax.grid     ()
            ax.legend   ()

        fig.canvas.draw ()
        plt.tight_layout()
        plt.pause       (1e-4)

    #-- Load best model (early stopping):
    oModel.load_state_dict(torch.load(sModelName + '.pt'))

    return mHistory

# %%
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
# %matplotlib notebook

nEpochs    = 100
nIter      = nEpochs * len(oTrainDL)

oModel     = Model      ().to(DEVICE)
oOptim     = optim.AdamW(oModel.parameters(), lr=0, betas=(0.9, 0.99), weight_decay=1e-5)
oScheduler = OneCycleLR (oOptim, max_lr=7e-5, total_steps=nIter)
mHistory   = TrainModel (oModel, oTrainDL, oTestDL, Loss, Metric, nEpochs, oOptim, oScheduler)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 000: | Train loss:  8.079 | Val loss:  7.236 | Train Metric:  0.001 | Val Metric:  0.000 | epoch time:  5.469 | <-- Checkpoint!
# Epoch 001: | Train loss:  7.051 | Val loss:  6.854 | Train Metric:  0.002 | Val Metric:  0.002 | epoch time:  1.965 | <-- Checkpoint!
# Epoch 002: | Train loss:  6.304 | Val loss:  6.222 | Train Metric:  0.002 | Val Metric:  0.004 | epoch time:  1.953 | <-- Checkpoint!
# Epoch 003: | Train loss:  5.551 | Val loss:  5.519 | Train Metric:  0.004 | Val Metric:  0.004 | epoch time:  1.947 | <-- Checkpoint!
# Epoch 004: | Train loss:  4.788 | Val loss:  5.017 | Train Metric:  0.006 | Val Metric:  0.006 | epoch time:  1.941 | <-- Checkpoint!
# Epoch 005: | Train loss:  4.007 | Val loss:  4.158 | Train Metric:  0.011 | Val Metric:  0.011 | epoch time:  1.959 | <-- Checkpoint!
# Epoch 006: | Train loss:  3.279 | Val loss:  3.453 | Train Metric:  0.019 | Val Metric:  0.022 | epoch time:  1.953 | <-- Checkpoint!
# Epoch 007: | Train loss:  2.651 | Val loss:  2.918 | Train Metric:  0.035 | Val Metric:  0.031 | epoch time:  1.943 | <-- Checkpoint!
# Epoch 008: | Train loss:  2.151 | Val loss:  2.399 | Train Metric:  0.061 | Val Metric:  0.052 | epoch time:  1.948 | <-- Checkpoint!
# Epoch 009: | Train loss:  1.798 | Val loss:  2.081 | Train Metric:  0.095 | Val Metric:  0.082 | epoch time:  1.947 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 010: | Train loss:  1.570 | Val loss:  1.882 | Train Metric:  0.131 | Val Metric:  0.105 | epoch time:  1.940 | <-- Checkpoint!
# Epoch 011: | Train loss:  1.403 | Val loss:  1.743 | Train Metric:  0.171 | Val Metric:  0.130 | epoch time:  1.954 | <-- Checkpoint!
# Epoch 012: | Train loss:  1.260 | Val loss:  1.569 | Train Metric:  0.207 | Val Metric:  0.147 | epoch time:  1.945 | <-- Checkpoint!
# Epoch 013: | Train loss:  1.131 | Val loss:  1.418 | Train Metric:  0.239 | Val Metric:  0.181 | epoch time:  1.947 | <-- Checkpoint!
# Epoch 014: | Train loss:  1.011 | Val loss:  1.261 | Train Metric:  0.267 | Val Metric:  0.200 | epoch time:  1.937 | <-- Checkpoint!
# Epoch 015: | Train loss:  0.902 | Val loss:  1.124 | Train Metric:  0.294 | Val Metric:  0.228 | epoch time:  1.950 | <-- Checkpoint!
# Epoch 016: | Train loss:  0.791 | Val loss:  0.991 | Train Metric:  0.319 | Val Metric:  0.252 | epoch time:  1.934 | <-- Checkpoint!
# Epoch 017: | Train loss:  0.699 | Val loss:  0.857 | Train Metric:  0.341 | Val Metric:  0.282 | epoch time:  1.942 | <-- Checkpoint!
# Epoch 018: | Train loss:  0.605 | Val loss:  0.744 | Train Metric:  0.363 | Val Metric:  0.294 | epoch time:  1.939 | <-- Checkpoint!
# Epoch 019: | Train loss:  0.523 | Val loss:  0.641 | Train Metric:  0.381 | Val Metric:  0.316 | epoch time:  1.967 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 020: | Train loss:  0.444 | Val loss:  0.561 | Train Metric:  0.400 | Val Metric:  0.340 | epoch time:  2.020 | <-- Checkpoint!
# Epoch 021: | Train loss:  0.375 | Val loss:  0.487 | Train Metric:  0.423 | Val Metric:  0.359 | epoch time:  1.997 | <-- Checkpoint!
# Epoch 022: | Train loss:  0.321 | Val loss:  0.417 | Train Metric:  0.441 | Val Metric:  0.390 | epoch time:  2.002 | <-- Checkpoint!
# Epoch 023: | Train loss:  0.274 | Val loss:  0.371 | Train Metric:  0.458 | Val Metric:  0.411 | epoch time:  1.988 | <-- Checkpoint!
# Epoch 024: | Train loss:  0.240 | Val loss:  0.330 | Train Metric:  0.471 | Val Metric:  0.438 | epoch time:  1.992 | <-- Checkpoint!
# Epoch 025: | Train loss:  0.208 | Val loss:  0.291 | Train Metric:  0.484 | Val Metric:  0.449 | epoch time:  2.056 | <-- Checkpoint!
# Epoch 026: | Train loss:  0.188 | Val loss:  0.263 | Train Metric:  0.497 | Val Metric:  0.453 | epoch time:  1.932 | <-- Checkpoint!
# Epoch 027: | Train loss:  0.161 | Val loss:  0.318 | Train Metric:  0.518 | Val Metric:  0.463 | epoch time:  1.941 | <-- Checkpoint!
# Epoch 028: | Train loss:  0.150 | Val loss:  0.230 | Train Metric:  0.518 | Val Metric:  0.468 | epoch time:  2.122 | <-- Checkpoint!
# Epoch 029: | Train loss:  0.132 | Val loss:  0.226 | Train Metric:  0.537 | Val Metric:  0.493 | epoch time:  2.119 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 030: | Train loss:  0.134 | Val loss:  0.190 | Train Metric:  0.537 | Val Metric:  0.521 | epoch time:  2.023 | <-- Checkpoint!
# Epoch 031: | Train loss:  0.116 | Val loss:  0.160 | Train Metric:  0.548 | Val Metric:  0.540 | epoch time:  1.942 | <-- Checkpoint!
# Epoch 032: | Train loss:  0.099 | Val loss:  0.193 | Train Metric:  0.571 | Val Metric:  0.483 | epoch time:  1.933 |
# Epoch 033: | Train loss:  0.106 | Val loss:  0.195 | Train Metric:  0.554 | Val Metric:  0.477 | epoch time:  1.933 |
# Epoch 034: | Train loss:  0.109 | Val loss:  0.150 | Train Metric:  0.559 | Val Metric:  0.550 | epoch time:  1.927 | <-- Checkpoint!
# Epoch 035: | Train loss:  0.092 | Val loss:  0.142 | Train Metric:  0.580 | Val Metric:  0.545 | epoch time:  1.928 |
# Epoch 036: | Train loss:  0.086 | Val loss:  0.170 | Train Metric:  0.589 | Val Metric:  0.528 | epoch time:  1.935 |
# Epoch 037: | Train loss:  0.087 | Val loss:  0.157 | Train Metric:  0.589 | Val Metric:  0.515 | epoch time:  1.935 |
# Epoch 038: | Train loss:  0.081 | Val loss:  0.129 | Train Metric:  0.587 | Val Metric:  0.539 | epoch time:  1.946 |
# Epoch 039: | Train loss:  0.071 | Val loss:  0.119 | Train Metric:  0.611 | Val Metric:  0.584 | epoch time:  1.926 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 040: | Train loss:  0.073 | Val loss:  0.115 | Train Metric:  0.606 | Val Metric:  0.588 | epoch time:  1.929 | <-- Checkpoint!
# Epoch 041: | Train loss:  0.067 | Val loss:  0.117 | Train Metric:  0.620 | Val Metric:  0.589 | epoch time:  1.947 | <-- Checkpoint!
# Epoch 042: | Train loss:  0.068 | Val loss:  0.120 | Train Metric:  0.620 | Val Metric:  0.568 | epoch time:  1.942 |
# Epoch 043: | Train loss:  0.071 | Val loss:  0.121 | Train Metric:  0.599 | Val Metric:  0.604 | epoch time:  1.930 | <-- Checkpoint!
# Epoch 044: | Train loss:  0.074 | Val loss:  0.110 | Train Metric:  0.616 | Val Metric:  0.596 | epoch time:  1.944 |
# Epoch 045: | Train loss:  0.060 | Val loss:  0.101 | Train Metric:  0.636 | Val Metric:  0.636 | epoch time:  1.946 | <-- Checkpoint!
# Epoch 046: | Train loss:  0.072 | Val loss:  0.110 | Train Metric:  0.618 | Val Metric:  0.608 | epoch time:  1.932 |
# Epoch 047: | Train loss:  0.061 | Val loss:  0.099 | Train Metric:  0.629 | Val Metric:  0.603 | epoch time:  1.922 |
# Epoch 048: | Train loss:  0.056 | Val loss:  0.093 | Train Metric:  0.641 | Val Metric:  0.626 | epoch time:  1.945 |
# Epoch 049: | Train loss:  0.055 | Val loss:  0.106 | Train Metric:  0.641 | Val Metric:  0.621 | epoch time:  1.944 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 050: | Train loss:  0.054 | Val loss:  0.092 | Train Metric:  0.642 | Val Metric:  0.637 | epoch time:  1.940 | <-- Checkpoint!
# Epoch 051: | Train loss:  0.052 | Val loss:  0.097 | Train Metric:  0.657 | Val Metric:  0.636 | epoch time:  1.943 |
# Epoch 052: | Train loss:  0.051 | Val loss:  0.087 | Train Metric:  0.658 | Val Metric:  0.652 | epoch time:  1.970 | <-- Checkpoint!
# Epoch 053: | Train loss:  0.048 | Val loss:  0.105 | Train Metric:  0.665 | Val Metric:  0.615 | epoch time:  1.950 |
# Epoch 054: | Train loss:  0.049 | Val loss:  0.094 | Train Metric:  0.664 | Val Metric:  0.636 | epoch time:  1.950 |
# Epoch 055: | Train loss:  0.051 | Val loss:  0.087 | Train Metric:  0.654 | Val Metric:  0.663 | epoch time:  1.934 | <-- Checkpoint!
# Epoch 056: | Train loss:  0.046 | Val loss:  0.084 | Train Metric:  0.674 | Val Metric:  0.660 | epoch time:  1.936 |
# Epoch 057: | Train loss:  0.047 | Val loss:  0.091 | Train Metric:  0.672 | Val Metric:  0.660 | epoch time:  1.983 |
# Epoch 058: | Train loss:  0.052 | Val loss:  0.092 | Train Metric:  0.656 | Val Metric:  0.652 | epoch time:  1.997 |
# Epoch 059: | Train loss:  0.044 | Val loss:  0.082 | Train Metric:  0.675 | Val Metric:  0.663 | epoch time:  1.972 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 060: | Train loss:  0.043 | Val loss:  0.082 | Train Metric:  0.679 | Val Metric:  0.671 | epoch time:  1.923 | <-- Checkpoint!
# Epoch 061: | Train loss:  0.056 | Val loss:  0.114 | Train Metric:  0.663 | Val Metric:  0.636 | epoch time:  1.936 |
# Epoch 062: | Train loss:  0.047 | Val loss:  0.079 | Train Metric:  0.677 | Val Metric:  0.673 | epoch time:  1.930 | <-- Checkpoint!
# Epoch 063: | Train loss:  0.044 | Val loss:  0.081 | Train Metric:  0.681 | Val Metric:  0.671 | epoch time:  1.987 |
# Epoch 064: | Train loss:  0.051 | Val loss:  0.081 | Train Metric:  0.680 | Val Metric:  0.684 | epoch time:  1.936 | <-- Checkpoint!
# Epoch 065: | Train loss:  0.043 | Val loss:  0.081 | Train Metric:  0.686 | Val Metric:  0.682 | epoch time:  1.940 |
# Epoch 066: | Train loss:  0.041 | Val loss:  0.081 | Train Metric:  0.686 | Val Metric:  0.681 | epoch time:  2.008 |
# Epoch 067: | Train loss:  0.040 | Val loss:  0.085 | Train Metric:  0.706 | Val Metric:  0.699 | epoch time:  1.959 | <-- Checkpoint!
# Epoch 068: | Train loss:  0.042 | Val loss:  0.086 | Train Metric:  0.698 | Val Metric:  0.667 | epoch time:  1.937 |
# Epoch 069: | Train loss:  0.044 | Val loss:  0.084 | Train Metric:  0.676 | Val Metric:  0.687 | epoch time:  1.930 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 070: | Train loss:  0.041 | Val loss:  0.092 | Train Metric:  0.701 | Val Metric:  0.686 | epoch time:  1.974 |
# Epoch 071: | Train loss:  0.043 | Val loss:  0.084 | Train Metric:  0.695 | Val Metric:  0.692 | epoch time:  2.098 |
# Epoch 072: | Train loss:  0.040 | Val loss:  0.080 | Train Metric:  0.700 | Val Metric:  0.684 | epoch time:  2.094 |
# Epoch 073: | Train loss:  0.038 | Val loss:  0.081 | Train Metric:  0.710 | Val Metric:  0.697 | epoch time:  2.134 |
# Epoch 074: | Train loss:  0.037 | Val loss:  0.080 | Train Metric:  0.711 | Val Metric:  0.692 | epoch time:  2.190 |
# Epoch 075: | Train loss:  0.037 | Val loss:  0.079 | Train Metric:  0.711 | Val Metric:  0.696 | epoch time:  2.252 |
# Epoch 076: | Train loss:  0.037 | Val loss:  0.078 | Train Metric:  0.717 | Val Metric:  0.694 | epoch time:  2.276 |
# Epoch 077: | Train loss:  0.037 | Val loss:  0.078 | Train Metric:  0.720 | Val Metric:  0.696 | epoch time:  2.274 |
# Epoch 078: | Train loss:  0.036 | Val loss:  0.075 | Train Metric:  0.718 | Val Metric:  0.702 | epoch time:  2.265 | <-- Checkpoint!
# Epoch 079: | Train loss:  0.036 | Val loss:  0.077 | Train Metric:  0.724 | Val Metric:  0.700 | epoch time:  2.330 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 080: | Train loss:  0.035 | Val loss:  0.078 | Train Metric:  0.722 | Val Metric:  0.702 | epoch time:  2.346 |
# Epoch 081: | Train loss:  0.036 | Val loss:  0.076 | Train Metric:  0.716 | Val Metric:  0.706 | epoch time:  2.327 | <-- Checkpoint!
# Epoch 082: | Train loss:  0.035 | Val loss:  0.079 | Train Metric:  0.723 | Val Metric:  0.694 | epoch time:  2.337 |
# Epoch 083: | Train loss:  0.033 | Val loss:  0.081 | Train Metric:  0.729 | Val Metric:  0.691 | epoch time:  2.322 |
# Epoch 084: | Train loss:  0.035 | Val loss:  0.084 | Train Metric:  0.734 | Val Metric:  0.698 | epoch time:  2.305 |
# Epoch 085: | Train loss:  0.034 | Val loss:  0.081 | Train Metric:  0.729 | Val Metric:  0.704 | epoch time:  2.285 |
# Epoch 086: | Train loss:  0.033 | Val loss:  0.079 | Train Metric:  0.737 | Val Metric:  0.692 | epoch time:  2.297 |
# Epoch 087: | Train loss:  0.033 | Val loss:  0.077 | Train Metric:  0.738 | Val Metric:  0.701 | epoch time:  2.168 |
# Epoch 088: | Train loss:  0.033 | Val loss:  0.080 | Train Metric:  0.735 | Val Metric:  0.700 | epoch time:  2.074 |
# Epoch 089: | Train loss:  0.033 | Val loss:  0.079 | Train Metric:  0.739 | Val Metric:  0.708 | epoch time:  2.101 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 090: | Train loss:  0.033 | Val loss:  0.079 | Train Metric:  0.739 | Val Metric:  0.710 | epoch time:  2.063 | <-- Checkpoint!
# Epoch 091: | Train loss:  0.032 | Val loss:  0.077 | Train Metric:  0.742 | Val Metric:  0.706 | epoch time:  2.089 |
# Epoch 092: | Train loss:  0.032 | Val loss:  0.080 | Train Metric:  0.746 | Val Metric:  0.701 | epoch time:  2.129 |
# Epoch 093: | Train loss:  0.032 | Val loss:  0.075 | Train Metric:  0.746 | Val Metric:  0.709 | epoch time:  2.242 |
# Epoch 094: | Train loss:  0.033 | Val loss:  0.079 | Train Metric:  0.741 | Val Metric:  0.706 | epoch time:  2.291 |
# Epoch 095: | Train loss:  0.032 | Val loss:  0.075 | Train Metric:  0.746 | Val Metric:  0.708 | epoch time:  2.253 |
# Epoch 096: | Train loss:  0.031 | Val loss:  0.079 | Train Metric:  0.748 | Val Metric:  0.709 | epoch time:  2.278 |
# Epoch 097: | Train loss:  0.032 | Val loss:  0.075 | Train Metric:  0.747 | Val Metric:  0.708 | epoch time:  2.149 |
# Epoch 098: | Train loss:  0.031 | Val loss:  0.075 | Train Metric:  0.753 | Val Metric:  0.705 | epoch time:  2.006 |
# Epoch 099: | Train loss:  0.032 | Val loss:  0.077 | Train Metric:  0.736 | Val Metric:  0.707 | epoch time:  1.983 |

# %%
# %matplotlib inline

from DeepLearningFramework.Utils import PlotPredictions

mXi, vBBox = oTestSet[np.random.randint(nTest)]
with torch.no_grad():
    mOutput = oModel(mXi[None].to(DEVICE)).detach().cpu()
    
mBBoxPred = Output2Target(mOutput)[0]
PlotPredictions(mXi, vBBox, mBBoxPred)
plt.show       ()

# %%
# def ComputeIoU(mBBox1, mBBox2):
#     #-- mBBox1.shape = (N, 4)
#     #-- mBBox2.shape = (N, 4)
#     #-- mBBox1[ii,:] = [xCenter, yCenter, width, height]
#     #-- mBBox2[ii,:] = [xCenter, yCenter, width, height]
#     mBBox1 = CenterToCorner(mBBox1)
#     mBBox2 = CenterToCorner(mBBox2)

#     mXLeft1, vYUp1, vXRight1, vYDown1  = mBBox1.T
#     vXLeft2, vYUp2, vXRight2, vYDown2  = mBBox2.T
    
#     vXLeft  = torch.maximum(mXLeft1,  vXLeft2 )
#     vXRight = torch.minimum(vXRight1, vXRight2)
#     vYUp    = torch.maximum(vYUp1,    vYUp2   )
#     vYDown  = torch.minimum(vYDown1,  vYDown2 )

#     mBBoxI  = torch.stack([vXLeft, vYUp, vXRight, vYDown], dim=1)
   
#     vArea1 = Area(mBBox1)
#     vArea2 = Area(mBBox2)
#     vAreaI = Area(mBBoxI)
    
#     vIoU   = vAreaI / (vArea1 + vArea2 - vAreaI) #-- vIoU.shape = (N,)
    
#     return vIoU

# %%
# def Metric(mOutput, mBBox):
#     #-- mOutput.shape = (N, 7)
#     #-- mBBox  .shape = (N, 5)
#     #-- mOutput[ii,:] = [R, G, B, x, y, W, H]
#     #-- mBBox  [ii,:] = [cIdx,    x, y, W, H]
    
#     mBBoxPred  = Output2Target(mOutput) #-- mBBoxPred[ii,:] = [cIdx, x, y, W, H]
#     vLabelPred = mBBoxPred[:,0]
#     vLabel     = mBBox    [:,0]
#     mBBoxPred  = mBBoxPred[:,1:]
#     mBBox      = mBBox    [:,1:]
#     vIoU       = ComputeIoU(mBBoxPred, mBBox)
#     vCorrect   = (vLabelPred == vLabel).type(torch.float32)

#     acc        = vCorrect.mean()            .item()
#     IoU        = vIoU    .mean()            .item()
#     metric     = torch.inner(vIoU, vCorrect).item() / mBBox.shape[0]
    
#     return metric, acc, IoU
