# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Exercise 7 - Transformer </center>
# ### <center> Music Classification - Solution </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/Exercises/Ex7/Exercise07_Transformer.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %%
import numpy             as np
import matplotlib.pyplot as plt

import torch
import torch.nn    as nn
import torch.optim as optim
import torchinfo
import torchaudio

import IPython.display as ipd

# %%
if 'google.colab' in str(get_ipython()):
    # !npx degit FixelAlgorithmsTeam/FixelCourses/DeepLearningMethods/Exercises/Ex7/DeepLearningFramework ./DeepLearningFramework

# %% [markdown]
# ### Exercise:
# Get above 50% accuracy on the GTZAN dataset.

# %% [markdown]
# #### Load the data:

# %%
from torchaudio.datasets import GTZAN

oTrainSet = GTZAN(root='../../../data', subset='training',   download=True)
oTestSet  = GTZAN(root='../../../data', subset='validation', download=True)

nTrain    = len(oTrainSet)
nTest     = len(oTestSet)
nTrain, nTest
# Out:
# (443, 197)

# %% [markdown]
# #### Display a single example:

# %%
idx       = np.random.randint(nTrain)
vX, Fs, y = oTrainSet[idx]

display(ipd.Audio(vX, rate=Fs))
vX.shape, Fs, y
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# (torch.Size([1, 661794]), 22050, 'blues')

# %% [markdown]
# #### waveform:

# %%
L  = vX.shape[1]
T  = L / Fs
tt = np.linspace(0, T, L, endpoint=False)
T
# Out:
# 30.013333333333332

# %%
plt.figure(figsize=(16, 4))
plt.plot  (tt, vX[0])
plt.xlabel('Time [sec]')
plt.grid  ()
plt.show  ()

# %% [markdown]
# #### (log) Spectrogram:

# %%
import torchaudio.transforms as transforms

def Spectrogram(vX):
    mS = transforms.Spectrogram(n_fft=512)(vX)[:-1,:]
    mS = torch.log10(mS + .1)
    
    return mS

# %%
Ti = 5
mS = Spectrogram(vX[0,:Ti*Fs])

plt.matshow (mS, origin='lower', extent=[0, Ti, 0, Fs//2000], aspect='auto')
plt.xlabel  ('Time [sec]')
plt.ylabel  ('Frequency [KHz]')
plt.colorbar()
plt.show    ()

# %% [markdown]
# #### Label encoder:

# %%
lLabels = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
from sklearn.preprocessing import LabelEncoder

oLabelEncoder = LabelEncoder().fit(lLabels)
nLabels       = len(oLabelEncoder.classes_)

print(f'Number of labels: {nLabels}'               )
print(f'Labels:         \n{oLabelEncoder.classes_}')
# Out:
# Number of labels: 10
# Labels:
# ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %% [markdown]
# #### Dataset:
# * The duration of each original sample is 30 seconds.
# * The following dataset returns a `T=3` seconds window from each sample.

# %%
class AudioDataset(torch.utils.data.Dataset):
    def __init__(self, oDataset, Fs, T, bTrain=False):
        self.oDataset = oDataset
        self.L        = int(T * Fs)
        self.bTrain   = bTrain
        self.nSplits  = 9 #-- Some signals are less than 30s so we split to 9 and not 10.
        
    def __len__(self):
        return self.nSplits * len(self.oDataset)
    
    def __getitem__(self, idx):
        nSplits = self.nSplits
        subIdx  = idx %  nSplits
        idx     = idx // nSplits
        L       = self.L
        start   = subIdx * L
        end     = start  + L
        
        #-- A random shift
        if self.bTrain == True and subIdx != (nSplits - 1):
            shift  = np.random.randint(L)
            start += shift
            end   += shift
        
        vX, _, label = self.oDataset[idx]
        vX           = vX[0,start:end]
        
        #-- Spectrogram:
        mS = Spectrogram(vX).T
        y  = oLabelEncoder.transform([label])[0]
        y  = torch.tensor(y, dtype=torch.long)
        
        return mS, y
    
#-----------------------------------------------------#
#-----------------------------------------------------#
Ti           = 3
oTrainSetAux = AudioDataset(oTrainSet, Fs, T=Ti, bTrain=True)
oTestSetAux  = AudioDataset(oTestSet,  Fs, T=Ti)

len(oTrainSetAux), len(oTestSetAux)
# Out:
# (3987, 1773)

# %%
mX, y = oTrainSetAux[100]

plt.matshow(mX.T, origin='lower', extent=[0, Ti, 0, Fs//2000], aspect='auto')
plt.xlabel ('Time [sec]')
plt.ylabel ('Frequency [KHz]')
plt.show   ()

mX.shape, y
# Out:
# (torch.Size([259, 256]), tensor(0))

# %% [markdown]
# #### Data-loader:

# %%
from torch.utils.data import DataLoader

batchSize = 128
oTrainDL  = DataLoader(oTrainSetAux, shuffle=True,  batch_size=batchSize)
oTestDL   = DataLoader(oTestSetAux,  shuffle=True,  batch_size=2*batchSize)

mX,       vY = next(iter(oTrainDL))
mX.shape, vY.shape
# Out:
# (torch.Size([128, 259, 256]), torch.Size([128]))

# %% [markdown]
# #### Model #1 - CNN
# Write a CNN based model that outputs `512` features.

# %%
class ConvBlock(nn.Module):
    def __init__(self, cIn, cOut, kernelSize, stride=1, bActivation=True):
        super(ConvBlock, self).__init__()

        padding = kernelSize // 2
        oConv   = nn.Conv2d(cIn, cOut, kernel_size=kernelSize, padding=padding, stride=stride, bias=not bActivation)
        if bActivation == True:
            self.oBlock = nn.Sequential(oConv, nn.BatchNorm2d(cOut), nn.LeakyReLU(0.1))
        else:
            self.oBlock = nn.Sequential(oConv)

    def forward(self, mX):
        return self.oBlock(mX)
#-------------------------------------------------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------------------------------------------------#
class ResBlock(nn.Module):
    def __init__(self, cIn):
        super(ResBlock, self).__init__()
        
        self.oBlock = nn.Sequential(
            ConvBlock(cIn,    cIn//2, kernelSize=1),
            ConvBlock(cIn//2, cIn,    kernelSize=3)
        )

    def forward(self, mX):
        return mX + self.oBlock(mX)
#-------------------------------------------------------------------------------------------------------------------------#
#-------------------------------------------------------------------------------------------------------------------------#
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()

        self.oNN = nn.Sequential(
            ???
            
            nn.AdaptiveAvgPool2d(1),
            nn.Flatten()
        )                  

    def forward(self, mX):
        return self.oNN(mX[:,None,:,:])
            
torchinfo.summary(CNN(), mX.shape)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# CNN                                                --                        --
# ├─Sequential: 1-1                                  [128, 512]                --
# │    └─ConvBlock: 2-1                              [128, 16, 130, 128]       --
# │    │    └─Sequential: 3-1                        [128, 16, 130, 128]       176
# │    └─Dropout2d: 2-2                              [128, 16, 130, 128]       --
# │    └─ConvBlock: 2-3                              [128, 32, 65, 64]         --
# │    │    └─Sequential: 3-2                        [128, 32, 65, 64]         4,672
# │    └─Dropout2d: 2-4                              [128, 32, 65, 64]         --
# │    └─ResBlock: 2-5                               [128, 32, 65, 64]         --
# │    │    └─Sequential: 3-3                        [128, 32, 65, 64]         5,216
# │    └─Dropout2d: 2-6                              [128, 32, 65, 64]         --
# │    └─ConvBlock: 2-7                              [128, 64, 33, 32]         --
# │    │    └─Sequential: 3-4                        [128, 64, 33, 32]         18,560
# │    └─Dropout2d: 2-8                              [128, 64, 33, 32]         --
# │    └─ResBlock: 2-9                               [128, 64, 33, 32]         --
# │    │    └─Sequential: 3-5                        [128, 64, 33, 32]         20,672
# │    └─Dropout2d: 2-10                             [128, 64, 33, 32]         --
# │    └─ConvBlock: 2-11                             [128, 128, 17, 16]        --
# │    │    └─Sequential: 3-6                        [128, 128, 17, 16]        73,984
# │    └─Dropout2d: 2-12                             [128, 128, 17, 16]        --
# │    └─ResBlock: 2-13                              [128, 128, 17, 16]        --
# │    │    └─Sequential: 3-7                        [128, 128, 17, 16]        82,304
# │    └─Dropout2d: 2-14                             [128, 128, 17, 16]        --
# │    └─ResBlock: 2-15                              [128, 128, 17, 16]        --
# │    │    └─Sequential: 3-8                        [128, 128, 17, 16]        82,304
# │    └─Dropout2d: 2-16                             [128, 128, 17, 16]        --
# │    └─ConvBlock: 2-17                             [128, 256, 9, 8]          --
# │    │    └─Sequential: 3-9                        [128, 256, 9, 8]          295,424
# │    └─Dropout2d: 2-18                             [128, 256, 9, 8]          --
# │    └─ResBlock: 2-19                              [128, 256, 9, 8]          --
# │    │    └─Sequential: 3-10                       [128, 256, 9, 8]          328,448
# │    └─Dropout2d: 2-20                             [128, 256, 9, 8]          --
# │    └─ResBlock: 2-21                              [128, 256, 9, 8]          --
# │    │    └─Sequential: 3-11                       [128, 256, 9, 8]          328,448
# │    └─Dropout2d: 2-22                             [128, 256, 9, 8]          --
# │    └─ConvBlock: 2-23                             [128, 512, 5, 4]          --
# │    │    └─Sequential: 3-12                       [128, 512, 5, 4]          1,180,672
# │    └─Dropout2d: 2-24                             [128, 512, 5, 4]          --
# │    └─AdaptiveAvgPool2d: 2-25                     [128, 512, 1, 1]          --
# │    └─Flatten: 2-26                               [128, 512]                --
# ====================================================================================================
# Total params: 2,420,880
# Trainable params: 2,420,880
# Non-trainable params: 0
# Total mult-adds (G): 30.80
# ====================================================================================================
# Input size (MB): 33.95
# Forward/backward pass size (MB): 2030.04
# Params size (MB): 9.68
# Estimated Total Size (MB): 2073.67
# ====================================================================================================

# %% [markdown]
# #### Model #2 - Transformer
# Write a Transformer based model that outputs `512` features.
# (You can consider only the last column of the transformer output just to shrink the model size.)

# %%
D = 256
L = 259
class Transformer(nn.Module):
    def __init__(self):
        super(Transformer, self).__init__()
        
        self.oEmbeedingPos = nn.Embedding              (L, D)
        oEncoderLayer      = nn.TransformerEncoderLayer(d_model=D, nhead=4, dropout=0.1)
        self.oTransformer  = nn.TransformerEncoder     (oEncoderLayer, 2)
        self.oLinear       = nn.Linear                 (D, 512)
    
    def forward(self, mX):
        mH = self.oTransformer(mX)
        mZ = self.oLinear     (mH[:,-1])
        
        return mZ
    
torchinfo.summary(Transformer(), mX.shape)
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# Transformer                                   --                        --
# ├─TransformerEncoder: 1                       --                        --
# │    └─ModuleList: 2-1                        --                        --
# ├─TransformerEncoder: 1-1                     [128, 259, 256]           --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [128, 259, 256]           1,315,072
# │    │    └─TransformerEncoderLayer: 3-2      [128, 259, 256]           1,315,072
# ├─Linear: 1-2                                 [128, 512]                131,584
# ===============================================================================================
# Total params: 2,235,392
# Trainable params: 2,235,392
# Non-trainable params: 0
# Total mult-adds (M): 286.13
# ===============================================================================================
# Input size (MB): 33.95
# Forward/backward pass size (MB): 1494.22
# Params size (MB): 8.94
# Estimated Total Size (MB): 1537.11
# ===============================================================================================

# %% [markdown]
# ### Joint Model
# CNN + Transformer + Linear

# %%
class JointModel(nn.Module):
    def __init__(self):
        super(JointModel, self).__init__()
        
        self.oCNN         = CNN        ()
        self.oTransformer = Transformer()
        self.oFC          = nn.Sequential(
                                nn.Linear(1024, 256), nn.ReLU(),
                                nn.Linear(256, 10)
                            )
     
    def forward(self, mX):
        mCNN         = self.oCNN        (???)
        mTransformer = self.oTransformer(???)
        mZ           = torch.cat        (???)
        mZ           = self.oFC         (???)
        
        return mZ
        
torchinfo.summary(JointModel(), mX.shape)
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# JointModel                                              --                        --
# ├─Transformer: 1                                        --                        --
# │    └─TransformerEncoder: 2                            --                        --
# │    │    └─ModuleList: 3-1                             --                        2,630,144
# ├─CNN: 1-1                                              [128, 512]                --
# │    └─Sequential: 2-1                                  [128, 512]                --
# │    │    └─ConvBlock: 3-2                              [128, 16, 130, 128]       176
# │    │    └─Dropout2d: 3-3                              [128, 16, 130, 128]       --
# │    │    └─ConvBlock: 3-4                              [128, 32, 65, 64]         4,672
# │    │    └─Dropout2d: 3-5                              [128, 32, 65, 64]         --
# │    │    └─ResBlock: 3-6                               [128, 32, 65, 64]         5,216
# │    │    └─Dropout2d: 3-7                              [128, 32, 65, 64]         --
# │    │    └─ConvBlock: 3-8                              [128, 64, 33, 32]         18,560
# │    │    └─Dropout2d: 3-9                              [128, 64, 33, 32]         --
# │    │    └─ResBlock: 3-10                              [128, 64, 33, 32]         20,672
# │    │    └─Dropout2d: 3-11                             [128, 64, 33, 32]         --
# │    │    └─ConvBlock: 3-12                             [128, 128, 17, 16]        73,984
# │    │    └─Dropout2d: 3-13                             [128, 128, 17, 16]        --
# │    │    └─ResBlock: 3-14                              [128, 128, 17, 16]        82,304
# │    │    └─Dropout2d: 3-15                             [128, 128, 17, 16]        --
# │    │    └─ResBlock: 3-16                              [128, 128, 17, 16]        82,304
# │    │    └─Dropout2d: 3-17                             [128, 128, 17, 16]        --
# │    │    └─ConvBlock: 3-18                             [128, 256, 9, 8]          295,424
# │    │    └─Dropout2d: 3-19                             [128, 256, 9, 8]          --
# │    │    └─ResBlock: 3-20                              [128, 256, 9, 8]          328,448
# │    │    └─Dropout2d: 3-21                             [128, 256, 9, 8]          --
# │    │    └─ResBlock: 3-22                              [128, 256, 9, 8]          328,448
# │    │    └─Dropout2d: 3-23                             [128, 256, 9, 8]          --
# │    │    └─ConvBlock: 3-24                             [128, 512, 5, 4]          1,180,672
# │    │    └─Dropout2d: 3-25                             [128, 512, 5, 4]          --
# │    │    └─AdaptiveAvgPool2d: 3-26                     [128, 512, 1, 1]          --
# │    │    └─Flatten: 3-27                               [128, 512]                --
# ├─Transformer: 1-2                                      [128, 512]                --
# │    └─TransformerEncoder: 2-2                          [128, 259, 256]           --
# │    └─Linear: 2-3                                      [128, 512]                131,584
# ├─Sequential: 1-3                                       [128, 10]                 --
# │    └─Linear: 2-4                                      [128, 256]                262,400
# │    └─ReLU: 2-5                                        [128, 256]                --
# │    └─Linear: 2-6                                      [128, 10]                 2,570
# =========================================================================================================
# Total params: 4,921,242
# Trainable params: 4,921,242
# Non-trainable params: 0
# Total mult-adds (G): 31.12
# =========================================================================================================
# Input size (MB): 33.95
# Forward/backward pass size (MB): 3524.54
# Params size (MB): 19.68
# Estimated Total Size (MB): 3578.17
# =========================================================================================================

# %%
from torch.optim.lr_scheduler       import OneCycleLR
from DeepLearningFramework.Training import TrainModel
from DeepLearningFramework.Metric   import Accuracy
from DeepLearningFramework.Losses   import LabelSmoothingLoss

DEVICE = torch.device      ("cuda:0" if torch.cuda.is_available() else "cpu") 
Loss   = LabelSmoothingLoss(len(oLabelEncoder.classes_))
Metric = Accuracy          ()

# %%
nEpochs    = 100
nIter      = nEpochs * len(oTrainDL)

oModel     = JointModel ().to(DEVICE)
oOptim     = optim.AdamW(oModel.parameters(), lr=0, betas=(0.9, 0.99), weight_decay=1)
oScheduler = OneCycleLR (oOptim, max_lr=5e-4, total_steps=nIter)
lHistory   = TrainModel (oModel, oTrainDL, oTestDL, Loss, Metric, nEpochs, oOptim, oScheduler, sModelName='GTZANJointModel')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 000: | Train loss:  2.228 | Val loss:  2.272 | Train Metric:  0.206 | Val Metric:  0.102 | epoch time: 17.509 | <-- Checkpoint!
# Epoch 001: | Train loss:  2.094 | Val loss:  2.230 | Train Metric:  0.273 | Val Metric:  0.127 | epoch time: 17.215 | <-- Checkpoint!
# Epoch 002: | Train loss:  1.965 | Val loss:  2.218 | Train Metric:  0.329 | Val Metric:  0.164 | epoch time: 17.041 | <-- Checkpoint!
# Epoch 003: | Train loss:  1.836 | Val loss:  2.200 | Train Metric:  0.377 | Val Metric:  0.215 | epoch time: 17.246 | <-- Checkpoint!
# Epoch 004: | Train loss:  1.739 | Val loss:  2.059 | Train Metric:  0.394 | Val Metric:  0.255 | epoch time: 16.975 | <-- Checkpoint!
# Epoch 005: | Train loss:  1.654 | Val loss:  2.084 | Train Metric:  0.426 | Val Metric:  0.260 | epoch time: 17.271 | <-- Checkpoint!
# Epoch 006: | Train loss:  1.602 | Val loss:  1.949 | Train Metric:  0.445 | Val Metric:  0.302 | epoch time: 17.515 | <-- Checkpoint!
# Epoch 007: | Train loss:  1.512 | Val loss:  1.939 | Train Metric:  0.482 | Val Metric:  0.318 | epoch time: 17.196 | <-- Checkpoint!
# Epoch 008: | Train loss:  1.476 | Val loss:  1.788 | Train Metric:  0.486 | Val Metric:  0.360 | epoch time: 17.082 | <-- Checkpoint!
# Epoch 009: | Train loss:  1.390 | Val loss:  1.853 | Train Metric:  0.523 | Val Metric:  0.370 | epoch time: 16.979 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 010: | Train loss:  1.328 | Val loss:  1.714 | Train Metric:  0.544 | Val Metric:  0.383 | epoch time: 17.119 | <-- Checkpoint!
# Epoch 011: | Train loss:  1.236 | Val loss:  1.787 | Train Metric:  0.579 | Val Metric:  0.384 | epoch time: 17.006 | <-- Checkpoint!
# Epoch 012: | Train loss:  1.141 | Val loss:  1.846 | Train Metric:  0.607 | Val Metric:  0.392 | epoch time: 17.326 | <-- Checkpoint!
# Epoch 013: | Train loss:  1.089 | Val loss:  1.851 | Train Metric:  0.626 | Val Metric:  0.389 | epoch time: 17.513 |
# Epoch 014: | Train loss:  1.034 | Val loss:  1.865 | Train Metric:  0.654 | Val Metric:  0.413 | epoch time: 17.176 | <-- Checkpoint!
# Epoch 015: | Train loss:  0.960 | Val loss:  1.907 | Train Metric:  0.677 | Val Metric:  0.406 | epoch time: 17.083 |
# Epoch 016: | Train loss:  0.946 | Val loss:  1.887 | Train Metric:  0.689 | Val Metric:  0.420 | epoch time: 17.177 | <-- Checkpoint!
# Epoch 017: | Train loss:  0.894 | Val loss:  1.797 | Train Metric:  0.704 | Val Metric:  0.448 | epoch time: 17.018 | <-- Checkpoint!
# Epoch 018: | Train loss:  0.825 | Val loss:  1.922 | Train Metric:  0.739 | Val Metric:  0.438 | epoch time: 17.135 |
# Epoch 019: | Train loss:  0.804 | Val loss:  1.892 | Train Metric:  0.742 | Val Metric:  0.449 | epoch time: 17.225 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 020: | Train loss:  0.787 | Val loss:  1.937 | Train Metric:  0.744 | Val Metric:  0.451 | epoch time: 17.641 | <-- Checkpoint!
# Epoch 021: | Train loss:  0.725 | Val loss:  1.956 | Train Metric:  0.769 | Val Metric:  0.448 | epoch time: 17.042 |
# Epoch 022: | Train loss:  0.681 | Val loss:  1.940 | Train Metric:  0.786 | Val Metric:  0.482 | epoch time: 17.014 | <-- Checkpoint!
# Epoch 023: | Train loss:  0.666 | Val loss:  1.933 | Train Metric:  0.787 | Val Metric:  0.461 | epoch time: 17.152 |
# Epoch 024: | Train loss:  0.641 | Val loss:  2.068 | Train Metric:  0.799 | Val Metric:  0.420 | epoch time: 16.988 |
# Epoch 025: | Train loss:  0.615 | Val loss:  2.075 | Train Metric:  0.811 | Val Metric:  0.438 | epoch time: 16.901 |
# Epoch 026: | Train loss:  0.581 | Val loss:  2.026 | Train Metric:  0.825 | Val Metric:  0.435 | epoch time: 17.120 |
# Epoch 027: | Train loss:  0.548 | Val loss:  2.143 | Train Metric:  0.834 | Val Metric:  0.442 | epoch time: 17.540 |
# Epoch 028: | Train loss:  0.505 | Val loss:  2.075 | Train Metric:  0.853 | Val Metric:  0.485 | epoch time: 17.039 | <-- Checkpoint!
# Epoch 029: | Train loss:  0.510 | Val loss:  2.110 | Train Metric:  0.843 | Val Metric:  0.456 | epoch time: 16.972 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 030: | Train loss:  0.473 | Val loss:  1.919 | Train Metric:  0.865 | Val Metric:  0.469 | epoch time: 16.843 |
# Epoch 031: | Train loss:  0.439 | Val loss:  1.865 | Train Metric:  0.878 | Val Metric:  0.491 | epoch time: 17.104 | <-- Checkpoint!
# Epoch 032: | Train loss:  0.439 | Val loss:  2.055 | Train Metric:  0.870 | Val Metric:  0.469 | epoch time: 17.123 |
# Epoch 033: | Train loss:  0.441 | Val loss:  2.287 | Train Metric:  0.876 | Val Metric:  0.431 | epoch time: 17.020 |
# Epoch 034: | Train loss:  0.405 | Val loss:  2.261 | Train Metric:  0.885 | Val Metric:  0.453 | epoch time: 17.490 |
# Epoch 035: | Train loss:  0.383 | Val loss:  2.196 | Train Metric:  0.900 | Val Metric:  0.460 | epoch time: 16.957 |
# Epoch 036: | Train loss:  0.371 | Val loss:  2.135 | Train Metric:  0.898 | Val Metric:  0.453 | epoch time: 16.968 |
# Epoch 037: | Train loss:  0.344 | Val loss:  2.160 | Train Metric:  0.911 | Val Metric:  0.453 | epoch time: 16.902 |
# Epoch 038: | Train loss:  0.326 | Val loss:  2.143 | Train Metric:  0.918 | Val Metric:  0.480 | epoch time: 16.944 |
# Epoch 039: | Train loss:  0.346 | Val loss:  2.315 | Train Metric:  0.909 | Val Metric:  0.451 | epoch time: 16.810 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 040: | Train loss:  0.324 | Val loss:  2.066 | Train Metric:  0.921 | Val Metric:  0.507 | epoch time: 16.893 | <-- Checkpoint!
# Epoch 041: | Train loss:  0.300 | Val loss:  2.192 | Train Metric:  0.923 | Val Metric:  0.479 | epoch time: 17.177 |
# Epoch 042: | Train loss:  0.306 | Val loss:  2.267 | Train Metric:  0.922 | Val Metric:  0.461 | epoch time: 17.061 |
# Epoch 043: | Train loss:  0.280 | Val loss:  2.264 | Train Metric:  0.938 | Val Metric:  0.484 | epoch time: 16.805 |
# Epoch 044: | Train loss:  0.287 | Val loss:  2.080 | Train Metric:  0.932 | Val Metric:  0.482 | epoch time: 16.977 |
# Epoch 045: | Train loss:  0.277 | Val loss:  2.242 | Train Metric:  0.934 | Val Metric:  0.453 | epoch time: 16.776 |
# Epoch 046: | Train loss:  0.269 | Val loss:  2.247 | Train Metric:  0.937 | Val Metric:  0.475 | epoch time: 16.728 |
# Epoch 047: | Train loss:  0.278 | Val loss:  2.151 | Train Metric:  0.937 | Val Metric:  0.484 | epoch time: 16.879 |
# Epoch 048: | Train loss:  0.244 | Val loss:  2.252 | Train Metric:  0.948 | Val Metric:  0.471 | epoch time: 17.319 |
# Epoch 049: | Train loss:  0.250 | Val loss:  2.162 | Train Metric:  0.948 | Val Metric:  0.497 | epoch time: 16.974 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 050: | Train loss:  0.238 | Val loss:  2.172 | Train Metric:  0.952 | Val Metric:  0.488 | epoch time: 16.794 |
# Epoch 051: | Train loss:  0.220 | Val loss:  2.112 | Train Metric:  0.960 | Val Metric:  0.496 | epoch time: 16.676 |
# Epoch 052: | Train loss:  0.231 | Val loss:  1.926 | Train Metric:  0.950 | Val Metric:  0.531 | epoch time: 16.790 | <-- Checkpoint!
# Epoch 053: | Train loss:  0.234 | Val loss:  2.097 | Train Metric:  0.949 | Val Metric:  0.495 | epoch time: 16.917 |
# Epoch 054: | Train loss:  0.205 | Val loss:  2.250 | Train Metric:  0.958 | Val Metric:  0.462 | epoch time: 16.768 |
# Epoch 055: | Train loss:  0.222 | Val loss:  2.131 | Train Metric:  0.957 | Val Metric:  0.505 | epoch time: 17.451 |
# Epoch 056: | Train loss:  0.194 | Val loss:  2.112 | Train Metric:  0.967 | Val Metric:  0.478 | epoch time: 16.997 |
# Epoch 057: | Train loss:  0.181 | Val loss:  2.241 | Train Metric:  0.971 | Val Metric:  0.461 | epoch time: 16.744 |
# Epoch 058: | Train loss:  0.191 | Val loss:  2.185 | Train Metric:  0.967 | Val Metric:  0.498 | epoch time: 16.836 |
# Epoch 059: | Train loss:  0.185 | Val loss:  2.177 | Train Metric:  0.968 | Val Metric:  0.479 | epoch time: 16.791 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 060: | Train loss:  0.180 | Val loss:  2.029 | Train Metric:  0.975 | Val Metric:  0.494 | epoch time: 16.797 |
# Epoch 061: | Train loss:  0.167 | Val loss:  2.156 | Train Metric:  0.977 | Val Metric:  0.488 | epoch time: 16.793 |
# Epoch 062: | Train loss:  0.167 | Val loss:  2.100 | Train Metric:  0.977 | Val Metric:  0.481 | epoch time: 16.655 |
# Epoch 063: | Train loss:  0.156 | Val loss:  2.101 | Train Metric:  0.980 | Val Metric:  0.496 | epoch time: 17.265 |
# Epoch 064: | Train loss:  0.151 | Val loss:  2.144 | Train Metric:  0.981 | Val Metric:  0.483 | epoch time: 16.989 |
# Epoch 065: | Train loss:  0.163 | Val loss:  2.032 | Train Metric:  0.977 | Val Metric:  0.513 | epoch time: 16.769 |
# Epoch 066: | Train loss:  0.170 | Val loss:  2.013 | Train Metric:  0.975 | Val Metric:  0.503 | epoch time: 16.966 |
# Epoch 067: | Train loss:  0.148 | Val loss:  2.076 | Train Metric:  0.984 | Val Metric:  0.499 | epoch time: 16.715 |
# Epoch 068: | Train loss:  0.141 | Val loss:  2.009 | Train Metric:  0.987 | Val Metric:  0.507 | epoch time: 16.850 |
# Epoch 069: | Train loss:  0.137 | Val loss:  2.113 | Train Metric:  0.986 | Val Metric:  0.479 | epoch time: 16.780 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 070: | Train loss:  0.143 | Val loss:  2.154 | Train Metric:  0.986 | Val Metric:  0.495 | epoch time: 17.145 |
# Epoch 071: | Train loss:  0.131 | Val loss:  2.082 | Train Metric:  0.991 | Val Metric:  0.499 | epoch time: 17.167 |
# Epoch 072: | Train loss:  0.130 | Val loss:  2.013 | Train Metric:  0.988 | Val Metric:  0.494 | epoch time: 16.761 |
# Epoch 073: | Train loss:  0.131 | Val loss:  2.040 | Train Metric:  0.991 | Val Metric:  0.494 | epoch time: 16.827 |
# Epoch 074: | Train loss:  0.124 | Val loss:  2.062 | Train Metric:  0.993 | Val Metric:  0.490 | epoch time: 16.709 |
# Epoch 075: | Train loss:  0.128 | Val loss:  2.028 | Train Metric:  0.989 | Val Metric:  0.494 | epoch time: 16.694 |
# Epoch 076: | Train loss:  0.127 | Val loss:  2.065 | Train Metric:  0.990 | Val Metric:  0.482 | epoch time: 16.718 |
# Epoch 077: | Train loss:  0.126 | Val loss:  2.019 | Train Metric:  0.991 | Val Metric:  0.503 | epoch time: 17.138 |
# Epoch 078: | Train loss:  0.127 | Val loss:  2.058 | Train Metric:  0.990 | Val Metric:  0.494 | epoch time: 17.179 |
# Epoch 079: | Train loss:  0.120 | Val loss:  1.954 | Train Metric:  0.993 | Val Metric:  0.513 | epoch time: 16.729 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 080: | Train loss:  0.115 | Val loss:  1.989 | Train Metric:  0.995 | Val Metric:  0.498 | epoch time: 16.739 |
# Epoch 081: | Train loss:  0.118 | Val loss:  2.010 | Train Metric:  0.994 | Val Metric:  0.503 | epoch time: 16.759 |
# Epoch 082: | Train loss:  0.116 | Val loss:  1.957 | Train Metric:  0.993 | Val Metric:  0.514 | epoch time: 16.826 |
# Epoch 083: | Train loss:  0.114 | Val loss:  1.931 | Train Metric:  0.995 | Val Metric:  0.508 | epoch time: 16.783 |
# Epoch 084: | Train loss:  0.113 | Val loss:  1.955 | Train Metric:  0.995 | Val Metric:  0.505 | epoch time: 17.120 |
# Epoch 085: | Train loss:  0.109 | Val loss:  1.950 | Train Metric:  0.997 | Val Metric:  0.508 | epoch time: 17.336 |
# Epoch 086: | Train loss:  0.109 | Val loss:  1.972 | Train Metric:  0.996 | Val Metric:  0.509 | epoch time: 16.795 |
# Epoch 087: | Train loss:  0.107 | Val loss:  1.992 | Train Metric:  0.997 | Val Metric:  0.503 | epoch time: 16.806 |
# Epoch 088: | Train loss:  0.108 | Val loss:  1.964 | Train Metric:  0.996 | Val Metric:  0.505 | epoch time: 16.788 |
# Epoch 089: | Train loss:  0.106 | Val loss:  1.957 | Train Metric:  0.997 | Val Metric:  0.500 | epoch time: 16.829 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 090: | Train loss:  0.106 | Val loss:  1.980 | Train Metric:  0.998 | Val Metric:  0.497 | epoch time: 16.857 |
# Epoch 091: | Train loss:  0.103 | Val loss:  1.991 | Train Metric:  0.998 | Val Metric:  0.503 | epoch time: 17.128 |
# Epoch 092: | Train loss:  0.107 | Val loss:  2.003 | Train Metric:  0.997 | Val Metric:  0.502 | epoch time: 17.269 |
# Epoch 093: | Train loss:  0.104 | Val loss:  1.982 | Train Metric:  0.998 | Val Metric:  0.499 | epoch time: 16.781 |
# Epoch 094: | Train loss:  0.103 | Val loss:  1.983 | Train Metric:  0.998 | Val Metric:  0.500 | epoch time: 16.698 |
# Epoch 095: | Train loss:  0.102 | Val loss:  1.981 | Train Metric:  0.999 | Val Metric:  0.500 | epoch time: 16.936 |
# Epoch 096: | Train loss:  0.104 | Val loss:  1.982 | Train Metric:  0.998 | Val Metric:  0.496 | epoch time: 16.904 |
# Epoch 097: | Train loss:  0.107 | Val loss:  1.976 | Train Metric:  0.996 | Val Metric:  0.508 | epoch time: 17.070 |
# Epoch 098: | Train loss:  0.103 | Val loss:  1.977 | Train Metric:  0.999 | Val Metric:  0.503 | epoch time: 17.117 |
# Epoch 099: | Train loss:  0.104 | Val loss:  1.964 | Train Metric:  0.997 | Val Metric:  0.501 | epoch time: 17.215 |

# %%
from DeepLearningFramework.Auxiliary import PlotHistory

PlotHistory(lHistory)
plt.show   ()

# %% [markdown]
# ### Predict
# * The model input is a 3 second long signal.
# * Given a full signal (~30 seconds) we split it into windows of 3 seconds.
# * We predict each window and take the average.

# %%
def Predict(oModel, vX):
    mS = Spectrogram(vX).T
    mX  = torch.stack(torch.split(mS, L, dim=0)[:-1])
        
    with torch.no_grad():
        
        mZ   = oModel(mX[:,:,:].to(DEVICE))
        yHat = mZ.softmax(1).mean(0).argmax()
        
    return yHat

# %% [markdown]
# #### Confusion matrix:

# %%
nTest = len(oTestSet)
vY    = torch.empty(nTest)
vHatY = torch.empty(nTest)

for ii, (vX, Fs, label) in enumerate(oTestSet):
    vY   [ii] = oLabelEncoder.transform([label])[0]
    vHatY[ii] = Predict(oModel, vX[0])

(vHatY == vY).float().mean()
# Out:
# tensor(0.5685)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

#-- Compute confusion matrices:
mConfusion = confusion_matrix(vY.cpu(), vHatY.cpu())

_, ax = plt.subplots(1, 1, figsize=(16,7))
ConfusionMatrixDisplay(mConfusion, display_labels=oLabelEncoder.classes_).plot(values_format='g', ax=ax)

mean = (vY.cpu() == vHatY.cpu()).float().mean().item()
ax.set_title    (f'Accuracy: {mean}')
plt.tight_layout()
plt.show        ()
