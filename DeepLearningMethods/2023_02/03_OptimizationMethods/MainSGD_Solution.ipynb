# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Lecture 3 - Optimization Methods </center>
# ### <center> Stochastic Gradient Descent (SGD) - Solution </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/03_OptimizationMethods/MainSGD_Solution.ipynb)

# %%
#-- Wide screen:
from IPython.display import HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

np.random.seed(0)

# %% [markdown]
# For Colab users:

# %%
if 'google.colab' in str(get_ipython()):
    # !wget https://raw.githubusercontent.com/FixelAlgorithmsTeam/FixelCourses/master/DeepLearningMethods/03_OptimizationMethods/SGD_Aux.py

# %%
#-- What we have so far:
from SGD_Aux import LinearLayer, ReLULayer, SequentialModel, CrossEntropyLoss, Accuracy

# %% [markdown]
# #### Get Fashion MNIST dataset

# %%
import torchvision
import torchvision.transforms as transforms

#-- For now, we use PyTorch just to get the data:
oTrainSet = torchvision.datasets.FashionMNIST(root='../../data', train=True,  download=True, transform=transforms.ToTensor())
oTestSet  = torchvision.datasets.FashionMNIST(root='../../data', train=False, download=True, transform=transforms.ToTensor())

lClasses = oTrainSet.classes
mTrainX  = oTrainSet.data.view(-1,784).numpy() / 255
mTestX   = oTestSet .data.view(-1,784).numpy() / 255
vTrainY  = oTrainSet.targets.numpy()
vTestY   = oTestSet .targets.numpy()

(
mTrainX.shape, 
vTrainY.shape, 
mTestX .shape,  
vTestY .shape
)
# Out:
# ((60000, 784), (60000,), (10000, 784), (10000,))

# %%
#-- Plot a few examples:
N, d   = mTrainX.shape
fig, _ = plt.subplots(2, 3, figsize=(8, 4))
for ax in fig.axes:
    idx = np.random.randint(N)
    ax.imshow   (np.reshape(mTrainX[idx,:], (28, 28)), cmap='gray')
    ax.set_title(f'True label: {lClasses[vTrainY[idx]]}')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ####  Normalize data:

# %%
vMean = mTrainX.mean(0)
vStd  = mTrainX.std (0)

mTrainX -= vMean
mTestX  -= vMean
mTrainX /= vStd
mTestX  /= vStd

# %% [markdown]
# ### Exercise
# * Add a drop last flag (`bDropLast`):
#     * If `bDropLast = False` then the last non-full batch is also returned in the iterations.
# * Update `TrainEpoch` and `ValidationEpoch` accordingly
#
# **Extra**: Play with the model (and the hyper-parameters) and improve your validation accuracy.

# %%
class Dataset:
    def __init__(self, mX, vY, batchSize, bDropLast=False):
        self.mX        = mX
        self.vY        = vY
        self.N         = len(vY)
        self.batchSize = min(batchSize, self.N)
        self.nBatches  = np.ceil(self.N / self.batchSize).astype(np.int32)

    def __len__(self):
        return self.nBatches

    #-- Loop over mini-batches:
    def __iter__(self):
        vIdx = np.random.permutation(self.N)

        for ii in range(self.nBatches):
            startIdx  = ii * self.batchSize
            vBatchIdx = vIdx[startIdx : startIdx + self.batchSize]
            mBatchX   = self.mX[:,vBatchIdx]
            vBatchY   = self.vY[vBatchIdx]

            yield mBatchX, vBatchY

# %%
batchSize = 256
oTrainSet = Dataset(mTrainX.T, vTrainY, batchSize)
oTestSet  = Dataset(mTestX.T,  vTestY,  batchSize)

# %% [markdown]
# #### Test your implementation
# You should get $4$ batches, where the last one is not full.

# %%
batchSize = 15
oDataset  = Dataset(mTrainX[:55,:].T, vTrainY[:55], batchSize)
for ii, (mXi, vYi) in enumerate(oDataset):
    print(f'mX_{ii}.shape = {mXi.shape}, vY_{ii}.shape = {vYi.shape}')
    
print(f'Dataset length = {len(oDataset)}')
# Out:
# mX_0.shape = (784, 15), vY_0.shape = (15,)
# mX_1.shape = (784, 15), vY_1.shape = (15,)
# mX_2.shape = (784, 15), vY_2.shape = (15,)
# mX_3.shape = (784, 10), vY_3.shape = (10,)
# Dataset length = 4

# %% [markdown]
# #### Update `TrainEpoch` and `ValidationEpoch`
# * Remember that each mini-batch might be of a different size.
# * Use `len(vY)` to get the current batch size.

# %%
import time

def TrainEpoch(oModel, oTrainData, learningRate):
    
    epochLoss = 0
    epochAcc  = 0
    count     = 0

    #-- Iterate over the mini-batches:
    for ii, (mX, vY) in enumerate(oTrainData):
        
        Nb     = len(vY) #-- currect batch size
        count += Nb
        
        #-- Forward:
        mZ        = oModel.Forward(mX)
        loss, mDz = CrossEntropyLoss(vY, mZ)

        #-- Backward:
        oModel.Backward(mDz)

        #-- Update parameters (stochasitc gradient descnet):
        for oLayer in oModel.lLayers:
            for sParam in oLayer.dGrads:
                oLayer.dParams[sParam] -= learningRate * oLayer.dGrads[sParam]
        
        epochLoss += Nb * loss
        epochAcc  += Nb * Accuracy(mZ, vY)
        print(f'\rIteration: {ii:3d}: loss = {loss:2.6f}', end='')
    
    print('', end='\r')
    epochLoss /= count
    epochAcc  /= count
    
    return epochLoss, epochAcc

#--------------------------------------------------------------------------------#
#--------------------------------------------------------------------------------#
def ValidationEpoch(oModel, oValData):
    
    epochLoss = 0
    epochAcc  = 0
    count     = 0
    
    #-- Iterate over the mini-batches:
    for ii, (mX, vY) in enumerate(oValData):
        
        Nb     = len(vY) #-- currect batch size
        count += Nb
        
        #-- Forward:
        mZ      = oModel.Forward(mX)
        loss, _ = CrossEntropyLoss(vY, mZ)
               
        epochLoss += Nb * loss
        epochAcc  += Nb * Accuracy(mZ, vY)
    
    epochLoss /= count
    epochAcc  /= count
    
    return epochLoss, epochAcc

# %% [markdown]
# #### Train model function:

# %%
def TrainModel(oModel, oTrainData, oValData, numEpochs, learningRate):
    for epoch in range(numEpochs):
        startTime           = time.time()
        trainLoss, trainAcc = TrainEpoch     (oModel, oTrainData, learningRate) #-- train
        valLoss,   valAcc   = ValidationEpoch(oModel, oValData)                 #-- validation
        epochTime           = time.time() - startTime

        #-- Display:
        print('Epoch '              f'{epoch    :3d}:',  end='')
        print(' | Train loss: '     f'{trainLoss:6.3f}', end='')
        print(' | Val loss: '       f'{valLoss  :6.3f}', end='')
        print(' | Train Accuracy: ' f'{trainAcc :6.3f}', end='')
        print(' | Val Accuracy: '   f'{valAcc   :6.3f}', end='')
        print(' | epoch time: '     f'{epochTime:6.3f} |')

# %% [markdown]
# #### Improve your accuracy:

# %%
oModel = SequentialModel([
        LinearLayer(784, 200), ReLULayer(),
        LinearLayer(200,  10, init='Xavier'),
])

nEpochs = 100
lr      = 2e-2

TrainModel(oModel, oTrainSet, oTestSet, nEpochs, lr)
# Out:
# Epoch   0: | Train loss:  0.749 | Val loss:  0.579 | Train Accuracy:  0.746 | Val Accuracy:  0.797 | epoch time:  0.928 |
# Epoch   1: | Train loss:  0.499 | Val loss:  0.499 | Train Accuracy:  0.825 | Val Accuracy:  0.825 | epoch time:  0.923 |
# Epoch   2: | Train loss:  0.445 | Val loss:  0.467 | Train Accuracy:  0.844 | Val Accuracy:  0.834 | epoch time:  0.907 |
# Epoch   3: | Train loss:  0.417 | Val loss:  0.449 | Train Accuracy:  0.854 | Val Accuracy:  0.841 | epoch time:  0.937 |
# Epoch   4: | Train loss:  0.397 | Val loss:  0.435 | Train Accuracy:  0.861 | Val Accuracy:  0.844 | epoch time:  0.931 |
# Epoch   5: | Train loss:  0.382 | Val loss:  0.424 | Train Accuracy:  0.865 | Val Accuracy:  0.848 | epoch time:  0.923 |
# Epoch   6: | Train loss:  0.371 | Val loss:  0.415 | Train Accuracy:  0.869 | Val Accuracy:  0.853 | epoch time:  0.972 |
# Epoch   7: | Train loss:  0.361 | Val loss:  0.411 | Train Accuracy:  0.873 | Val Accuracy:  0.853 | epoch time:  0.921 |
# Epoch   8: | Train loss:  0.352 | Val loss:  0.402 | Train Accuracy:  0.875 | Val Accuracy:  0.856 | epoch time:  0.911 |
# Epoch   9: | Train loss:  0.345 | Val loss:  0.398 | Train Accuracy:  0.878 | Val Accuracy:  0.859 | epoch time:  0.887 |
# Epoch  10: | Train loss:  0.338 | Val loss:  0.393 | Train Accuracy:  0.880 | Val Accuracy:  0.860 | epoch time:  0.911 |
# Epoch  11: | Train loss:  0.332 | Val loss:  0.389 | Train Accuracy:  0.882 | Val Accuracy:  0.861 | epoch time:  0.921 |
# Epoch  12: | Train loss:  0.326 | Val loss:  0.386 | Train Accuracy:  0.885 | Val Accuracy:  0.862 | epoch time:  0.989 |
# Epoch  13: | Train loss:  0.320 | Val loss:  0.384 | Train Accuracy:  0.887 | Val Accuracy:  0.864 | epoch time:  0.929 |
# Epoch  14: | Train loss:  0.316 | Val loss:  0.380 | Train Accuracy:  0.888 | Val Accuracy:  0.865 | epoch time:  0.999 |
# Epoch  15: | Train loss:  0.311 | Val loss:  0.377 | Train Accuracy:  0.889 | Val Accuracy:  0.865 | epoch time:  0.968 |
# Epoch  16: | Train loss:  0.307 | Val loss:  0.376 | Train Accuracy:  0.891 | Val Accuracy:  0.866 | epoch time:  0.935 |
# Epoch  17: | Train loss:  0.302 | Val loss:  0.374 | Train Accuracy:  0.893 | Val Accuracy:  0.865 | epoch time:  0.993 |
# Epoch  18: | Train loss:  0.298 | Val loss:  0.371 | Train Accuracy:  0.894 | Val Accuracy:  0.869 | epoch time:  0.982 |
# Epoch  19: | Train loss:  0.294 | Val loss:  0.367 | Train Accuracy:  0.895 | Val Accuracy:  0.869 | epoch time:  0.951 |
# Epoch  20: | Train loss:  0.291 | Val loss:  0.367 | Train Accuracy:  0.897 | Val Accuracy:  0.871 | epoch time:  0.965 |
# Epoch  21: | Train loss:  0.287 | Val loss:  0.366 | Train Accuracy:  0.898 | Val Accuracy:  0.867 | epoch time:  0.931 |
# Epoch  22: | Train loss:  0.283 | Val loss:  0.362 | Train Accuracy:  0.900 | Val Accuracy:  0.872 | epoch time:  0.975 |
# Epoch  23: | Train loss:  0.280 | Val loss:  0.360 | Train Accuracy:  0.901 | Val Accuracy:  0.871 | epoch time:  1.022 |
# Epoch  24: | Train loss:  0.277 | Val loss:  0.359 | Train Accuracy:  0.902 | Val Accuracy:  0.872 | epoch time:  0.940 |
# Epoch  25: | Train loss:  0.274 | Val loss:  0.357 | Train Accuracy:  0.903 | Val Accuracy:  0.872 | epoch time:  1.001 |
# Epoch  26: | Train loss:  0.271 | Val loss:  0.357 | Train Accuracy:  0.904 | Val Accuracy:  0.871 | epoch time:  0.998 |
# Epoch  27: | Train loss:  0.268 | Val loss:  0.355 | Train Accuracy:  0.905 | Val Accuracy:  0.870 | epoch time:  0.947 |
# Epoch  28: | Train loss:  0.265 | Val loss:  0.353 | Train Accuracy:  0.906 | Val Accuracy:  0.874 | epoch time:  0.958 |
# Epoch  29: | Train loss:  0.262 | Val loss:  0.352 | Train Accuracy:  0.907 | Val Accuracy:  0.874 | epoch time:  0.988 |
# Epoch  30: | Train loss:  0.260 | Val loss:  0.351 | Train Accuracy:  0.908 | Val Accuracy:  0.874 | epoch time:  0.996 |
# Epoch  31: | Train loss:  0.257 | Val loss:  0.351 | Train Accuracy:  0.909 | Val Accuracy:  0.875 | epoch time:  1.058 |
# Epoch  32: | Train loss:  0.254 | Val loss:  0.349 | Train Accuracy:  0.911 | Val Accuracy:  0.875 | epoch time:  0.972 |
# Epoch  33: | Train loss:  0.251 | Val loss:  0.349 | Train Accuracy:  0.912 | Val Accuracy:  0.873 | epoch time:  0.919 |
# Epoch  34: | Train loss:  0.249 | Val loss:  0.349 | Train Accuracy:  0.913 | Val Accuracy:  0.874 | epoch time:  0.968 |
# Epoch  35: | Train loss:  0.246 | Val loss:  0.347 | Train Accuracy:  0.914 | Val Accuracy:  0.874 | epoch time:  0.951 |
# Epoch  36: | Train loss:  0.244 | Val loss:  0.345 | Train Accuracy:  0.914 | Val Accuracy:  0.876 | epoch time:  0.952 |
# Epoch  37: | Train loss:  0.242 | Val loss:  0.344 | Train Accuracy:  0.915 | Val Accuracy:  0.875 | epoch time:  0.919 |
# Epoch  38: | Train loss:  0.239 | Val loss:  0.345 | Train Accuracy:  0.917 | Val Accuracy:  0.877 | epoch time:  0.915 |
# Epoch  39: | Train loss:  0.237 | Val loss:  0.343 | Train Accuracy:  0.917 | Val Accuracy:  0.879 | epoch time:  0.951 |
# Epoch  40: | Train loss:  0.235 | Val loss:  0.343 | Train Accuracy:  0.918 | Val Accuracy:  0.877 | epoch time:  0.954 |
# Epoch  41: | Train loss:  0.232 | Val loss:  0.341 | Train Accuracy:  0.919 | Val Accuracy:  0.876 | epoch time:  0.962 |
# Epoch  42: | Train loss:  0.230 | Val loss:  0.341 | Train Accuracy:  0.920 | Val Accuracy:  0.877 | epoch time:  0.918 |
# Epoch  43: | Train loss:  0.228 | Val loss:  0.343 | Train Accuracy:  0.920 | Val Accuracy:  0.878 | epoch time:  0.975 |
# Epoch  44: | Train loss:  0.226 | Val loss:  0.341 | Train Accuracy:  0.921 | Val Accuracy:  0.878 | epoch time:  0.934 |
# Epoch  45: | Train loss:  0.224 | Val loss:  0.339 | Train Accuracy:  0.922 | Val Accuracy:  0.878 | epoch time:  0.960 |
# Epoch  46: | Train loss:  0.222 | Val loss:  0.340 | Train Accuracy:  0.923 | Val Accuracy:  0.878 | epoch time:  0.939 |
# Epoch  47: | Train loss:  0.220 | Val loss:  0.339 | Train Accuracy:  0.924 | Val Accuracy:  0.880 | epoch time:  0.930 |
# Epoch  48: | Train loss:  0.217 | Val loss:  0.341 | Train Accuracy:  0.925 | Val Accuracy:  0.878 | epoch time:  0.967 |
# Epoch  49: | Train loss:  0.216 | Val loss:  0.337 | Train Accuracy:  0.925 | Val Accuracy:  0.881 | epoch time:  0.938 |
# Epoch  50: | Train loss:  0.213 | Val loss:  0.338 | Train Accuracy:  0.927 | Val Accuracy:  0.879 | epoch time:  0.942 |
# Epoch  51: | Train loss:  0.212 | Val loss:  0.341 | Train Accuracy:  0.927 | Val Accuracy:  0.881 | epoch time:  0.949 |
# Epoch  52: | Train loss:  0.210 | Val loss:  0.338 | Train Accuracy:  0.928 | Val Accuracy:  0.879 | epoch time:  1.014 |
# Epoch  53: | Train loss:  0.208 | Val loss:  0.345 | Train Accuracy:  0.928 | Val Accuracy:  0.878 | epoch time:  0.951 |
# Epoch  54: | Train loss:  0.206 | Val loss:  0.340 | Train Accuracy:  0.929 | Val Accuracy:  0.878 | epoch time:  0.944 |
# Epoch  55: | Train loss:  0.204 | Val loss:  0.341 | Train Accuracy:  0.930 | Val Accuracy:  0.881 | epoch time:  0.959 |
# Epoch  56: | Train loss:  0.202 | Val loss:  0.336 | Train Accuracy:  0.931 | Val Accuracy:  0.880 | epoch time:  0.908 |
# Epoch  57: | Train loss:  0.201 | Val loss:  0.339 | Train Accuracy:  0.932 | Val Accuracy:  0.881 | epoch time:  0.941 |
# Epoch  58: | Train loss:  0.199 | Val loss:  0.336 | Train Accuracy:  0.932 | Val Accuracy:  0.882 | epoch time:  0.940 |
# Epoch  59: | Train loss:  0.197 | Val loss:  0.338 | Train Accuracy:  0.932 | Val Accuracy:  0.881 | epoch time:  0.974 |
# Epoch  60: | Train loss:  0.196 | Val loss:  0.337 | Train Accuracy:  0.934 | Val Accuracy:  0.882 | epoch time:  0.978 |
# Epoch  61: | Train loss:  0.194 | Val loss:  0.336 | Train Accuracy:  0.934 | Val Accuracy:  0.882 | epoch time:  0.922 |
# Epoch  62: | Train loss:  0.192 | Val loss:  0.336 | Train Accuracy:  0.935 | Val Accuracy:  0.883 | epoch time:  0.939 |
# Epoch  63: | Train loss:  0.190 | Val loss:  0.337 | Train Accuracy:  0.935 | Val Accuracy:  0.881 | epoch time:  0.913 |
# Epoch  64: | Train loss:  0.189 | Val loss:  0.338 | Train Accuracy:  0.936 | Val Accuracy:  0.882 | epoch time:  0.927 |
# Epoch  65: | Train loss:  0.187 | Val loss:  0.336 | Train Accuracy:  0.936 | Val Accuracy:  0.882 | epoch time:  0.923 |
# Epoch  66: | Train loss:  0.185 | Val loss:  0.336 | Train Accuracy:  0.936 | Val Accuracy:  0.885 | epoch time:  0.964 |
# Epoch  67: | Train loss:  0.184 | Val loss:  0.341 | Train Accuracy:  0.938 | Val Accuracy:  0.881 | epoch time:  0.936 |
# Epoch  68: | Train loss:  0.183 | Val loss:  0.335 | Train Accuracy:  0.939 | Val Accuracy:  0.883 | epoch time:  0.986 |
# Epoch  69: | Train loss:  0.181 | Val loss:  0.336 | Train Accuracy:  0.938 | Val Accuracy:  0.882 | epoch time:  0.976 |
# Epoch  70: | Train loss:  0.179 | Val loss:  0.335 | Train Accuracy:  0.939 | Val Accuracy:  0.883 | epoch time:  0.949 |
# Epoch  71: | Train loss:  0.178 | Val loss:  0.334 | Train Accuracy:  0.940 | Val Accuracy:  0.885 | epoch time:  0.914 |
# Epoch  72: | Train loss:  0.176 | Val loss:  0.337 | Train Accuracy:  0.941 | Val Accuracy:  0.884 | epoch time:  0.946 |
# Epoch  73: | Train loss:  0.175 | Val loss:  0.339 | Train Accuracy:  0.942 | Val Accuracy:  0.881 | epoch time:  0.921 |
# Epoch  74: | Train loss:  0.173 | Val loss:  0.336 | Train Accuracy:  0.942 | Val Accuracy:  0.884 | epoch time:  0.960 |
# Epoch  75: | Train loss:  0.172 | Val loss:  0.336 | Train Accuracy:  0.942 | Val Accuracy:  0.884 | epoch time:  0.944 |
# Epoch  76: | Train loss:  0.170 | Val loss:  0.337 | Train Accuracy:  0.943 | Val Accuracy:  0.884 | epoch time:  0.917 |
# Epoch  77: | Train loss:  0.169 | Val loss:  0.340 | Train Accuracy:  0.944 | Val Accuracy:  0.882 | epoch time:  0.939 |
# Epoch  78: | Train loss:  0.167 | Val loss:  0.338 | Train Accuracy:  0.944 | Val Accuracy:  0.884 | epoch time:  0.929 |
# Epoch  79: | Train loss:  0.166 | Val loss:  0.339 | Train Accuracy:  0.945 | Val Accuracy:  0.885 | epoch time:  0.916 |
# Epoch  80: | Train loss:  0.164 | Val loss:  0.337 | Train Accuracy:  0.946 | Val Accuracy:  0.886 | epoch time:  0.985 |
# Epoch  81: | Train loss:  0.163 | Val loss:  0.341 | Train Accuracy:  0.945 | Val Accuracy:  0.883 | epoch time:  0.970 |
# Epoch  82: | Train loss:  0.162 | Val loss:  0.340 | Train Accuracy:  0.947 | Val Accuracy:  0.885 | epoch time:  0.905 |
# Epoch  83: | Train loss:  0.160 | Val loss:  0.338 | Train Accuracy:  0.947 | Val Accuracy:  0.885 | epoch time:  0.915 |
# Epoch  84: | Train loss:  0.159 | Val loss:  0.339 | Train Accuracy:  0.947 | Val Accuracy:  0.885 | epoch time:  0.946 |
# Epoch  85: | Train loss:  0.158 | Val loss:  0.344 | Train Accuracy:  0.949 | Val Accuracy:  0.884 | epoch time:  0.969 |
# Epoch  86: | Train loss:  0.156 | Val loss:  0.341 | Train Accuracy:  0.948 | Val Accuracy:  0.885 | epoch time:  0.918 |
# Epoch  87: | Train loss:  0.155 | Val loss:  0.340 | Train Accuracy:  0.950 | Val Accuracy:  0.885 | epoch time:  0.992 |
# Epoch  88: | Train loss:  0.154 | Val loss:  0.345 | Train Accuracy:  0.951 | Val Accuracy:  0.882 | epoch time:  0.922 |
# Epoch  89: | Train loss:  0.153 | Val loss:  0.342 | Train Accuracy:  0.950 | Val Accuracy:  0.885 | epoch time:  0.943 |
# Epoch  90: | Train loss:  0.152 | Val loss:  0.342 | Train Accuracy:  0.951 | Val Accuracy:  0.884 | epoch time:  0.944 |
# Epoch  91: | Train loss:  0.150 | Val loss:  0.340 | Train Accuracy:  0.951 | Val Accuracy:  0.888 | epoch time:  0.951 |
# Epoch  92: | Train loss:  0.149 | Val loss:  0.343 | Train Accuracy:  0.952 | Val Accuracy:  0.886 | epoch time:  0.967 |
# Epoch  93: | Train loss:  0.148 | Val loss:  0.345 | Train Accuracy:  0.953 | Val Accuracy:  0.885 | epoch time:  0.918 |
# Epoch  94: | Train loss:  0.146 | Val loss:  0.343 | Train Accuracy:  0.953 | Val Accuracy:  0.886 | epoch time:  0.951 |
# Epoch  95: | Train loss:  0.145 | Val loss:  0.342 | Train Accuracy:  0.953 | Val Accuracy:  0.886 | epoch time:  0.982 |
# Epoch  96: | Train loss:  0.144 | Val loss:  0.357 | Train Accuracy:  0.953 | Val Accuracy:  0.879 | epoch time:  0.927 |
# Epoch  97: | Train loss:  0.143 | Val loss:  0.344 | Train Accuracy:  0.954 | Val Accuracy:  0.886 | epoch time:  0.921 |
# Epoch  98: | Train loss:  0.142 | Val loss:  0.345 | Train Accuracy:  0.955 | Val Accuracy:  0.885 | epoch time:  0.913 |
# Epoch  99: | Train loss:  0.140 | Val loss:  0.343 | Train Accuracy:  0.955 | Val Accuracy:  0.885 | epoch time:  0.931 |

# %%
#-- Apply model to data:
mHatTestY = oModel.Forward(mTestX.T)
print(f'Test accuracy: {100 * Accuracy(mHatTestY, vTestY)}%')

#-- Plot a few mistakes:
vHatTestY = np.argmax(mHatTestY, axis=0)
vWrongIdx = np.nonzero(vTestY != vHatTestY)[0]

N, d   = mTestX.shape
fig, _ = plt.subplots(2, 3, figsize=(8, 4))
for ax in fig.axes:
    idx = vWrongIdx[np.random.randint(0, len(vWrongIdx))]
    ax.imshow   (np.reshape(mTestX[idx,:] * vStd + vMean, (28, 28)), cmap='gray')
    ax.set_title(f'True label: {lClasses[vTestY[idx]]}\nEstimated label: {lClasses[vHatTestY[idx]]}', color='r')
    
plt.tight_layout()
plt.show()
# Out:
# Test accuracy: 88.5%
