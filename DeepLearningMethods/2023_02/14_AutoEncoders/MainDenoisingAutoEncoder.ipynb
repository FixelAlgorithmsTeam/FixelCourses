# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Lecture 14 - Auto-encoders </center>
# ### <center> Denoising Auto-encoders </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/14_AutoEncoders/MainDenoisingAutoEncoder.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# For Colab users:

# %%
if 'google.colab' in str(get_ipython()):
    # !pip install torchinfo
    # !npx degit FixelAlgorithmsTeam/FixelCourses/DeepLearningMethods/14_AutoEncoders/DeepLearningFramework ./DeepLearningFramework

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt

import torch
import torch.nn          as nn
import torch.optim       as optim
import torchinfo

torch.backends.cudnn.benchmark = True

# %% [markdown]
# #### Load MNIST data:

# %%
import torchvision.transforms as transforms
import torchvision

dataPath   = '../../data/'
oTrainSet_ = torchvision.datasets.MNIST(root=dataPath, train=True,  transform=transforms.ToTensor(), download=True)
oTestSet_  = torchvision.datasets.MNIST(root=dataPath, train=False, transform=transforms.ToTensor(), download=True)

# %% [markdown]
# #### Dataset:

# %%
    from torch.utils.data import Dataset

    if False:
        class NNISTDataset(Dataset):
            def __init__(self, oDataset, σ):
                self.oDataset = oDataset
                self.σ        = σ

            def __len__(self):
                return len(self.oDataset)

            def __getitem__(self, idx):
                mX, _ = self.oDataset[idx]
                mXN   = mX + self.σ * torch.randn_like(mX)

                return mXN, mX

# %%
from DeepLearningFramework.AEUtils import NNISTDataset

σ         = 0.4
oTrainSet = NNISTDataset(oTrainSet_, σ)
oTestSet  = NNISTDataset(oTestSet_,  σ)
mXN, mX   = oTrainSet[0]

_, ax   = plt.subplots(1, 2, figsize=(6, 3))
ax[0].matshow(mX .permute(1,2,0),             cmap='gray')
ax[1].matshow(mXN.permute(1,2,0).clamp(0, 1), cmap='gray')
plt.show     ()

# %%
batchSize = 128
oTrainDL  = torch.utils.data.DataLoader(oTrainSet, shuffle=True,  batch_size=1*batchSize, num_workers=2, persistent_workers=True)
oTestDL   = torch.utils.data.DataLoader(oTestSet,  shuffle=False, batch_size=2*batchSize, num_workers=2, persistent_workers=True)

mXN,       mX   = next(iter(oTrainDL))
mXN.shape, mX.shape
# Out:
# (torch.Size([128, 1, 28, 28]), torch.Size([128, 1, 28, 28]))

# %% [markdown]
# #### Encoder:

# %%
def GetEncoder():
    oEncoder = nn.Sequential(
        nn.Identity(),
        nn.Conv2d(1,  8,  kernel_size=3, bias=False), nn.BatchNorm2d(8 ), nn.ReLU(), 
        nn.Conv2d(8,  16, kernel_size=3, bias=False), nn.BatchNorm2d(16), nn.ReLU(),
        nn.Conv2d(16, 32, kernel_size=3, bias=False), nn.BatchNorm2d(32), nn.ReLU(),
        nn.Conv2d(32, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d(2),
        nn.Conv2d(64, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 64, kernel_size=3, bias=False), nn.BatchNorm2d(64), nn.ReLU(),
        nn.Conv2d(64, 16, kernel_size=1), 
        nn.Flatten()
    )
    
    return oEncoder

#=============================================================#
#=============================================================#
torchinfo.summary(GetEncoder(), (128, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               --                        --
# ├─Identity: 1-1                          [128, 1, 28, 28]          --
# ├─Conv2d: 1-2                            [128, 8, 26, 26]          72
# ├─BatchNorm2d: 1-3                       [128, 8, 26, 26]          16
# ├─ReLU: 1-4                              [128, 8, 26, 26]          --
# ├─Conv2d: 1-5                            [128, 16, 24, 24]         1,152
# ├─BatchNorm2d: 1-6                       [128, 16, 24, 24]         32
# ├─ReLU: 1-7                              [128, 16, 24, 24]         --
# ├─Conv2d: 1-8                            [128, 32, 22, 22]         4,608
# ├─BatchNorm2d: 1-9                       [128, 32, 22, 22]         64
# ├─ReLU: 1-10                             [128, 32, 22, 22]         --
# ├─Conv2d: 1-11                           [128, 64, 20, 20]         18,432
# ├─BatchNorm2d: 1-12                      [128, 64, 20, 20]         128
# ├─ReLU: 1-13                             [128, 64, 20, 20]         --
# ├─Conv2d: 1-14                           [128, 64, 18, 18]         36,864
# ├─BatchNorm2d: 1-15                      [128, 64, 18, 18]         128
# ├─ReLU: 1-16                             [128, 64, 18, 18]         --
# ├─MaxPool2d: 1-17                        [128, 64, 9, 9]           --
# ├─Conv2d: 1-18                           [128, 64, 7, 7]           36,864
# ├─BatchNorm2d: 1-19                      [128, 64, 7, 7]           128
# ├─ReLU: 1-20                             [128, 64, 7, 7]           --
# ├─Conv2d: 1-21                           [128, 64, 5, 5]           36,864
# ├─BatchNorm2d: 1-22                      [128, 64, 5, 5]           128
# ├─ReLU: 1-23                             [128, 64, 5, 5]           --
# ├─Conv2d: 1-24                           [128, 64, 3, 3]           36,864
# ├─BatchNorm2d: 1-25                      [128, 64, 3, 3]           128
# ├─ReLU: 1-26                             [128, 64, 3, 3]           --
# ├─Conv2d: 1-27                           [128, 64, 1, 1]           36,864
# ├─BatchNorm2d: 1-28                      [128, 64, 1, 1]           128
# ├─ReLU: 1-29                             [128, 64, 1, 1]           --
# ├─Conv2d: 1-30                           [128, 16, 1, 1]           1,040
# ├─Flatten: 1-31                          [128, 16]                 --
# ==========================================================================================
# Total params: 210,504
# Trainable params: 210,504
# Non-trainable params: 0
# Total mult-adds (G): 3.25
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 167.59
# Params size (MB): 0.84
# Estimated Total Size (MB): 168.84
# ==========================================================================================

# %% [markdown]
# #### Decoder:

# %%
from DeepLearningFramework.Layers import Reshape

def GetDecoder():
    oDecoder = nn.Sequential(
        nn.Identity(),
        nn.Unflatten(1, (16, 1, 1)),
        nn.Upsample(scale_factor=3), nn.Conv2d(16, 16, kernel_size=2, padding=1, bias=False), nn.BatchNorm2d(16), nn.ReLU(), 
        nn.Upsample(scale_factor=2), nn.Conv2d(16, 16, kernel_size=3, padding=1, bias=False), nn.BatchNorm2d(16), nn.ReLU(), 
                                     nn.Conv2d(16, 32, kernel_size=3, padding=1, bias=False), nn.BatchNorm2d(32), nn.ReLU(), 
        nn.Upsample(scale_factor=2), nn.Conv2d(32, 40, kernel_size=3, padding=1, bias=False), nn.BatchNorm2d(40), nn.ReLU(), 
        nn.Upsample(scale_factor=2), nn.Conv2d(40, 40, kernel_size=3, padding=1, bias=False), nn.BatchNorm2d(40), nn.ReLU(), 
                                     nn.Conv2d(40, 40, kernel_size=3, padding=0, bias=False), nn.BatchNorm2d(40), nn.ReLU(), 
                                     nn.Conv2d(40, 1,  kernel_size=3),
        nn.Sigmoid(), 
    )

    return oDecoder

#=============================================================#
#=============================================================#
torchinfo.summary(GetDecoder(), (128, 16))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               --                        --
# ├─Identity: 1-1                          [128, 16]                 --
# ├─Unflatten: 1-2                         [128, 16, 1, 1]           --
# ├─Upsample: 1-3                          [128, 16, 3, 3]           --
# ├─Conv2d: 1-4                            [128, 16, 4, 4]           1,024
# ├─BatchNorm2d: 1-5                       [128, 16, 4, 4]           32
# ├─ReLU: 1-6                              [128, 16, 4, 4]           --
# ├─Upsample: 1-7                          [128, 16, 8, 8]           --
# ├─Conv2d: 1-8                            [128, 16, 8, 8]           2,304
# ├─BatchNorm2d: 1-9                       [128, 16, 8, 8]           32
# ├─ReLU: 1-10                             [128, 16, 8, 8]           --
# ├─Conv2d: 1-11                           [128, 32, 8, 8]           4,608
# ├─BatchNorm2d: 1-12                      [128, 32, 8, 8]           64
# ├─ReLU: 1-13                             [128, 32, 8, 8]           --
# ├─Upsample: 1-14                         [128, 32, 16, 16]         --
# ├─Conv2d: 1-15                           [128, 40, 16, 16]         11,520
# ├─BatchNorm2d: 1-16                      [128, 40, 16, 16]         80
# ├─ReLU: 1-17                             [128, 40, 16, 16]         --
# ├─Upsample: 1-18                         [128, 40, 32, 32]         --
# ├─Conv2d: 1-19                           [128, 40, 32, 32]         14,400
# ├─BatchNorm2d: 1-20                      [128, 40, 32, 32]         80
# ├─ReLU: 1-21                             [128, 40, 32, 32]         --
# ├─Conv2d: 1-22                           [128, 40, 30, 30]         14,400
# ├─BatchNorm2d: 1-23                      [128, 40, 30, 30]         80
# ├─ReLU: 1-24                             [128, 40, 30, 30]         --
# ├─Conv2d: 1-25                           [128, 1, 28, 28]          361
# ├─Sigmoid: 1-26                          [128, 1, 28, 28]          --
# ==========================================================================================
# Total params: 48,985
# Trainable params: 48,985
# Non-trainable params: 0
# Total mult-adds (G): 4.02
# ==========================================================================================
# Input size (MB): 0.01
# Forward/backward pass size (MB): 186.20
# Params size (MB): 0.20
# Estimated Total Size (MB): 186.41
# ==========================================================================================

# %% [markdown]
# #### Full model (autoencoder):

# %%
def GetModel():
    oModel = nn.Sequential(
        nn.Identity(),
        GetEncoder (),
        GetDecoder ()
    )
    return oModel

#=============================================================#
#=============================================================#
torchinfo.summary(GetModel(), (128, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               --                        --
# ├─Identity: 1-1                          [128, 1, 28, 28]          --
# ├─Sequential: 1-2                        [128, 16]                 --
# │    └─Identity: 2-1                     [128, 1, 28, 28]          --
# │    └─Conv2d: 2-2                       [128, 8, 26, 26]          72
# │    └─BatchNorm2d: 2-3                  [128, 8, 26, 26]          16
# │    └─ReLU: 2-4                         [128, 8, 26, 26]          --
# │    └─Conv2d: 2-5                       [128, 16, 24, 24]         1,152
# │    └─BatchNorm2d: 2-6                  [128, 16, 24, 24]         32
# │    └─ReLU: 2-7                         [128, 16, 24, 24]         --
# │    └─Conv2d: 2-8                       [128, 32, 22, 22]         4,608
# │    └─BatchNorm2d: 2-9                  [128, 32, 22, 22]         64
# │    └─ReLU: 2-10                        [128, 32, 22, 22]         --
# │    └─Conv2d: 2-11                      [128, 64, 20, 20]         18,432
# │    └─BatchNorm2d: 2-12                 [128, 64, 20, 20]         128
# │    └─ReLU: 2-13                        [128, 64, 20, 20]         --
# │    └─Conv2d: 2-14                      [128, 64, 18, 18]         36,864
# │    └─BatchNorm2d: 2-15                 [128, 64, 18, 18]         128
# │    └─ReLU: 2-16                        [128, 64, 18, 18]         --
# │    └─MaxPool2d: 2-17                   [128, 64, 9, 9]           --
# │    └─Conv2d: 2-18                      [128, 64, 7, 7]           36,864
# │    └─BatchNorm2d: 2-19                 [128, 64, 7, 7]           128
# │    └─ReLU: 2-20                        [128, 64, 7, 7]           --
# │    └─Conv2d: 2-21                      [128, 64, 5, 5]           36,864
# │    └─BatchNorm2d: 2-22                 [128, 64, 5, 5]           128
# │    └─ReLU: 2-23                        [128, 64, 5, 5]           --
# │    └─Conv2d: 2-24                      [128, 64, 3, 3]           36,864
# │    └─BatchNorm2d: 2-25                 [128, 64, 3, 3]           128
# │    └─ReLU: 2-26                        [128, 64, 3, 3]           --
# │    └─Conv2d: 2-27                      [128, 64, 1, 1]           36,864
# │    └─BatchNorm2d: 2-28                 [128, 64, 1, 1]           128
# │    └─ReLU: 2-29                        [128, 64, 1, 1]           --
# │    └─Conv2d: 2-30                      [128, 16, 1, 1]           1,040
# │    └─Flatten: 2-31                     [128, 16]                 --
# ├─Sequential: 1-3                        [128, 1, 28, 28]          --
# │    └─Identity: 2-32                    [128, 16]                 --
# │    └─Unflatten: 2-33                   [128, 16, 1, 1]           --
# │    └─Upsample: 2-34                    [128, 16, 3, 3]           --
# │    └─Conv2d: 2-35                      [128, 16, 4, 4]           1,024
# │    └─BatchNorm2d: 2-36                 [128, 16, 4, 4]           32
# │    └─ReLU: 2-37                        [128, 16, 4, 4]           --
# │    └─Upsample: 2-38                    [128, 16, 8, 8]           --
# │    └─Conv2d: 2-39                      [128, 16, 8, 8]           2,304
# │    └─BatchNorm2d: 2-40                 [128, 16, 8, 8]           32
# │    └─ReLU: 2-41                        [128, 16, 8, 8]           --
# │    └─Conv2d: 2-42                      [128, 32, 8, 8]           4,608
# │    └─BatchNorm2d: 2-43                 [128, 32, 8, 8]           64
# │    └─ReLU: 2-44                        [128, 32, 8, 8]           --
# │    └─Upsample: 2-45                    [128, 32, 16, 16]         --
# │    └─Conv2d: 2-46                      [128, 40, 16, 16]         11,520
# │    └─BatchNorm2d: 2-47                 [128, 40, 16, 16]         80
# │    └─ReLU: 2-48                        [128, 40, 16, 16]         --
# │    └─Upsample: 2-49                    [128, 40, 32, 32]         --
# │    └─Conv2d: 2-50                      [128, 40, 32, 32]         14,400
# │    └─BatchNorm2d: 2-51                 [128, 40, 32, 32]         80
# │    └─ReLU: 2-52                        [128, 40, 32, 32]         --
# │    └─Conv2d: 2-53                      [128, 40, 30, 30]         14,400
# │    └─BatchNorm2d: 2-54                 [128, 40, 30, 30]         80
# │    └─ReLU: 2-55                        [128, 40, 30, 30]         --
# │    └─Conv2d: 2-56                      [128, 1, 28, 28]          361
# │    └─Sigmoid: 2-57                     [128, 1, 28, 28]          --
# ==========================================================================================
# Total params: 259,489
# Trainable params: 259,489
# Non-trainable params: 0
# Total mult-adds (G): 7.26
# ==========================================================================================
# Input size (MB): 0.40
# Forward/backward pass size (MB): 353.80
# Params size (MB): 1.04
# Estimated Total Size (MB): 355.24
# ==========================================================================================

# %% [markdown]
# ### Train the model:

# %%
from torch.optim.lr_scheduler       import OneCycleLR
from DeepLearningFramework.Training import TrainModel
from DeepLearningFramework.Metric   import R2Score

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu') 
Loss   = nn.MSELoss  ()
Metric = R2Score

# %%
nEpochs    = 50
nIter      = nEpochs * len(oTrainDL)

oModel     = GetModel  ().to(DEVICE)
oOptim     = optim.Adam(oModel.parameters(), lr=0, betas=(0.9, 0.99))
oScheduler = OneCycleLR(oOptim, max_lr=4e-3, total_steps=nIter)
lHistory   = TrainModel(oModel, oTrainDL, oTestDL, Loss, Metric, nEpochs, oOptim, oScheduler, sModelName='DenosingAE')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 000: | Train loss:  0.052 | Val loss:  0.029 | Train Metric:  0.450 | Val Metric:  0.697 | epoch time:  8.122 | <-- Checkpoint!
# Epoch 001: | Train loss:  0.025 | Val loss:  0.021 | Train Metric:  0.733 | Val Metric:  0.777 | epoch time:  5.733 | <-- Checkpoint!
# Epoch 002: | Train loss:  0.021 | Val loss:  0.019 | Train Metric:  0.783 | Val Metric:  0.800 | epoch time:  5.733 | <-- Checkpoint!
# Epoch 003: | Train loss:  0.018 | Val loss:  0.016 | Train Metric:  0.806 | Val Metric:  0.833 | epoch time:  5.727 | <-- Checkpoint!
# Epoch 004: | Train loss:  0.017 | Val loss:  0.016 | Train Metric:  0.820 | Val Metric:  0.834 | epoch time:  5.714 | <-- Checkpoint!
# Epoch 005: | Train loss:  0.016 | Val loss:  0.015 | Train Metric:  0.829 | Val Metric:  0.838 | epoch time:  5.729 | <-- Checkpoint!
# Epoch 006: | Train loss:  0.016 | Val loss:  0.017 | Train Metric:  0.833 | Val Metric:  0.824 | epoch time:  5.776 |
# Epoch 007: | Train loss:  0.015 | Val loss:  0.014 | Train Metric:  0.838 | Val Metric:  0.853 | epoch time:  5.709 | <-- Checkpoint!
# Epoch 008: | Train loss:  0.015 | Val loss:  0.016 | Train Metric:  0.841 | Val Metric:  0.836 | epoch time:  5.725 |
# Epoch 009: | Train loss:  0.015 | Val loss:  0.014 | Train Metric:  0.846 | Val Metric:  0.848 | epoch time:  5.765 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 010: | Train loss:  0.014 | Val loss:  0.015 | Train Metric:  0.848 | Val Metric:  0.847 | epoch time:  5.759 |
# Epoch 011: | Train loss:  0.014 | Val loss:  0.015 | Train Metric:  0.852 | Val Metric:  0.839 | epoch time:  5.783 |
# Epoch 012: | Train loss:  0.014 | Val loss:  0.013 | Train Metric:  0.856 | Val Metric:  0.864 | epoch time:  5.836 | <-- Checkpoint!
# Epoch 013: | Train loss:  0.013 | Val loss:  0.013 | Train Metric:  0.860 | Val Metric:  0.859 | epoch time:  5.766 |
# Epoch 014: | Train loss:  0.013 | Val loss:  0.012 | Train Metric:  0.863 | Val Metric:  0.870 | epoch time:  5.767 | <-- Checkpoint!
# Epoch 015: | Train loss:  0.013 | Val loss:  0.015 | Train Metric:  0.866 | Val Metric:  0.840 | epoch time:  5.783 |
# Epoch 016: | Train loss:  0.012 | Val loss:  0.012 | Train Metric:  0.869 | Val Metric:  0.877 | epoch time:  5.788 | <-- Checkpoint!
# Epoch 017: | Train loss:  0.012 | Val loss:  0.011 | Train Metric:  0.872 | Val Metric:  0.882 | epoch time:  5.890 | <-- Checkpoint!
# Epoch 018: | Train loss:  0.012 | Val loss:  0.011 | Train Metric:  0.874 | Val Metric:  0.884 | epoch time:  6.082 | <-- Checkpoint!
# Epoch 019: | Train loss:  0.012 | Val loss:  0.012 | Train Metric:  0.877 | Val Metric:  0.878 | epoch time:  6.103 |
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 020: | Train loss:  0.012 | Val loss:  0.011 | Train Metric:  0.878 | Val Metric:  0.889 | epoch time:  6.118 | <-- Checkpoint!
# Epoch 021: | Train loss:  0.011 | Val loss:  0.011 | Train Metric:  0.879 | Val Metric:  0.881 | epoch time:  6.216 |
# Epoch 022: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.881 | Val Metric:  0.892 | epoch time:  6.041 | <-- Checkpoint!
# Epoch 023: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.883 | Val Metric:  0.890 | epoch time:  6.101 |
# Epoch 024: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.885 | Val Metric:  0.894 | epoch time:  6.105 | <-- Checkpoint!
# Epoch 025: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.886 | Val Metric:  0.895 | epoch time:  6.181 | <-- Checkpoint!
# Epoch 026: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.887 | Val Metric:  0.895 | epoch time:  5.935 |
# Epoch 027: | Train loss:  0.011 | Val loss:  0.010 | Train Metric:  0.889 | Val Metric:  0.897 | epoch time:  5.939 | <-- Checkpoint!
# Epoch 028: | Train loss:  0.010 | Val loss:  0.010 | Train Metric:  0.890 | Val Metric:  0.898 | epoch time:  5.906 | <-- Checkpoint!
# Epoch 029: | Train loss:  0.010 | Val loss:  0.010 | Train Metric:  0.891 | Val Metric:  0.898 | epoch time:  5.969 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 030: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.892 | Val Metric:  0.901 | epoch time:  6.109 | <-- Checkpoint!
# Epoch 031: | Train loss:  0.010 | Val loss:  0.010 | Train Metric:  0.894 | Val Metric:  0.899 | epoch time:  6.124 |
# Epoch 032: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.895 | Val Metric:  0.902 | epoch time:  6.112 | <-- Checkpoint!
# Epoch 033: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.896 | Val Metric:  0.905 | epoch time:  6.195 | <-- Checkpoint!
# Epoch 034: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.897 | Val Metric:  0.903 | epoch time:  6.554 |
# Epoch 035: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.898 | Val Metric:  0.907 | epoch time:  6.479 | <-- Checkpoint!
# Epoch 036: | Train loss:  0.010 | Val loss:  0.009 | Train Metric:  0.899 | Val Metric:  0.908 | epoch time:  6.262 | <-- Checkpoint!
# Epoch 037: | Train loss:  0.009 | Val loss:  0.009 | Train Metric:  0.900 | Val Metric:  0.904 | epoch time:  6.082 |
# Epoch 038: | Train loss:  0.009 | Val loss:  0.009 | Train Metric:  0.901 | Val Metric:  0.907 | epoch time:  6.141 |
# Epoch 039: | Train loss:  0.009 | Val loss:  0.009 | Train Metric:  0.901 | Val Metric:  0.908 | epoch time:  6.064 | <-- Checkpoint!
# ------------------------------------------------------------------------------------------------------------------------
# Epoch 040: | Train loss:  0.009 | Val loss:  0.009 | Train Metric:  0.902 | Val Metric:  0.908 | epoch time:  6.072 |
# Epoch 041: | Train loss:  0.009 | Val loss:  0.009 | Train Metric:  0.903 | Val Metric:  0.910 | epoch time:  5.996 | <-- Checkpoint!
# Epoch 042: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.904 | Val Metric:  0.911 | epoch time:  6.069 | <-- Checkpoint!
# Epoch 043: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.904 | Val Metric:  0.911 | epoch time:  6.034 | <-- Checkpoint!
# Epoch 044: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.905 | Val Metric:  0.911 | epoch time:  6.051 | <-- Checkpoint!
# Epoch 045: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.905 | Val Metric:  0.912 | epoch time:  6.069 | <-- Checkpoint!
# Epoch 046: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.906 | Val Metric:  0.912 | epoch time:  6.061 | <-- Checkpoint!
# Epoch 047: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.906 | Val Metric:  0.911 | epoch time:  6.044 |
# Epoch 048: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.906 | Val Metric:  0.912 | epoch time:  6.021 |
# Epoch 049: | Train loss:  0.009 | Val loss:  0.008 | Train Metric:  0.906 | Val Metric:  0.912 | epoch time:  6.047 |

# %%
from DeepLearningFramework.Auxiliary import PlotHistory

PlotHistory(lHistory)
plt.show   ()

# %%
# #-- Run this to load a trained model:
# oModel = GetModel().to(DEVICE)
# oModel.load_state_dict(torch.load('DenosingAE_v1.pt'))
# oModel.train(False);

# %% [markdown]
# ### Test the model:

# %%
oModel.eval()
nTest   = len(oTestSet)
idx     = np.random.randint(nTest)
mXN, mX = oTestSet[idx]
with torch.no_grad():
    mHatX = oModel(mXN[None].to(DEVICE))[0]

_, axs = plt.subplots(1, 3, figsize=(8, 4))
axs[0].matshow(mX            [0], cmap='gray'); axs[0].set_title('Original')
axs[1].matshow(mXN.clamp(0,1)[0], cmap='gray'); axs[1].set_title('Noisy')
axs[2].matshow(mHatX.cpu()   [0], cmap='gray'); axs[2].set_title('Output')
plt.tight_layout()
plt.show()
