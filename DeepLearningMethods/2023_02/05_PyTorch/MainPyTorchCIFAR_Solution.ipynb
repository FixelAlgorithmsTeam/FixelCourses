# %% [markdown]
# ![Fixel Algorithms](https://fixelalgorithms.co/images/CCExt.png)

# %% [markdown]
# # <center> Deep Learning Methods </center>
# ## <center> Lecture 5 - PyTorch</center>
# ### <center> Cifar-10 Example - Solution </center>

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FixelAlgorithmsTeam/FixelCourses/blob/master/DeepLearningMethods/05_PyTorch/MainPyTorchCifar_Solution.ipynb)

# %%
#-- Wide screen:
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
#-- Auto reload:
# %load_ext autoreload
# %autoreload 2

# %%
if 'google.colab' in str(get_ipython()):
    # !pip install torchinfo

# %%
#-- Imports:
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib

#-- torch:
import torch
import torch.nn            as nn
import torch.nn.functional as F
import torch.optim         as optim
import torchinfo

# #-- Fix seed (for presentation sake)
# torch.manual_seed(0)
# np.random.seed   (0)
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark     = False

# %%
def Epoch(oModel, oDataDL, Loss, Metric, oOptim=None, bTrain=True):

    epochLoss   = 0
    epochMetric = 0
    count       = 0
    nIter       = len(oDataDL)
    DEVICE      = next(oModel.parameters()).device #-- CPU\GPU

    oModel.train(bTrain) #-- train or test
    
    #-- Iterate over the mini-batches:
    for ii, (mX, vY) in enumerate(oDataDL):
        #-- Move to device (CPU\GPU):
        mX = mX.to(DEVICE)
        vY = vY.to(DEVICE)
        
        #-- Forward:
        if bTrain == True:
            #-- Store computational graph:
            mZ   = oModel(mX)
            loss = Loss(mZ, vY)
        else:
            with torch.no_grad():
                #-- Do not store computational graph:
                mZ   = oModel(mX)
                loss = Loss(mZ, vY)

        #-- Backward:
        if bTrain == True:
            oOptim.zero_grad() #-- set gradients to zeros
            loss.backward()    #-- backward
            oOptim.step()      #-- update parameters

        Nb           = vY.shape[0]
        count       += Nb
        epochLoss   += Nb * loss.item()
        epochMetric += Nb * Metric(mZ, vY)
        print(f'\r{"Train" if bTrain else "Val"} - Iteration: {ii:3d} ({nIter}): loss = {loss:.6f}', end='')

    print('', end='\r')
    epochLoss   /= count
    epochMetric /= count

    return epochLoss, epochMetric

# %% [markdown]
# ### Exercise:
# * Use the California housing dataset `fetch_california_housing`.
# * Use MSE loss (instead of the cross-entropy)
# * Replace the classification accuracy with $R^2$ score.
# * Try to get the best MSE\R2 score you can.
#
# **Tips**:
# * You should test different models (layers\activations) and hyper-parameters.
# * Try different optimizers and regularizations.
# * $R_2 > 0.8$ (on the validation set) is quite good.

# %%
from sklearn.datasets import fetch_california_housing

mX, vY  = fetch_california_housing(return_X_y=True)
mX     -= mX.mean(0)
mX     /= mX.std (0)

mX.shape, vY.shape
# Out:
# ((20640, 8), (20640,))

# %%
from torch.utils.data import TensorDataset

nTrain              = 15000
nTest               = 5640
oDataset            = TensorDataset(torch.tensor(mX, dtype=torch.float32), torch.tensor(vY, dtype=torch.float32))
oTrainSet, oValSet  = torch.utils.data.random_split(oDataset, [nTrain, nTest])
len(oTrainSet), len(oValSet)
# Out:
# (15000, 5640)

# %% [markdown]
# #### $R^2$ function
# `tensor.detach()` creates a tensor that shares storage with `tensor` that does not require grad.

# %%
from sklearn.metrics import r2_score

def R2Score(vHatY, vY):
    vY    = vY   .detach().cpu().view(-1)
    vHatY = vHatY.detach().cpu().view(-1)
    return r2_score(vY, vHatY)

# %%
import time

def TrainRegressionModel(oModel, oTrainData, oValData, Loss, nEpochs, oOptim):

    vTrainLoss = np.full(nEpochs, np.nan)
    vTrainR2   = np.full(nEpochs, np.nan)
    vValLoss   = np.full(nEpochs, np.nan)
    vValR2     = np.full(nEpochs, np.nan)
    bestR2     = 0

    for epoch in range(nEpochs):
        startTime = time.time()
        trainLoss, trainR2 = Epoch(oModel, oTrainData, Loss, R2Score, oOptim, bTrain=True ) #-- train
        valLoss,   valR2   = Epoch(oModel, oValData,   Loss, R2Score,         bTrain=False) #-- validate
        epochTime = time.time() - startTime

        #-- Display:
        print('Epoch '          f'{epoch    :03d}:',   end='')
        print(' | Train loss: ' f'{trainLoss:6.3f}' ,  end='')
        print(' | Val loss: '   f'{valLoss  :6.3f}' ,  end='')
        print(' | Train R²: '   f'{trainR2 :+6.3f}',   end='')
        print(' | Val R²: '     f'{valR2   :+6.3f}',   end='')
        print(' | epoch time: ' f'{epochTime:3.3f} |', end='')

        vTrainLoss[epoch] = trainLoss
        vTrainR2  [epoch] = trainR2
        vValLoss  [epoch] = valLoss
        vValR2    [epoch] = valR2

        #-- Save best model (early stopping):
        if bestR2 < valR2:
            bestR2 = valR2
            try:
                dCheckpoint = {'Model'     : oModel.state_dict(),
                               'Optimizer' : oOptim.state_dict()}
                torch.save(dCheckpoint, 'BestModel.pt')
            except:
                pass
            print(' <-- Checkpoint!')
        else:
            print('')

    #-- Load best model (early stopping):
    dCheckpoint = torch.load('BestModel.pt')
    oModel.load_state_dict(dCheckpoint['Model'])

    return vTrainLoss, vTrainR2, vValLoss, vValR2

# %%
batchSize = 128
oTrainDL  = torch.utils.data.DataLoader(oTrainSet, shuffle=True,  batch_size=batchSize,   num_workers=2, persistent_workers=True)
oValDL    = torch.utils.data.DataLoader(oValSet,   shuffle=False, batch_size=2*batchSize, num_workers=2, persistent_workers=True)

mX,       vY       = next(iter(oTrainDL))
mX.shape, vY.shape
# Out:
# (torch.Size([128, 8]), torch.Size([128]))

# %%
import torch.nn            as nn
import torch.nn.functional as F
import torch.optim         as optim
import torchinfo

#-- Model:
def GetModel():
    p      = 0.1
    oModel = nn.Sequential(
        nn.Identity(),  #-- does nothing
        nn.Linear (8,   900), nn.LeakyReLU(), nn.Dropout(p),
        nn.Linear (900, 700), nn.LeakyReLU(), nn.Dropout(p),
        nn.Linear (700, 500), nn.LeakyReLU(), nn.Dropout(p),
        nn.Linear (500, 300), nn.LeakyReLU(), nn.Dropout(p),
        nn.Linear (300, 100), nn.LeakyReLU(), nn.Dropout(p),
        nn.Linear (100, 1),
        nn.Flatten(start_dim=0)
    )
    
    def InitWeights(oLayer):
        if isinstance(oLayer, nn.Linear):
            nn.init.kaiming_normal_(oLayer.weight.data)

    oModel.apply(InitWeights)
    
    return oModel

#--------------------------------------------------------------------------------#
#--------------------------------------------------------------------------------#
torchinfo.summary(GetModel(), mX.shape)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Sequential                               --                        --
# ├─Identity: 1-1                          [128, 8]                  --
# ├─Linear: 1-2                            [128, 900]                8,100
# ├─LeakyReLU: 1-3                         [128, 900]                --
# ├─Dropout: 1-4                           [128, 900]                --
# ├─Linear: 1-5                            [128, 700]                630,700
# ├─LeakyReLU: 1-6                         [128, 700]                --
# ├─Dropout: 1-7                           [128, 700]                --
# ├─Linear: 1-8                            [128, 500]                350,500
# ├─LeakyReLU: 1-9                         [128, 500]                --
# ├─Dropout: 1-10                          [128, 500]                --
# ├─Linear: 1-11                           [128, 300]                150,300
# ├─LeakyReLU: 1-12                        [128, 300]                --
# ├─Dropout: 1-13                          [128, 300]                --
# ├─Linear: 1-14                           [128, 100]                30,100
# ├─LeakyReLU: 1-15                        [128, 100]                --
# ├─Dropout: 1-16                          [128, 100]                --
# ├─Linear: 1-17                           [128, 1]                  101
# ├─Flatten: 1-18                          [128]                     --
# ==========================================================================================
# Total params: 1,169,801
# Trainable params: 1,169,801
# Non-trainable params: 0
# Total mult-adds (M): 149.73
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 2.56
# Params size (MB): 4.68
# Estimated Total Size (MB): 7.24
# ==========================================================================================

# %%
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") 
DEVICE
# Out:
# device(type='cuda', index=0)

# %%
nEpochs  = 100
Loss     = nn.MSELoss()

oModel   = GetModel            ().to(DEVICE)
oOptim   = optim.AdamW         (oModel.parameters(), lr=1e-3, betas=(0.9, 0.99), weight_decay=3e-5)
lHistory = TrainRegressionModel(oModel, oTrainDL, oValDL, Loss, nEpochs, oOptim);
# Out:
# Epoch 000: | Train loss:  1.685 | Val loss:  0.686 | Train R²: -0.287 | Val R²: +0.489 | epoch time: 1.457 | <-- Checkpoint!
# Epoch 001: | Train loss:  2.760 | Val loss:  0.523 | Train R²: -0.953 | Val R²: +0.610 | epoch time: 0.360 | <-- Checkpoint!
# Epoch 002: | Train loss:  3.510 | Val loss:  2.344 | Train R²: -2.907 | Val R²: -0.747 | epoch time: 0.341 |
# Epoch 003: | Train loss: 13.824 | Val loss:  0.458 | Train R²: -10.759 | Val R²: +0.660 | epoch time: 0.337 | <-- Checkpoint!
# Epoch 004: | Train loss:  1.091 | Val loss:  5.326 | Train R²: +0.226 | Val R²: -2.973 | epoch time: 0.336 |
# Epoch 005: | Train loss:  4.677 | Val loss:  0.715 | Train R²: -2.432 | Val R²: +0.455 | epoch time: 0.351 |
# Epoch 006: | Train loss: 10.189 | Val loss:  0.443 | Train R²: -7.420 | Val R²: +0.672 | epoch time: 0.337 | <-- Checkpoint!
# Epoch 007: | Train loss:  1.468 | Val loss:  0.373 | Train R²: -0.250 | Val R²: +0.724 | epoch time: 0.351 | <-- Checkpoint!
# Epoch 008: | Train loss:  0.476 | Val loss:  0.424 | Train R²: +0.636 | Val R²: +0.686 | epoch time: 0.336 |
# Epoch 009: | Train loss:  0.560 | Val loss:  0.727 | Train R²: +0.569 | Val R²: +0.460 | epoch time: 0.354 |
# Epoch 010: | Train loss:  1.137 | Val loss:  0.493 | Train R²: +0.204 | Val R²: +0.634 | epoch time: 0.339 |
# Epoch 011: | Train loss:  0.973 | Val loss:  0.499 | Train R²: +0.262 | Val R²: +0.630 | epoch time: 0.335 |
# Epoch 012: | Train loss:  0.458 | Val loss:  0.520 | Train R²: +0.638 | Val R²: +0.615 | epoch time: 0.338 |
# Epoch 013: | Train loss:  0.573 | Val loss:  0.370 | Train R²: +0.546 | Val R²: +0.726 | epoch time: 0.335 | <-- Checkpoint!
# Epoch 014: | Train loss:  9.081 | Val loss:  0.389 | Train R²: -5.112 | Val R²: +0.711 | epoch time: 0.348 |
# Epoch 015: | Train loss:  0.500 | Val loss:  0.346 | Train R²: +0.609 | Val R²: +0.744 | epoch time: 0.334 | <-- Checkpoint!
# Epoch 016: | Train loss:  0.976 | Val loss:  0.427 | Train R²: +0.273 | Val R²: +0.684 | epoch time: 0.334 |
# Epoch 017: | Train loss:  0.815 | Val loss:  0.324 | Train R²: +0.344 | Val R²: +0.759 | epoch time: 0.339 | <-- Checkpoint!
# Epoch 018: | Train loss:  0.542 | Val loss:  0.388 | Train R²: +0.581 | Val R²: +0.713 | epoch time: 0.351 |
# Epoch 019: | Train loss:  0.759 | Val loss:  0.415 | Train R²: +0.459 | Val R²: +0.693 | epoch time: 0.340 |
# Epoch 020: | Train loss:  0.362 | Val loss:  0.411 | Train R²: +0.722 | Val R²: +0.696 | epoch time: 0.324 |
# Epoch 021: | Train loss:  0.357 | Val loss:  0.352 | Train R²: +0.726 | Val R²: +0.739 | epoch time: 0.349 |
# Epoch 022: | Train loss:  0.347 | Val loss:  0.324 | Train R²: +0.732 | Val R²: +0.760 | epoch time: 0.337 | <-- Checkpoint!
# Epoch 023: | Train loss:  0.344 | Val loss:  0.316 | Train R²: +0.736 | Val R²: +0.766 | epoch time: 0.334 | <-- Checkpoint!
# Epoch 024: | Train loss:  0.439 | Val loss:  0.361 | Train R²: +0.676 | Val R²: +0.733 | epoch time: 0.344 |
# Epoch 025: | Train loss:  0.650 | Val loss:  0.299 | Train R²: +0.505 | Val R²: +0.778 | epoch time: 0.337 | <-- Checkpoint!
# Epoch 026: | Train loss:  0.373 | Val loss:  0.324 | Train R²: +0.717 | Val R²: +0.760 | epoch time: 0.334 |
# Epoch 027: | Train loss:  0.401 | Val loss:  0.292 | Train R²: +0.698 | Val R²: +0.783 | epoch time: 0.340 | <-- Checkpoint!
# Epoch 028: | Train loss:  0.341 | Val loss:  0.320 | Train R²: +0.738 | Val R²: +0.763 | epoch time: 0.332 |
# Epoch 029: | Train loss:  0.520 | Val loss:  0.338 | Train R²: +0.577 | Val R²: +0.750 | epoch time: 0.338 |
# Epoch 030: | Train loss:  0.682 | Val loss:  0.292 | Train R²: +0.394 | Val R²: +0.784 | epoch time: 0.348 | <-- Checkpoint!
# Epoch 031: | Train loss:  0.479 | Val loss:  0.288 | Train R²: +0.656 | Val R²: +0.787 | epoch time: 0.328 | <-- Checkpoint!
# Epoch 032: | Train loss:  0.473 | Val loss:  0.289 | Train R²: +0.630 | Val R²: +0.786 | epoch time: 0.353 |
# Epoch 033: | Train loss:  0.326 | Val loss:  0.283 | Train R²: +0.750 | Val R²: +0.791 | epoch time: 0.352 | <-- Checkpoint!
# Epoch 034: | Train loss:  0.309 | Val loss:  0.289 | Train R²: +0.763 | Val R²: +0.786 | epoch time: 0.339 |
# Epoch 035: | Train loss:  0.386 | Val loss:  0.290 | Train R²: +0.711 | Val R²: +0.785 | epoch time: 0.335 |
# Epoch 036: | Train loss:  0.318 | Val loss:  0.278 | Train R²: +0.753 | Val R²: +0.793 | epoch time: 0.364 | <-- Checkpoint!
# Epoch 037: | Train loss:  0.325 | Val loss:  0.350 | Train R²: +0.750 | Val R²: +0.741 | epoch time: 0.330 |
# Epoch 038: | Train loss:  0.319 | Val loss:  0.279 | Train R²: +0.752 | Val R²: +0.793 | epoch time: 0.336 |
# Epoch 039: | Train loss:  0.309 | Val loss:  0.291 | Train R²: +0.763 | Val R²: +0.785 | epoch time: 0.337 |
# Epoch 040: | Train loss:  0.287 | Val loss:  0.289 | Train R²: +0.779 | Val R²: +0.786 | epoch time: 0.337 |
# Epoch 041: | Train loss:  0.298 | Val loss:  0.309 | Train R²: +0.771 | Val R²: +0.771 | epoch time: 0.341 |
# Epoch 042: | Train loss:  0.299 | Val loss:  0.289 | Train R²: +0.770 | Val R²: +0.785 | epoch time: 0.334 |
# Epoch 043: | Train loss:  0.294 | Val loss:  0.318 | Train R²: +0.773 | Val R²: +0.765 | epoch time: 0.337 |
# Epoch 044: | Train loss:  4.141 | Val loss:  0.301 | Train R²: -2.149 | Val R²: +0.777 | epoch time: 0.338 |
# Epoch 045: | Train loss:  0.285 | Val loss:  0.307 | Train R²: +0.781 | Val R²: +0.772 | epoch time: 0.345 |
# Epoch 046: | Train loss:  0.289 | Val loss:  0.278 | Train R²: +0.776 | Val R²: +0.794 | epoch time: 0.332 | <-- Checkpoint!
# Epoch 047: | Train loss:  0.358 | Val loss:  0.315 | Train R²: +0.697 | Val R²: +0.767 | epoch time: 0.337 |
# Epoch 048: | Train loss:  0.278 | Val loss:  0.293 | Train R²: +0.785 | Val R²: +0.783 | epoch time: 0.337 |
# Epoch 049: | Train loss:  0.274 | Val loss:  0.288 | Train R²: +0.789 | Val R²: +0.787 | epoch time: 0.352 |
# Epoch 050: | Train loss:  0.274 | Val loss:  0.302 | Train R²: +0.789 | Val R²: +0.776 | epoch time: 0.355 |
# Epoch 051: | Train loss:  0.278 | Val loss:  0.293 | Train R²: +0.785 | Val R²: +0.783 | epoch time: 0.337 |
# Epoch 052: | Train loss:  0.273 | Val loss:  0.269 | Train R²: +0.791 | Val R²: +0.801 | epoch time: 0.338 | <-- Checkpoint!
# Epoch 053: | Train loss:  0.274 | Val loss:  0.286 | Train R²: +0.789 | Val R²: +0.788 | epoch time: 0.352 |
# Epoch 054: | Train loss:  0.278 | Val loss:  0.318 | Train R²: +0.787 | Val R²: +0.764 | epoch time: 0.336 |
# Epoch 055: | Train loss:  0.278 | Val loss:  0.277 | Train R²: +0.784 | Val R²: +0.795 | epoch time: 0.350 |
# Epoch 056: | Train loss:  0.274 | Val loss:  0.293 | Train R²: +0.787 | Val R²: +0.783 | epoch time: 0.341 |
# Epoch 057: | Train loss:  0.347 | Val loss:  0.324 | Train R²: +0.729 | Val R²: +0.760 | epoch time: 0.339 |
# Epoch 058: | Train loss:  0.270 | Val loss:  0.296 | Train R²: +0.793 | Val R²: +0.781 | epoch time: 0.335 |
# Epoch 059: | Train loss:  0.287 | Val loss:  0.318 | Train R²: +0.776 | Val R²: +0.765 | epoch time: 0.337 |
# Epoch 060: | Train loss:  0.260 | Val loss:  0.277 | Train R²: +0.801 | Val R²: +0.795 | epoch time: 0.352 |
# Epoch 061: | Train loss:  0.261 | Val loss:  0.290 | Train R²: +0.802 | Val R²: +0.785 | epoch time: 0.326 |
# Epoch 062: | Train loss:  0.255 | Val loss:  0.280 | Train R²: +0.803 | Val R²: +0.792 | epoch time: 0.351 |
# Epoch 063: | Train loss:  0.253 | Val loss:  0.273 | Train R²: +0.806 | Val R²: +0.798 | epoch time: 0.350 |
# Epoch 064: | Train loss:  0.254 | Val loss:  0.275 | Train R²: +0.805 | Val R²: +0.796 | epoch time: 0.339 |
# Epoch 065: | Train loss:  0.249 | Val loss:  0.284 | Train R²: +0.809 | Val R²: +0.790 | epoch time: 0.335 |
# Epoch 066: | Train loss:  0.248 | Val loss:  0.268 | Train R²: +0.808 | Val R²: +0.801 | epoch time: 0.357 | <-- Checkpoint!
# Epoch 067: | Train loss:  0.243 | Val loss:  0.281 | Train R²: +0.814 | Val R²: +0.791 | epoch time: 0.335 |
# Epoch 068: | Train loss:  0.284 | Val loss:  0.270 | Train R²: +0.780 | Val R²: +0.799 | epoch time: 0.342 |
# Epoch 069: | Train loss:  0.239 | Val loss:  0.287 | Train R²: +0.817 | Val R²: +0.787 | epoch time: 0.349 |
# Epoch 070: | Train loss:  0.243 | Val loss:  0.275 | Train R²: +0.813 | Val R²: +0.797 | epoch time: 0.339 |
# Epoch 071: | Train loss:  0.233 | Val loss:  0.268 | Train R²: +0.821 | Val R²: +0.801 | epoch time: 0.355 | <-- Checkpoint!
# Epoch 072: | Train loss:  0.247 | Val loss:  0.276 | Train R²: +0.810 | Val R²: +0.795 | epoch time: 0.340 |
# Epoch 073: | Train loss:  0.237 | Val loss:  0.272 | Train R²: +0.817 | Val R²: +0.798 | epoch time: 0.331 |
# Epoch 074: | Train loss:  0.230 | Val loss:  0.302 | Train R²: +0.824 | Val R²: +0.777 | epoch time: 0.350 |
# Epoch 075: | Train loss:  0.231 | Val loss:  0.276 | Train R²: +0.822 | Val R²: +0.795 | epoch time: 0.338 |
# Epoch 076: | Train loss:  0.234 | Val loss:  0.277 | Train R²: +0.820 | Val R²: +0.795 | epoch time: 0.343 |
# Epoch 077: | Train loss:  0.227 | Val loss:  0.306 | Train R²: +0.825 | Val R²: +0.774 | epoch time: 0.335 |
# Epoch 078: | Train loss:  0.229 | Val loss:  0.268 | Train R²: +0.823 | Val R²: +0.801 | epoch time: 0.337 | <-- Checkpoint!
# Epoch 079: | Train loss:  0.221 | Val loss:  0.290 | Train R²: +0.828 | Val R²: +0.785 | epoch time: 0.337 |
# Epoch 080: | Train loss:  0.226 | Val loss:  0.264 | Train R²: +0.826 | Val R²: +0.804 | epoch time: 0.350 | <-- Checkpoint!
# Epoch 081: | Train loss:  0.222 | Val loss:  0.293 | Train R²: +0.829 | Val R²: +0.783 | epoch time: 0.350 |
# Epoch 082: | Train loss:  0.218 | Val loss:  0.273 | Train R²: +0.831 | Val R²: +0.798 | epoch time: 0.327 |
# Epoch 083: | Train loss:  0.223 | Val loss:  0.280 | Train R²: +0.829 | Val R²: +0.793 | epoch time: 0.338 |
# Epoch 084: | Train loss:  0.217 | Val loss:  0.289 | Train R²: +0.834 | Val R²: +0.786 | epoch time: 0.336 |
# Epoch 085: | Train loss:  0.213 | Val loss:  0.273 | Train R²: +0.836 | Val R²: +0.798 | epoch time: 0.360 |
# Epoch 086: | Train loss:  0.211 | Val loss:  0.273 | Train R²: +0.839 | Val R²: +0.798 | epoch time: 0.349 |
# Epoch 087: | Train loss:  0.219 | Val loss:  0.263 | Train R²: +0.832 | Val R²: +0.805 | epoch time: 0.336 | <-- Checkpoint!
# Epoch 088: | Train loss:  0.212 | Val loss:  0.265 | Train R²: +0.837 | Val R²: +0.803 | epoch time: 0.337 |
# Epoch 089: | Train loss:  0.211 | Val loss:  0.280 | Train R²: +0.837 | Val R²: +0.792 | epoch time: 0.337 |
# Epoch 090: | Train loss:  0.213 | Val loss:  0.256 | Train R²: +0.835 | Val R²: +0.810 | epoch time: 0.345 | <-- Checkpoint!
# Epoch 091: | Train loss:  0.205 | Val loss:  0.261 | Train R²: +0.843 | Val R²: +0.806 | epoch time: 0.351 |
# Epoch 092: | Train loss:  0.208 | Val loss:  0.262 | Train R²: +0.841 | Val R²: +0.806 | epoch time: 0.332 |
# Epoch 093: | Train loss:  0.198 | Val loss:  0.259 | Train R²: +0.848 | Val R²: +0.808 | epoch time: 0.338 |
# Epoch 094: | Train loss:  0.202 | Val loss:  0.261 | Train R²: +0.845 | Val R²: +0.806 | epoch time: 0.335 |
# Epoch 095: | Train loss:  0.200 | Val loss:  0.263 | Train R²: +0.846 | Val R²: +0.805 | epoch time: 0.347 |
# Epoch 096: | Train loss:  0.201 | Val loss:  0.268 | Train R²: +0.845 | Val R²: +0.801 | epoch time: 0.340 |
# Epoch 097: | Train loss:  0.196 | Val loss:  0.269 | Train R²: +0.850 | Val R²: +0.800 | epoch time: 0.346 |
# Epoch 098: | Train loss:  0.196 | Val loss:  0.264 | Train R²: +0.850 | Val R²: +0.804 | epoch time: 0.342 |
# Epoch 099: | Train loss:  0.199 | Val loss:  0.265 | Train R²: +0.846 | Val R²: +0.804 | epoch time: 0.343 |

# %%
def PlotHistory(lHistory):

    vTrainLoss, vTrainR2, vValLoss, vValR2 = lHistory
    
    plt.figure(figsize=(16, 6))
    
    plt.subplot(1,2,1)
    plt.plot   (vTrainLoss, 'b', lw=2, label='Train'     )
    plt.plot   (vValLoss,   'r', lw=2, label='Validation')
    plt.title  ('Loss')
    plt.xlabel ('epoch')
    plt.ylim   ([0, 2])
    plt.legend ()
    plt.grid   ()

    plt.subplot(1,2,2)
    plt.plot   (vTrainR2, 'b', lw=2, label='Train'     )
    plt.plot   (vValR2,   'r', lw=2, label='Validation')
    plt.title  ('$R^2$')
    plt.xlabel ('epoch')
    plt.ylim   ([0, 1])
    plt.legend ()
    plt.grid   ()
    
PlotHistory (lHistory)
plt.suptitle('Exercise 2')
plt.show    ()

# %%
from torch.utils.data import DataLoader
from sklearn.metrics  import r2_score

#-- Entire dataset in one batch:
mTrainX, vTrainY = next(iter(DataLoader(oTrainSet, shuffle=False, batch_size=nTrain)))
mValX,   vValY   = next(iter(DataLoader(oValSet,   shuffle=False, batch_size=nTest )))

#-- Apply model to data:
with torch.no_grad():
    vHatTrainY = oModel(mTrainX.to(DEVICE)).detach().cpu()
    vHatValY   = oModel(mValX  .to(DEVICE)).detach().cpu()

_, ax = plt.subplots(1, 2, figsize=(16, 7))

ax[0].scatter   (vTrainY, vHatTrainY, s=10, c='b', edgecolor=None)
ax[1].scatter   (vValY,   vHatValY,   s=10, c='b', edgecolor=None)
ax[0].plot      (vTrainY, vTrainY, ':k')
ax[1].plot      (vValY,   vValY,   ':k')
ax[0].set_title ('Train $R^2$ score:'      f'{r2_score(vTrainY, vHatTrainY)}')
ax[1].set_title ('Validation $R^2$ score:' f'{r2_score(vValY,   vHatValY)}')
ax[0].set_xlabel('$y_i$')
ax[1].set_xlabel('$y_i$')
ax[0].set_ylabel('$\hat{y}_i$')
ax[1].set_ylabel('$\hat{y}_i$')

plt.tight_layout()
plt.show        ()
